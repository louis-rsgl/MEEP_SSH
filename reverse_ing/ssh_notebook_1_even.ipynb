# %%
#!/usr/bin/env python
# coding: utf-8
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_waveguide(N, intra_pair_spacing, inter_pair_spacing, radius):
        # Adjust spacings to include the diameters of the circles
        adjusted_intra_pair_spacing = intra_pair_spacing + 2 * radius
        adjusted_inter_pair_spacing = inter_pair_spacing + 2 * radius
        
        # Generate the list with adjusted spacings
        result = [0]
        for i in range(1, N):
            if i % 2 == 1:  # If it's an odd index, use adjusted intra-pair spacing
                next_value = result[-1] + adjusted_intra_pair_spacing
            else:  # For even indices, use adjusted inter-pair spacing
                next_value = result[-1] + adjusted_inter_pair_spacing
            result.append(next_value)
        
        # Find the center value
        if N % 2 == 1:
            center_value = result[len(result) // 2]
        else:
            center_value = (result[(len(result) // 2) - 1] + result[len(result) // 2]) / 2
        
        # Shift the list so the center value is at 0
        shifted_result = [x - center_value for x in result]
        
        return shifted_result

# %%
# Material definitions
n_SiO2 = 1.45  # Refractive index of SiO2
eps_SiO2 = n_SiO2**2  # Dielectric constant of SiO2

resolution = 20  # pixels/um
w = 2  # width of waveguide in um
r = 0.5  # radius of holes in um
t_1 = 1  # intra-pair spacing
t_2 = 2  # inter-pair spacing (defect spacing, ordinary spacing = 1)
sy = 10  # size of cell in y direction (perpendicular to waveguide), in um
pad = 7  # padding between last hole and PML edge, in um
dpml = 1  # PML thickness, in um
N = 16  # number of holes

# %%
wl = 1    # source wavelength (in μm)
fcen = 1/wl  # pulse center frequency (in 1/μm)
df = 0.001  # pulse width (in frequency, in 1/μm)
nfreq = 500  # number of frequency points to compute flux

# %%
# Calculate the size of the cell in the x direction
if N % 2 == 0:
    sx = 2 * (pad + dpml + N // 2 + 2 * N // 2) - 20
else:
    sx = 2 * (pad + dpml + (N + 1) // 2 + 2 * (N + 1) // 2) - 20


cell = mp.Vector3(sx, sy, 0)
pml_layers = [mp.PML(dpml)]

# Define the waveguide material
SiO2_material = mp.Medium(epsilon=eps_SiO2)


# Source
sources = [mp.Source(mp.GaussianSource(wavelength=wl, fwidth=df),
                     component=mp.Ez,
                     center=mp.Vector3(-0.5 * sx + dpml),
                     size=mp.Vector3(0, w, 0))]

# Normalization run simulation
norm_sim = mp.Simulation(cell_size=cell,
                         boundary_layers=pml_layers,
                         geometry=[mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)],  # No holes for normalization
                         sources=sources,
                         resolution=resolution)



# Flux monitors
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5 * sx + dpml + 0.5), size=mp.Vector3(0, 2*w, 0))
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5 * sx - dpml - 0.5), size=mp.Vector3(0, 2*w, 0))


# Add flux monitors
norm_refl = norm_sim.add_flux(fcen, df, nfreq, refl_fr)
norm_tran = norm_sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
plt.title("Wave guide no holes")
norm_sim.plot2D()
plt.show()

# Run normalization simulation
norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(figsize=(16,9) )
plt.title("Wave propagation no holes z component")
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Save flux for normalization
norm_refl_data = norm_sim.get_flux_data(norm_refl)
norm_tran_data = norm_sim.get_flux_data(norm_tran)

# Calculate the incident power for normalization
norm_refl_flux = mp.get_fluxes(norm_refl)
norm_tran_flux = mp.get_fluxes(norm_tran)
norm_incident_flux = np.array(norm_refl_flux) + np.array(norm_tran_flux)

# Reset simulation for main run with holes
norm_sim.reset_meep()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000268936 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# time for set_epsilon = 0.26435 s
# -----------
# field decay(t = 50.025000000000006): 1.2904399841634256e-17 / 1.2904399841634256e-17 = 1.0
# field decay(t = 100.05000000000001): 4.40050923509865e-12 / 4.40050923509865e-12 = 1.0
# on time step 5617 (time=140.425), 0.000712243 s/step
# field decay(t = 150.07500000000002): 7.217280328538401e-12 / 7.217280328538401e-12 = 1.0
# field decay(t = 200.10000000000002): 1.1710712829685955e-11 / 1.1710712829685955e-11 = 1.0
# field decay(t = 250.125): 1.8696349286156955e-11 / 1.8696349286156955e-11 = 1.0
# on time step 10988 (time=274.7), 0.000744822 s/step
# field decay(t = 300.15000000000003): 3.034176194759502e-11 / 3.034176194759502e-11 = 1.0
# field decay(t = 350.175): 4.8584561846709556e-11 / 4.8584561846709556e-11 = 1.0
# on time step 15930 (time=398.25), 0.000809495 s/step
# field decay(t = 400.20000000000005): 7.751364463352526e-11 / 7.751364463352526e-11 = 1.0
# field decay(t = 450.225): 1.2316055639675848e-10 / 1.2316055639675848e-10 = 1.0
# field decay(t = 500.25): 1.950165494060855e-10 / 1.950165494060855e-10 = 1.0
# on time step 21109 (time=527.725), 0.000772549 s/step
# field decay(t = 550.275): 3.067283830236344e-10 / 3.067283830236344e-10 = 1.0
# field decay(t = 600.3000000000001): 4.806779224712259e-10 / 4.806779224712259e-10 = 1.0
# field decay(t = 650.325): 7.478717673164084e-10 / 7.478717673164084e-10 = 1.0
# on time step 26497 (time=662.425), 0.000742496 s/step
# field decay(t = 700.35): 1.16125923658437e-09 / 1.16125923658437e-09 = 1.0
# field decay(t = 750.375): 1.799414139974168e-09 / 1.799414139974168e-09 = 1.0
# field decay(t = 800.4000000000001): 2.7627573686878063e-09 / 2.7627573686878063e-09 = 1.0
# on time step 32396 (time=809.9), 0.000678163 s/step
# field decay(t = 850.4250000000001): 4.2175595777923234e-09 / 4.2175595777923234e-09 = 1.0
# field decay(t = 900.45): 6.411612325833523e-09 / 6.411612325833523e-09 = 1.0
# field decay(t = 950.475): 9.698114919796252e-09 / 9.698114919796252e-09 = 1.0
# on time step 38263 (time=956.575), 0.000681882 s/step
# field decay(t = 1000.5): 1.4595918722036617e-08 / 1.4595918722036617e-08 = 1.0
# field decay(t = 1050.525): 2.1857350744330028e-08 / 2.1857350744330028e-08 = 1.0
# field decay(t = 1100.55): 3.2561953509731304e-08 / 3.2561953509731304e-08 = 1.0
# on time step 44112 (time=1102.8), 0.000683979 s/step
# field decay(t = 1150.575): 4.8269373467319734e-08 / 4.8269373467319734e-08 = 1.0
# field decay(t = 1200.6000000000001): 7.12010933012926e-08 / 7.12010933012926e-08 = 1.0
# on time step 49960 (time=1249), 0.000684034 s/step
# field decay(t = 1250.625): 1.0449956250865245e-07 / 1.0449956250865245e-07 = 1.0
# field decay(t = 1300.65): 1.5260920070676402e-07 / 1.5260920070676402e-07 = 1.0
# field decay(t = 1350.6750000000002): 2.2175631889274055e-07 / 2.2175631889274055e-07 = 1.0
# on time step 55563 (time=1389.08), 0.000713959 s/step
# field decay(t = 1400.7): 3.206180612901781e-07 / 3.206180612901781e-07 = 1.0
# field decay(t = 1450.7250000000001): 4.61257515622699e-07 / 4.61257515622699e-07 = 1.0
# field decay(t = 1500.75): 6.6026733698549e-07 / 6.6026733698549e-07 = 1.0
# on time step 60366 (time=1509.15), 0.000832942 s/step
# field decay(t = 1550.775): 9.404409189894241e-07 / 9.404409189894241e-07 = 1.0
# on time step 63885 (time=1597.12), 0.00113682 s/step
# field decay(t = 1600.8000000000002): 1.3328177429376354e-06 / 1.3328177429376354e-06 = 1.0
# field decay(t = 1650.825): 1.879502158180331e-06 / 1.879502158180331e-06 = 1.0
# on time step 66983 (time=1674.58), 0.00129152 s/step
# field decay(t = 1700.8500000000001): 2.6371694504216283e-06 / 2.6371694504216283e-06 = 1.0
# field decay(t = 1750.875): 3.6940366461093302e-06 / 3.6940366461093302e-06 = 1.0
# on time step 70043 (time=1751.08), 0.00130784 s/step
# field decay(t = 1800.9): 5.131359040342493e-06 / 5.131359040342493e-06 = 1.0
# on time step 73207 (time=1830.18), 0.00126447 s/step
# field decay(t = 1850.9250000000002): 7.092385576382565e-06 / 7.092385576382565e-06 = 1.0
# field decay(t = 1900.95): 9.753913815859354e-06 / 9.753913815859354e-06 = 1.0
# on time step 76523 (time=1913.08), 0.00120657 s/step
# field decay(t = 1950.9750000000001): 1.3347388764578041e-05 / 1.3347388764578041e-05 = 1.0
# field decay(t = 2001.0): 1.8173684932732703e-05 / 1.8173684932732703e-05 = 1.0
# on time step 80069 (time=2001.73), 0.00112819 s/step
# field decay(t = 2051.025): 2.462160857325152e-05 / 2.462160857325152e-05 = 1.0
# on time step 83896 (time=2097.4), 0.00104529 s/step
# field decay(t = 2101.05): 3.319091543682239e-05 / 3.319091543682239e-05 = 1.0
# field decay(t = 2151.0750000000003): 4.451939381961609e-05 / 4.451939381961609e-05 = 1.0
# on time step 87628 (time=2190.7), 0.00107215 s/step
# field decay(t = 2201.1): 5.9416856668033727e-05 / 5.9416856668033727e-05 = 1.0
# field decay(t = 2251.125): 7.890374727311387e-05 / 7.890374727311387e-05 = 1.0
# on time step 91302 (time=2282.55), 0.00108905 s/step
# field decay(t = 2301.15): 0.00010425930326425912 / 0.00010425930326425912 = 1.0
# field decay(t = 2351.175): 0.0001370754598746503 / 0.0001370754598746503 = 1.0
# on time step 94848 (time=2371.2), 0.0011284 s/step
# field decay(t = 2401.2000000000003): 0.00017932176434145325 / 0.00017932176434145325 = 1.0
# field decay(t = 2451.225): 0.00023341875139219528 / 0.00023341875139219528 = 1.0
# on time step 98351 (time=2458.78), 0.00114199 s/step
# field decay(t = 2501.25): 0.0003023198019911032 / 0.0003023198019911032 = 1.0
# on time step 101799 (time=2544.98), 0.00116023 s/step
# field decay(t = 2551.275): 0.0003896059910711984 / 0.0003896059910711984 = 1.0
# field decay(t = 2601.3): 0.0004995894496556733 / 0.0004995894496556733 = 1.0
# on time step 105028 (time=2625.7), 0.00123895 s/step
# field decay(t = 2651.3250000000003): 0.0006374261645741691 / 0.0006374261645741691 = 1.0
# field decay(t = 2701.3500000000004): 0.000809235559590783 / 0.000809235559590783 = 1.0
# on time step 108138 (time=2703.45), 0.00128632 s/step
# field decay(t = 2751.375): 0.001024594378314124 / 0.001024594378314124 = 1.0
# on time step 111092 (time=2777.3), 0.00135412 s/step
# field decay(t = 2801.4): 0.0012877517752461285 / 0.0012877517752461285 = 1.0
# on time step 113624 (time=2840.6), 0.00158004 s/step
# field decay(t = 2851.425): 0.0016104264768748826 / 0.0016104264768748826 = 1.0
# field decay(t = 2901.4500000000003): 0.0020039100899058543 / 0.0020039100899058543 = 1.0
# on time step 116210 (time=2905.25), 0.00154734 s/step
# field decay(t = 2951.4750000000004): 0.0024810989408117 / 0.0024810989408117 = 1.0
# on time step 118536 (time=2963.4), 0.00172015 s/step
# field decay(t = 3001.5): 0.003056598582164844 / 0.003056598582164844 = 1.0
# on time step 120766 (time=3019.15), 0.00179415 s/step
# field decay(t = 3051.525): 0.0037468060815431274 / 0.0037468060815431274 = 1.0
# on time step 122639 (time=3065.98), 0.00213611 s/step
# field decay(t = 3101.55): 0.0045699620404574615 / 0.0045699620404574615 = 1.0
# on time step 124422 (time=3110.55), 0.00224351 s/step
# on time step 125970 (time=3149.25), 0.00258487 s/step
# field decay(t = 3151.5750000000003): 0.005546161610203413 / 0.005546161610203413 = 1.0
# on time step 127318 (time=3182.95), 0.00296849 s/step
# field decay(t = 3201.6000000000004): 0.006697318207702428 / 0.006697318207702428 = 1.0
# on time step 128458 (time=3211.45), 0.00352715 s/step
# on time step 129359 (time=3233.98), 0.00444005 s/step
# field decay(t = 3251.625): 0.008047071749205303 / 0.008047071749205303 = 1.0
# on time step 130399 (time=3259.98), 0.00385207 s/step
# on time step 131553 (time=3288.83), 0.00346778 s/step
# field decay(t = 3301.65): 0.009620626485133994 / 0.009620626485133994 = 1.0
# on time step 132604 (time=3315.1), 0.00380661 s/step
# on time step 133713 (time=3342.83), 0.00360819 s/step
# field decay(t = 3351.675): 0.011444515003712831 / 0.011444515003712831 = 1.0
# on time step 134712 (time=3367.8), 0.00400652 s/step
# on time step 135506 (time=3387.65), 0.00505168 s/step
# field decay(t = 3401.7000000000003): 0.013546275983318113 / 0.013546275983318113 = 1.0
# on time step 136365 (time=3409.12), 0.00465956 s/step
# on time step 137235 (time=3430.88), 0.00459939 s/step
# on time step 137999 (time=3449.98), 0.00523725 s/step
# field decay(t = 3451.7250000000004): 0.015954051073005467 / 0.015954051073005467 = 1.0
# on time step 138532 (time=3463.3), 0.0075103 s/step
# on time step 139241 (time=3481.03), 0.00564356 s/step
# on time step 139881 (time=3497.03), 0.00625096 s/step
# field decay(t = 3501.75): 0.01869608162876517 / 0.01869608162876517 = 1.0
# on time step 140414 (time=3510.35), 0.00752122 s/step
# on time step 141182 (time=3529.55), 0.00522412 s/step
# on time step 142061 (time=3551.53), 0.00455142 s/step
# field decay(t = 3551.775): 0.021800110636420112 / 0.021800110636420112 = 1.0
# on time step 143126 (time=3578.15), 0.00376257 s/step
# field decay(t = 3601.8): 0.025292708583248908 / 0.025292708583248908 = 1.0
# on time step 144224 (time=3605.6), 0.00364323 s/step
# on time step 145376 (time=3634.4), 0.00352055 s/step
# field decay(t = 3651.8250000000003): 0.02919849828313861 / 0.02919849828313861 = 1.0
# on time step 146449 (time=3661.23), 0.00372958 s/step
# on time step 147747 (time=3693.68), 0.00308308 s/step
# field decay(t = 3701.8500000000004): 0.033539316750882384 / 0.033539316750882384 = 1.0
# on time step 149064 (time=3726.6), 0.00303878 s/step
# field decay(t = 3751.875): 0.03838359876024204 / 0.03838359876024204 = 1.0
# on time step 150247 (time=3756.18), 0.00338878 s/step
# on time step 151486 (time=3787.15), 0.00323769 s/step
# field decay(t = 3801.9): 0.043649042977055116 / 0.043649042977055116 = 1.0
# on time step 152483 (time=3812.08), 0.00401264 s/step
# on time step 153807 (time=3845.18), 0.00302464 s/step
# field decay(t = 3851.925): 0.04938923323697931 / 0.04938923323697931 = 1.0
# on time step 154812 (time=3870.3), 0.00398156 s/step
# on time step 155842 (time=3896.05), 0.00388431 s/step
# field decay(t = 3901.9500000000003): 0.055605580118983124 / 0.055605580118983124 = 1.0
# on time step 157025 (time=3925.62), 0.00338184 s/step
# field decay(t = 3951.9750000000004): 0.06229210226709229 / 0.06229210226709229 = 1.0
# on time step 158110 (time=3952.75), 0.00369061 s/step
# on time step 158740 (time=3968.5), 0.00635725 s/step
# on time step 159341 (time=3983.53), 0.00665671 s/step
# field decay(t = 4002.0): 0.06943463155497846 / 0.06943463155497846 = 1.0
# on time step 160531 (time=4013.28), 0.00336566 s/step
# on time step 161721 (time=4043.03), 0.00336791 s/step
# field decay(t = 4052.025): 0.07701011900715293 / 0.07701011900715293 = 1.0
# on time step 163291 (time=4082.28), 0.00254918 s/step
# field decay(t = 4102.05): 0.08498611770557302 / 0.08498611770557302 = 1.0
# on time step 164811 (time=4120.28), 0.00263274 s/step
# field decay(t = 4152.075): 0.09332042685564261 / 0.09332042685564261 = 1.0
# on time step 166350 (time=4158.75), 0.00260268 s/step
# on time step 167953 (time=4198.82), 0.00249578 s/step
# field decay(t = 4202.1): 0.1019609676576616 / 0.1019609676576616 = 1.0
# on time step 169627 (time=4240.68), 0.00239005 s/step
# field decay(t = 4252.125): 0.1108459206905703 / 0.1108459206905703 = 1.0
# on time step 170911 (time=4272.78), 0.00311655 s/step
# field decay(t = 4302.150000000001): 0.11990409295275045 / 0.11990409295275045 = 1.0
# on time step 172360 (time=4309), 0.00276459 s/step
# on time step 173008 (time=4325.2), 0.00617932 s/step
# on time step 173804 (time=4345.1), 0.00506678 s/step
# field decay(t = 4352.175): 0.12905559415599208 / 0.12905559415599208 = 1.0
# on time step 175004 (time=4375.1), 0.00333975 s/step
# field decay(t = 4402.2): 0.1382127719787578 / 0.1382127719787578 = 1.0
# on time step 176334 (time=4408.35), 0.00300835 s/step
# on time step 177624 (time=4440.6), 0.00310311 s/step
# field decay(t = 4452.225): 0.14728145029795117 / 0.14728145029795117 = 1.0
# on time step 178664 (time=4466.6), 0.0038507 s/step
# on time step 179795 (time=4494.88), 0.00353701 s/step
# field decay(t = 4502.25): 0.15616239188499476 / 0.15616239188499476 = 1.0
# on time step 180886 (time=4522.15), 0.00366732 s/step
# field decay(t = 4552.275000000001): 0.16475302001014988 / 0.16475302001014988 = 1.0
# on time step 182363 (time=4559.07), 0.00270967 s/step
# on time step 183534 (time=4588.35), 0.00341626 s/step
# field decay(t = 4602.3): 0.172949311595677 / 0.172949311595677 = 1.0
# on time step 184932 (time=4623.3), 0.00286496 s/step
# on time step 185844 (time=4646.1), 0.00438675 s/step
# field decay(t = 4652.325): 0.18064785818961854 / 0.18064785818961854 = 1.0
# on time step 187153 (time=4678.82), 0.00305751 s/step
# field decay(t = 4702.35): 0.187747999759456 / 0.187747999759456 = 1.0
# on time step 188596 (time=4714.9), 0.00277349 s/step
# on time step 190090 (time=4752.25), 0.0026778 s/step
# field decay(t = 4752.375): 0.19421424949288577 / 0.19421424949288577 = 1.0
# on time step 191698 (time=4792.45), 0.00248887 s/step
# field decay(t = 4802.400000000001): 0.1998291923521496 / 0.1998291923521496 = 1.0
# on time step 193305 (time=4832.62), 0.00248949 s/step
# field decay(t = 4852.425): 0.2045809996249147 / 0.2045809996249147 = 1.0
# on time step 194884 (time=4872.1), 0.0025401 s/step
# field decay(t = 4902.45): 0.20840119158769246 / 0.20840119158769246 = 1.0
# on time step 196408 (time=4910.2), 0.00262589 s/step
# on time step 198055 (time=4951.38), 0.00242916 s/step
# field decay(t = 4952.475): 0.2112339013565795 / 0.2112339013565795 = 1.0
# on time step 199726 (time=4993.15), 0.00239474 s/step
# field decay(t = 5002.5): 0.21303726148554916 / 0.21303726148554916 = 1.0
# on time step 201583 (time=5039.58), 0.00215419 s/step
# field decay(t = 5052.525000000001): 0.21378441430840836 / 0.21378441430840836 = 1.0
# on time step 203388 (time=5084.7), 0.00221645 s/step
# field decay(t = 5102.55): 0.21380583498515351 / 0.21380583498515351 = 1.0
# on time step 204846 (time=5121.15), 0.00274386 s/step
# field decay(t = 5152.575000000001): 0.21345560509960215 / 0.21380583498515351 = 0.9983619255032227
# on time step 206246 (time=5156.15), 0.00285739 s/step
# on time step 207534 (time=5188.35), 0.00310621 s/step
# field decay(t = 5202.6): 0.2120622532899472 / 0.21380583498515351 = 0.9918450228669982
# on time step 208824 (time=5220.6), 0.00310106 s/step
# field decay(t = 5252.625): 0.20962723573821734 / 0.21380583498515351 = 0.980456102859745
# on time step 210252 (time=5256.3), 0.00280127 s/step
# on time step 210999 (time=5274.98), 0.00535692 s/step
# field decay(t = 5302.650000000001): 0.2061866614549741 / 0.21380583498515351 = 0.9643640524090071
# on time step 212843 (time=5321.08), 0.00217022 s/step
# field decay(t = 5352.675): 0.20179107816199304 / 0.21380583498515351 = 0.9438052903280457
# on time step 214820 (time=5370.5), 0.00202373 s/step
# field decay(t = 5402.700000000001): 0.1965042189651015 / 0.21380583498515351 = 0.9190779053281992
# on time step 216452 (time=5411.3), 0.00245183 s/step
# on time step 218101 (time=5452.53), 0.00242723 s/step
# field decay(t = 5452.725): 0.19040148096501658 / 0.21380583498515351 = 0.8905345402675183
# on time step 219883 (time=5497.08), 0.00224557 s/step
# field decay(t = 5502.75): 0.18356813090331459 / 0.21380583498515351 = 0.858573999704271
# on time step 221590 (time=5539.75), 0.00234788 s/step
# field decay(t = 5552.775000000001): 0.17609733290751917 / 0.21380583498515351 = 0.8236320253829705
# on time step 223380 (time=5584.5), 0.00223537 s/step
# field decay(t = 5602.8): 0.16808803253846985 / 0.21380583498515351 = 0.7861713996259351
# on time step 225031 (time=5625.78), 0.00242376 s/step
# field decay(t = 5652.825000000001): 0.1596428025646696 / 0.21380583498515351 = 0.7466718697165353
# on time step 226708 (time=5667.7), 0.00238592 s/step
# field decay(t = 5702.85): 0.1508656682544237 / 0.21380583498515351 = 0.7056199764842699
# on time step 228575 (time=5714.38), 0.00214261 s/step
# field decay(t = 5752.875): 0.14186002050594365 / 0.21380583498515351 = 0.6634992937203715
# on time step 230239 (time=5755.98), 0.00240888 s/step
# on time step 231999 (time=5799.98), 0.00227286 s/step
# field decay(t = 5802.900000000001): 0.13263500401523678 / 0.21380583498515351 = 0.6203525924558927
# on time step 233554 (time=5838.85), 0.00257278 s/step
# field decay(t = 5852.925): 0.12347046594155733 / 0.21380583498515351 = 0.5774887572648848
# on time step 235338 (time=5883.45), 0.00224278 s/step
# field decay(t = 5902.950000000001): 0.11436589786595462 / 0.21380583498515351 = 0.534905410200316
# on time step 237257 (time=5931.43), 0.00208533 s/step
# field decay(t = 5952.975): 0.10540434997105058 / 0.21380583498515351 = 0.49299098866207164
# on time step 239224 (time=5980.6), 0.00203397 s/step
# field decay(t = 6003.0): 0.09666050341553269 / 0.21380583498515351 = 0.45209478694650546
# on time step 241134 (time=6028.35), 0.00209439 s/step
# field decay(t = 6053.025000000001): 0.08819990054015796 / 0.21380583498515351 = 0.4125233558115122
# on time step 242884 (time=6072.1), 0.00228639 s/step
# field decay(t = 6103.05): 0.08007844967898003 / 0.21380583498515351 = 0.37453818640890046
# on time step 244609 (time=6115.23), 0.00231899 s/step
# field decay(t = 6153.075000000001): 0.07234220575731401 / 0.21380583498515351 = 0.3383546841101759
# on time step 246449 (time=6161.23), 0.00217437 s/step
# field decay(t = 6203.1): 0.0650273966462447 / 0.21380583498515351 = 0.3041422917702884
# on time step 248334 (time=6208.35), 0.00212239 s/step
# field decay(t = 6253.125): 0.058160685590705724 / 0.21380583498515351 = 0.27202571714071483
# on time step 250151 (time=6253.78), 0.00220279 s/step
# on time step 252074 (time=6301.85), 0.00208058 s/step
# field decay(t = 6303.150000000001): 0.05175963389539196 / 0.21380583498515351 = 0.24208709691663047
# field decay(t = 6353.175): 0.045833326574782195 / 0.21380583498515351 = 0.21436892299017388
# on time step 254133 (time=6353.33), 0.0019434 s/step
# field decay(t = 6403.200000000001): 0.040383141741014775 / 0.21380583498515351 = 0.18887764098589238
# on time step 256173 (time=6404.33), 0.00196081 s/step
# field decay(t = 6453.225): 0.03540359427196814 / 0.21380583498515351 = 0.16558759621516658
# on time step 258266 (time=6456.65), 0.00191241 s/step
# field decay(t = 6503.25): 0.030883259881077173 / 0.21380583498515351 = 0.14444535568087596
# on time step 260245 (time=6506.12), 0.00203168 s/step
# field decay(t = 6553.275000000001): 0.026805717891288116 / 0.21380583498515351 = 0.1253741175639546
# on time step 262330 (time=6558.25), 0.0019186 s/step
# field decay(t = 6603.3): 0.023150493529018077 / 0.21380583498515351 = 0.108278118464941
# on time step 264322 (time=6608.05), 0.00200863 s/step
# field decay(t = 6653.325000000001): 0.019893976610591883 / 0.21380583498515351 = 0.09304693022981951
# on time step 266376 (time=6659.4), 0.00194795 s/step
# field decay(t = 6703.35): 0.017010280347593252 / 0.21380583498515351 = 0.07955947670359151
# on time step 268373 (time=6709.33), 0.00200387 s/step
# on time step 270057 (time=6751.43), 0.00237573 s/step
# field decay(t = 6753.375): 0.014472044454773661 / 0.21380583498515351 = 0.06768778997906483
# on time step 271695 (time=6792.38), 0.00244212 s/step
# field decay(t = 6803.400000000001): 0.012230447217400624 / 0.21380583498515351 = 0.057203524020987995
# on time step 273344 (time=6833.6), 0.00242684 s/step
# field decay(t = 6853.425): 0.010301395888399642 / 0.21380583498515351 = 0.04818107929147472
# on time step 275039 (time=6875.98), 0.00236063 s/step
# field decay(t = 6903.450000000001): 0.008633329695714254 / 0.21380583498515351 = 0.04037929879843431
# on time step 276898 (time=6922.45), 0.00215256 s/step
# field decay(t = 6953.475): 0.007199280822004827 / 0.21380583498515351 = 0.033672050262354807
# on time step 278783 (time=6969.58), 0.00212242 s/step
# field decay(t = 7003.5): 0.005973494229469508 / 0.21380583498515351 = 0.027938873744415355
# on time step 280614 (time=7015.35), 0.00218577 s/step
# field decay(t = 7053.525000000001): 0.00493169623362875 / 0.21380583498515351 = 0.02306623780389905
# on time step 282471 (time=7061.78), 0.00215412 s/step
# field decay(t = 7103.55): 0.004051284016684778 / 0.21380583498515351 = 0.018948425878863858
# on time step 284383 (time=7109.58), 0.00209249 s/step
# field decay(t = 7153.575000000001): 0.0033114452449406083 / 0.21380583498515351 = 0.015488095753656827
# on time step 286309 (time=7157.73), 0.00207714 s/step
# on time step 287850 (time=7196.25), 0.00259689 s/step
# field decay(t = 7203.6): 0.0026932149811238334 / 0.21380583498515351 = 0.012596545745867263
# on time step 289769 (time=7244.23), 0.00208478 s/step
# field decay(t = 7253.625): 0.00217948050142556 / 0.21380583498515351 = 0.0101937372362962
# on time step 291724 (time=7293.1), 0.00204609 s/step
# field decay(t = 7303.650000000001): 0.0017549446981742448 / 0.21380583498515351 = 0.008208123498108021
# on time step 293629 (time=7340.73), 0.00210044 s/step
# field decay(t = 7353.675): 0.0014060553951667676 / 0.21380583498515351 = 0.006576319094679539
# on time step 295725 (time=7393.12), 0.00190899 s/step
# field decay(t = 7403.700000000001): 0.0011209078739336067 / 0.21380583498515351 = 0.005242643981215206
# on time step 297699 (time=7442.48), 0.00202684 s/step
# field decay(t = 7453.725): 0.0008891315678725598 / 0.21380583498515351 = 0.0041585935572539465
# on time step 299661 (time=7491.53), 0.00204052 s/step
# field decay(t = 7503.75): 0.000701763258557925 / 0.21380583498515351 = 0.003282245587949715
# on time step 301745 (time=7543.62), 0.00192004 s/step
# field decay(t = 7553.775000000001): 0.000551116968106284 / 0.21380583498515351 = 0.002577651672343522
# on time step 303679 (time=7591.98), 0.00208763 s/step
# field decay(t = 7603.8): 0.00043065090497735367 / 0.21380583498515351 = 0.0020142149301362973
# on time step 305494 (time=7637.35), 0.0022039 s/step
# field decay(t = 7653.825000000001): 0.0003348386007261309 / 0.21380583498515351 = 0.0015660872901311687
# on time step 306906 (time=7672.65), 0.00283378 s/step
# on time step 308087 (time=7702.18), 0.00338871 s/step
# field decay(t = 7703.85): 0.00025904442297050475 / 0.21380583498515351 = 0.0012115872468517642
# on time step 309516 (time=7737.9), 0.00279938 s/step
# field decay(t = 7753.875): 0.00019940743436821032 / 0.21380583498515351 = 0.0009326566526215573
# on time step 310958 (time=7773.95), 0.00277403 s/step
# field decay(t = 7803.900000000001): 0.00015232393797656296 / 0.21380583498515351 = 0.000712440509339421
# on time step 312385 (time=7809.62), 0.00281811 s/step
# on time step 314030 (time=7850.75), 0.00243192 s/step
# field decay(t = 7853.925): 0.00011608348710064422 / 0.21380583498515351 = 0.000542938816935024
# on time step 315523 (time=7888.08), 0.00268725 s/step
# field decay(t = 7903.950000000001): 8.802412332982993e-05 / 0.21380583498515351 = 0.0004117012210445157
# on time step 316903 (time=7922.58), 0.00289955 s/step
# field decay(t = 7953.975): 6.641427083241334e-05 / 0.21380583498515351 = 0.00031062889764923903
# on time step 318541 (time=7963.53), 0.00245035 s/step
# on time step 320091 (time=8002.28), 0.00258489 s/step
# field decay(t = 8004.0): 4.985970035963884e-05 / 0.21380583498515351 = 0.000233200840206728
# on time step 321683 (time=8042.08), 0.00251297 s/step
# field decay(t = 8054.025000000001): 3.724484691812705e-05 / 0.21380583498515351 = 0.00017419939414054484
# on time step 323155 (time=8078.88), 0.00271774 s/step
# field decay(t = 8104.05): 2.7682889557202923e-05 / 0.21380583498515351 = 0.0001294767729754672
# on time step 324848 (time=8121.2), 0.00237068 s/step
# field decay(t = 8154.075000000001): 2.047317441923612e-05 / 0.21380583498515351 = 9.575591994791797e-05
# on time step 326471 (time=8161.78), 0.00246648 s/step
# on time step 327949 (time=8198.73), 0.00270671 s/step
# field decay(t = 8204.1): 1.5065628769227374e-05 / 0.21380583498515351 = 7.046406741085208e-05
# on time step 329503 (time=8237.58), 0.00257443 s/step
# field decay(t = 8254.125): 1.1031066262962136e-05 / 0.21380583498515351 = 5.1593850391071524e-05
# on time step 330906 (time=8272.65), 0.0028608 s/step
# field decay(t = 8304.15): 8.036689494750949e-06 / 0.21380583498515351 = 3.7588728555088356e-05
# on time step 332451 (time=8311.27), 0.00258911 s/step
# on time step 334026 (time=8350.65), 0.0025401 s/step
# field decay(t = 8354.175000000001): 5.825930624672148e-06 / 0.21380583498515351 = 2.724869798374163e-05
# on time step 335414 (time=8385.35), 0.00288642 s/step
# field decay(t = 8404.2): 4.202252076737818e-06 / 0.21380583498515351 = 1.965452475620985e-05
# on time step 336540 (time=8413.5), 0.00356613 s/step
# on time step 337711 (time=8442.77), 0.00342521 s/step
# field decay(t = 8454.225): 3.0159622313162697e-06 / 0.21380583498515351 = 1.4106080086755797e-05
# on time step 339258 (time=8481.45), 0.00258723 s/step
# field decay(t = 8504.25): 2.153769636129007e-06 / 0.21380583498515351 = 1.0073483898503344e-05
# on time step 341066 (time=8526.65), 0.00221311 s/step
# field decay(t = 8554.275): 1.5303849058293558e-06 / 0.21380583498515351 = 7.157825725081939e-06
# on time step 342398 (time=8559.95), 0.00300376 s/step
# on time step 343683 (time=8592.08), 0.00311628 s/step
# field decay(t = 8604.300000000001): 1.082011505790381e-06 / 0.21380583498515351 = 5.060720189725013e-06
# on time step 345024 (time=8625.6), 0.00305819 s/step
# on time step 346145 (time=8653.62), 0.00357104 s/step
# field decay(t = 8654.325): 7.611843043177406e-07 / 0.21380583498515351 = 3.5601661870949245e-06
# on time step 347452 (time=8686.3), 0.00310186 s/step
# field decay(t = 8704.35): 5.328167569610211e-07 / 0.21380583498515351 = 2.4920590076412995e-06
# on time step 348790 (time=8719.75), 0.00299055 s/step
# field decay(t = 8754.375): 3.711033254825927e-07 / 0.21380583498515351 = 1.7357025148932993e-06
# on time step 350201 (time=8755.02), 0.00283676 s/step
# on time step 351659 (time=8791.48), 0.00274686 s/step
# field decay(t = 8804.4): 2.562340313327593e-07 / 0.21380583498515351 = 1.1984426493811638e-06
# on time step 353045 (time=8826.12), 0.00288647 s/step
# field decay(t = 8854.425000000001): 1.766799807307634e-07 / 0.21380583498515351 = 8.263571513052107e-07
# on time step 354315 (time=8857.88), 0.00315021 s/step
# on time step 355388 (time=8884.7), 0.00372881 s/step
# field decay(t = 8904.45): 1.212171470827615e-07 / 0.21380583498515351 = 5.669496676326851e-07
# on time step 356691 (time=8917.27), 0.00307007 s/step
# on time step 357833 (time=8945.83), 0.0035031 s/step
# field decay(t = 8954.475): 8.274984328253975e-08 / 0.21380583498515351 = 3.8703267049884686e-07
# on time step 358817 (time=8970.43), 0.00406553 s/step
# on time step 360041 (time=9001.02), 0.00326863 s/step
# field decay(t = 9004.5): 5.621011009690712e-08 / 0.21380583498515351 = 2.6290260086124543e-07
# on time step 361379 (time=9034.48), 0.00298994 s/step
# field decay(t = 9054.525): 3.79906948506715e-08 / 0.21380583498515351 = 1.776878299570708e-07
# on time step 362706 (time=9067.65), 0.00301588 s/step
# on time step 364126 (time=9103.15), 0.00281819 s/step
# field decay(t = 9104.550000000001): 2.554891649484283e-08 / 0.21380583498515351 = 1.1949588044038613e-07
# on time step 365648 (time=9141.2), 0.00262864 s/step
# field decay(t = 9154.575): 1.7095898337815424e-08 / 0.21380583498515351 = 7.995992410124143e-08
# on time step 367117 (time=9177.93), 0.00272319 s/step
# field decay(t = 9204.6): 1.1382847032593893e-08 / 0.21380583498515351 = 5.323917859110023e-08
# on time step 368352 (time=9208.8), 0.00323928 s/step
# on time step 369621 (time=9240.52), 0.00315292 s/step
# field decay(t = 9254.625): 7.541080240056107e-09 / 0.21380583498515351 = 3.527069427539128e-08
# on time step 370997 (time=9274.93), 0.00290698 s/step
# on time step 372135 (time=9303.38), 0.00351946 s/step
# field decay(t = 9304.65): 4.970976547178879e-09 / 0.21380583498515351 = 2.3249957362127462e-08
# on time step 373426 (time=9335.65), 0.00310024 s/step
# field decay(t = 9354.675000000001): 3.2605630053586537e-09 / 0.21380583498515351 = 1.5250112353505528e-08
# on time step 374791 (time=9369.77), 0.00293222 s/step
# field decay(t = 9404.7): 2.1279549835759313e-09 / 0.21380583498515351 = 9.952745133095617e-09
# on time step 376356 (time=9408.9), 0.00255657 s/step
# on time step 377932 (time=9448.3), 0.00253907 s/step
# field decay(t = 9454.725): 1.3817446071130457e-09 / 0.21380583498515351 = 6.462614115321e-09
# on time step 379431 (time=9485.77), 0.00266962 s/step
# field decay(t = 9504.75): 8.927130400885355e-10 / 0.21380583498515351 = 4.1753446071784e-09
# on time step 380923 (time=9523.08), 0.00268294 s/step
# field decay(t = 9554.775): 5.739373534360461e-10 / 0.21380583498515351 = 2.684385828272179e-09
# on time step 382533 (time=9563.33), 0.0024888 s/step
# on time step 384066 (time=9601.65), 0.0026096 s/step
# field decay(t = 9604.800000000001): 3.6717471286214075e-10 / 0.21380583498515351 = 1.7173278404101414e-09
# on time step 385634 (time=9640.85), 0.00255197 s/step
# field decay(t = 9654.825): 2.3371168038415607e-10 / 0.21380583498515351 = 1.0931024422246698e-09
# on time step 387242 (time=9681.05), 0.00248767 s/step
# field decay(t = 9704.85): 1.4799005802900816e-10 / 0.21380583498515351 = 6.921703424945556e-10
# on time step 388789 (time=9719.73), 0.00258568 s/step
# field decay(t = 9754.875): 9.325691068718123e-11 / 0.21380583498515351 = 4.361757044360221e-10
# on time step 390235 (time=9755.88), 0.00276634 s/step
# on time step 391742 (time=9793.55), 0.00265533 s/step
# field decay(t = 9804.9): 5.824273504727479e-11 / 0.21380583498515351 = 2.7240947400392093e-10
# on time step 393180 (time=9829.5), 0.00278275 s/step
# field decay(t = 9854.925000000001): 3.631969772070851e-11 / 0.21380583498515351 = 1.6987234105762603e-10
# on time step 394718 (time=9867.95), 0.0026008 s/step
# field decay(t = 9904.95): 2.255231304983549e-11 / 0.21380583498515351 = 1.0548034412344967e-10
# on time step 396255 (time=9906.38), 0.00260249 s/step
# on time step 397734 (time=9943.35), 0.002705 s/step
# field decay(t = 9954.975): 1.3939170356236095e-11 / 0.21380583498515351 = 6.519546277679475e-11
# on time step 399360 (time=9984), 0.0024603 s/step
# field decay(t = 10005.0): 8.563864560536911e-12 / 0.21380583498515351 = 4.005440057859777e-11
# run 0 finished at t = 10005.0 (400200 timesteps)

# %%
# Main simulation with holes
geometry_holes = [mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)]

hole_positions = generate_waveguide(N, t_1, t_2, r)
for x_position in hole_positions:
    geometry_holes.append(mp.Cylinder(r, height=mp.inf, center=mp.Vector3(x_position, 0, 0), material=mp.air))

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry_holes,  # Geometry with holes
                    sources=sources,
                    resolution=resolution)



# Add flux monitors
refl = sim.add_flux(fcen, df, nfreq, refl_fr)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()

# Load the saved flux data for normalization
sim.load_minus_flux_data(refl, norm_refl_data)

# Run simulation with holes
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Get the reflected and transmitted flux
reflected_flux = mp.get_fluxes(refl)
transmitted_flux = mp.get_fluxes(tran)

# Normalize the transmission and reflection
transmission = np.array(transmitted_flux) / norm_incident_flux
reflection = np.array(reflected_flux) / norm_incident_flux
freqs = np.linspace(fcen - df/2, fcen + df/2, nfreq)

# Plot the transmission and reflection
plt.figure(figsize=(10, 6))
plt.plot(freqs, transmission, label="Transmission")
plt.plot(freqs, reflection, label="Reflection")
plt.xlabel("Frequency (1/μm)")
plt.ylabel("Normalized Flux")
plt.legend()
plt.title("Transmission and Reflection Spectra")
plt.grid(True)
plt.show()
# Out:
#      block
# , center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-18.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-16.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-13.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-11.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-8.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-6.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-3.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 7 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000854969 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-18.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-16.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-13.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-11.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-8.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-6.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-3.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 7 objects not shown)...
# time for set_epsilon = 1.4094 s
# -----------
# on time step 1477 (time=36.925), 0.0027083 s/step
# field decay(t = 50.025000000000006): 1.6622515449526914e-16 / 1.6622515449526914e-16 = 1.0
# on time step 2596 (time=64.9), 0.00357594 s/step
# field decay(t = 100.05000000000001): 4.561531618998004e-13 / 4.561531618998004e-13 = 1.0
# on time step 4058 (time=101.45), 0.00273682 s/step
# on time step 5618 (time=140.45), 0.00256735 s/step
# field decay(t = 150.07500000000002): 5.881011887783e-13 / 5.881011887783e-13 = 1.0
# on time step 7226 (time=180.65), 0.00248808 s/step
# field decay(t = 200.10000000000002): 9.295669303711072e-13 / 9.295669303711072e-13 = 1.0
# on time step 8850 (time=221.25), 0.0024666 s/step
# field decay(t = 250.125): 1.5027919895319739e-12 / 1.5027919895319739e-12 = 1.0
# on time step 10472 (time=261.8), 0.00246656 s/step
# on time step 11739 (time=293.475), 0.00316378 s/step
# field decay(t = 300.15000000000003): 2.4174839704737798e-12 / 2.4174839704737798e-12 = 1.0
# on time step 13174 (time=329.35), 0.00278758 s/step
# field decay(t = 350.175): 3.888145811695417e-12 / 3.888145811695417e-12 = 1.0
# on time step 14524 (time=363.1), 0.00296413 s/step
# on time step 15959 (time=398.975), 0.00278756 s/step
# field decay(t = 400.20000000000005): 6.201914256491407e-12 / 6.201914256491407e-12 = 1.0
# on time step 17453 (time=436.325), 0.00267759 s/step
# field decay(t = 450.225): 9.861212056908492e-12 / 9.861212056908492e-12 = 1.0
# on time step 18838 (time=470.95), 0.00288876 s/step
# field decay(t = 500.25): 1.5596123131466985e-11 / 1.5596123131466985e-11 = 1.0
# on time step 20169 (time=504.225), 0.00300574 s/step
# on time step 21557 (time=538.925), 0.00288271 s/step
# field decay(t = 550.275): 2.4534600875941444e-11 / 2.4534600875941444e-11 = 1.0
# on time step 22835 (time=570.875), 0.00313123 s/step
# field decay(t = 600.3000000000001): 3.840263996401012e-11 / 3.840263996401012e-11 = 1.0
# on time step 24312 (time=607.8), 0.00270869 s/step
# on time step 25894 (time=647.35), 0.00252876 s/step
# field decay(t = 650.325): 5.983087022825741e-11 / 5.983087022825741e-11 = 1.0
# on time step 27446 (time=686.15), 0.00257847 s/step
# field decay(t = 700.35): 9.274893205240576e-11 / 9.274893205240576e-11 = 1.0
# on time step 28996 (time=724.9), 0.00258122 s/step
# field decay(t = 750.375): 1.4303664550406114e-10 / 1.4303664550406114e-10 = 1.0
# on time step 30196 (time=754.9), 0.00333437 s/step
# on time step 31610 (time=790.25), 0.00282954 s/step
# field decay(t = 800.4000000000001): 2.194769329114438e-10 / 2.194769329114438e-10 = 1.0
# on time step 33141 (time=828.525), 0.00261427 s/step
# field decay(t = 850.4250000000001): 3.3509559169432006e-10 / 3.3509559169432006e-10 = 1.0
# on time step 34536 (time=863.4), 0.00288133 s/step
# on time step 35901 (time=897.525), 0.00293102 s/step
# field decay(t = 900.45): 5.09082539585514e-10 / 5.09082539585514e-10 = 1.0
# on time step 37191 (time=929.775), 0.00310114 s/step
# field decay(t = 950.475): 7.69577933160896e-10 / 7.69577933160896e-10 = 1.0
# on time step 38664 (time=966.6), 0.00271577 s/step
# field decay(t = 1000.5): 1.1575563455429207e-09 / 1.1575563455429207e-09 = 1.0
# on time step 40020 (time=1000.5), 0.00296064 s/step
# on time step 41273 (time=1031.83), 0.00319252 s/step
# field decay(t = 1050.525): 1.7324088699923837e-09 / 1.7324088699923837e-09 = 1.0
# on time step 42548 (time=1063.7), 0.00313789 s/step
# on time step 43945 (time=1098.62), 0.00286495 s/step
# field decay(t = 1100.55): 2.579788436870151e-09 / 2.579788436870151e-09 = 1.0
# on time step 45209 (time=1130.23), 0.0031655 s/step
# field decay(t = 1150.575): 3.837497661000562e-09 / 3.837497661000562e-09 = 1.0
# on time step 46431 (time=1160.78), 0.00327537 s/step
# on time step 47703 (time=1192.58), 0.00314742 s/step
# field decay(t = 1200.6000000000001): 5.657456361658804e-09 / 5.657456361658804e-09 = 1.0
# on time step 48907 (time=1222.67), 0.00333465 s/step
# field decay(t = 1250.625): 8.298889130845947e-09 / 8.298889130845947e-09 = 1.0
# on time step 50135 (time=1253.38), 0.0032575 s/step
# on time step 51484 (time=1287.1), 0.00296555 s/step
# field decay(t = 1300.65): 1.2112872896408226e-08 / 1.2112872896408226e-08 = 1.0
# on time step 52723 (time=1318.08), 0.00322855 s/step
# on time step 54016 (time=1350.4), 0.00309363 s/step
# field decay(t = 1350.6750000000002): 1.7591482053343028e-08 / 1.7591482053343028e-08 = 1.0
# on time step 55344 (time=1383.6), 0.00301599 s/step
# field decay(t = 1400.7): 2.5420641995446465e-08 / 2.5420641995446465e-08 = 1.0
# on time step 56745 (time=1418.62), 0.00285655 s/step
# field decay(t = 1450.7250000000001): 3.6550875144090565e-08 / 3.6550875144090565e-08 = 1.0
# on time step 58145 (time=1453.62), 0.00286385 s/step
# on time step 59604 (time=1490.1), 0.00274251 s/step
# field decay(t = 1500.75): 5.229225627770156e-08 / 5.229225627770156e-08 = 1.0
# on time step 61064 (time=1526.6), 0.00273983 s/step
# field decay(t = 1550.775): 7.443977723260071e-08 / 7.443977723260071e-08 = 1.0
# on time step 62528 (time=1563.2), 0.00278474 s/step
# on time step 63825 (time=1595.62), 0.00308413 s/step
# field decay(t = 1600.8000000000002): 1.0543896244240511e-07 / 1.0543896244240511e-07 = 1.0
# on time step 65306 (time=1632.65), 0.00270105 s/step
# field decay(t = 1650.825): 1.4860192184529518e-07 / 1.4860192184529518e-07 = 1.0
# on time step 66941 (time=1673.53), 0.00244653 s/step
# field decay(t = 1700.8500000000001): 2.083895414804995e-07 / 2.083895414804995e-07 = 1.0
# on time step 68317 (time=1707.93), 0.00290966 s/step
# on time step 69779 (time=1744.48), 0.00273799 s/step
# field decay(t = 1750.875): 2.907736921646755e-07 / 2.907736921646755e-07 = 1.0
# on time step 71079 (time=1776.98), 0.00307712 s/step
# field decay(t = 1800.9): 4.037034922899879e-07 / 4.037034922899879e-07 = 1.0
# on time step 72503 (time=1812.58), 0.00281084 s/step
# on time step 74034 (time=1850.85), 0.00261539 s/step
# field decay(t = 1850.9250000000002): 5.57696345593463e-07 / 5.57696345593463e-07 = 1.0
# on time step 75379 (time=1884.48), 0.00298277 s/step
# field decay(t = 1900.95): 7.665863555218586e-07 / 7.665863555218586e-07 = 1.0
# on time step 76855 (time=1921.38), 0.00271164 s/step
# field decay(t = 1950.9750000000001): 1.0484609380248483e-06 / 1.0484609380248483e-06 = 1.0
# on time step 78326 (time=1958.15), 0.00272075 s/step
# on time step 79758 (time=1993.95), 0.00279437 s/step
# field decay(t = 2001.0): 1.4268273408144642e-06 / 1.4268273408144642e-06 = 1.0
# on time step 81022 (time=2025.55), 0.00316642 s/step
# field decay(t = 2051.025): 1.9320503401216906e-06 / 1.9320503401216906e-06 = 1.0
# on time step 82409 (time=2060.22), 0.00288398 s/step
# on time step 83831 (time=2095.78), 0.00281432 s/step
# field decay(t = 2101.05): 2.603115290924666e-06 / 2.603115290924666e-06 = 1.0
# on time step 85118 (time=2127.95), 0.00311018 s/step
# field decay(t = 2151.0750000000003): 3.499922070625482e-06 / 3.499922070625482e-06 = 1.0
# on time step 86551 (time=2163.78), 0.00280465 s/step
# on time step 88030 (time=2200.75), 0.00270515 s/step
# field decay(t = 2201.1): 4.668393684750062e-06 / 4.668393684750062e-06 = 1.0
# on time step 89537 (time=2238.43), 0.0026543 s/step
# field decay(t = 2251.125): 6.195901368442098e-06 / 6.195901368442098e-06 = 1.0
# on time step 90972 (time=2274.3), 0.00278912 s/step
# field decay(t = 2301.15): 8.182188048391824e-06 / 8.182188048391824e-06 = 1.0
# on time step 92307 (time=2307.68), 0.00299997 s/step
# on time step 93806 (time=2345.15), 0.0026699 s/step
# field decay(t = 2351.175): 1.0751333635770823e-05 / 1.0751333635770823e-05 = 1.0
# on time step 95490 (time=2387.25), 0.00237583 s/step
# field decay(t = 2401.2000000000003): 1.405669235233482e-05 / 1.405669235233482e-05 = 1.0
# on time step 97101 (time=2427.53), 0.00248309 s/step
# field decay(t = 2451.225): 1.8286553127598368e-05 / 1.8286553127598368e-05 = 1.0
# on time step 98643 (time=2466.08), 0.00260394 s/step
# field decay(t = 2501.25): 2.3670556429620128e-05 / 2.3670556429620128e-05 = 1.0
# on time step 100322 (time=2508.05), 0.00238316 s/step
# on time step 101934 (time=2548.35), 0.00248157 s/step
# field decay(t = 2551.275): 3.0486880372190813e-05 / 3.0486880372190813e-05 = 1.0
# on time step 103721 (time=2593.03), 0.00223927 s/step
# field decay(t = 2601.3): 3.907018003822666e-05 / 3.907018003822666e-05 = 1.0
# on time step 105507 (time=2637.68), 0.00224091 s/step
# field decay(t = 2651.3250000000003): 4.98202321379075e-05 / 4.98202321379075e-05 = 1.0
# on time step 107335 (time=2683.38), 0.00219012 s/step
# field decay(t = 2701.3500000000004): 6.321119310324437e-05 / 6.321119310324437e-05 = 1.0
# on time step 109053 (time=2726.33), 0.00233337 s/step
# field decay(t = 2751.375): 7.98013288007449e-05 / 7.98013288007449e-05 = 1.0
# on time step 110783 (time=2769.58), 0.00231266 s/step
# field decay(t = 2801.4): 0.00010024302237605572 / 0.00010024302237605572 = 1.0
# on time step 112534 (time=2813.35), 0.00228526 s/step
# field decay(t = 2851.425): 0.00012529278737436421 / 0.00012529278737436421 = 1.0
# on time step 114355 (time=2858.88), 0.00219732 s/step
# field decay(t = 2901.4500000000003): 0.00015582096196008172 / 0.00015582096196008172 = 1.0
# on time step 116150 (time=2903.75), 0.00222861 s/step
# on time step 117797 (time=2944.93), 0.00243317 s/step
# field decay(t = 2951.4750000000004): 0.00019282066673540003 / 0.00019282066673540003 = 1.0
# on time step 119432 (time=2985.8), 0.00244691 s/step
# field decay(t = 3001.5): 0.0002374155531842156 / 0.0002374155531842156 = 1.0
# on time step 121138 (time=3028.45), 0.002345 s/step
# field decay(t = 3051.525): 0.0002908657820616847 / 0.0002908657820616847 = 1.0
# on time step 122680 (time=3067), 0.00259566 s/step
# on time step 123346 (time=3083.65), 0.00604504 s/step
# on time step 123952 (time=3098.8), 0.00660568 s/step
# field decay(t = 3101.55): 0.0003545716269142441 / 0.0003545716269142441 = 1.0
# on time step 124741 (time=3118.53), 0.00507295 s/step
# on time step 125484 (time=3137.1), 0.00538666 s/step
# field decay(t = 3151.5750000000003): 0.0004308941769968255 / 0.0004308941769968255 = 1.0
# on time step 126103 (time=3152.58), 0.00646414 s/step
# on time step 126665 (time=3166.62), 0.00714532 s/step
# on time step 127580 (time=3189.5), 0.00437519 s/step
# field decay(t = 3201.6000000000004): 0.0005200151538883752 / 0.0005200151538883752 = 1.0
# on time step 128951 (time=3223.78), 0.00294433 s/step
# on time step 130058 (time=3251.45), 0.00361578 s/step
# field decay(t = 3251.625): 0.000624437887857842 / 0.000624437887857842 = 1.0
# on time step 131409 (time=3285.23), 0.00296094 s/step
# field decay(t = 3301.65): 0.0007460885251554216 / 0.0007460885251554216 = 1.0
# on time step 132761 (time=3319.03), 0.00296023 s/step
# on time step 134013 (time=3350.33), 0.00319616 s/step
# field decay(t = 3351.675): 0.0008869912614335534 / 0.0008869912614335534 = 1.0
# on time step 135256 (time=3381.4), 0.00321901 s/step
# field decay(t = 3401.7000000000003): 0.0010492432521062996 / 0.0010492432521062996 = 1.0
# on time step 136457 (time=3411.43), 0.0033314 s/step
# on time step 137572 (time=3439.3), 0.00358841 s/step
# field decay(t = 3451.7250000000004): 0.0012349827413446614 / 0.0012349827413446614 = 1.0
# on time step 138776 (time=3469.4), 0.00332418 s/step
# on time step 140017 (time=3500.43), 0.00322495 s/step
# field decay(t = 3501.75): 0.0014463501642969932 / 0.0014463501642969932 = 1.0
# on time step 140964 (time=3524.1), 0.00422874 s/step
# field decay(t = 3551.775): 0.0016854422040065663 / 0.0016854422040065663 = 1.0
# on time step 142114 (time=3552.85), 0.00347975 s/step
# on time step 143413 (time=3585.33), 0.00308003 s/step
# field decay(t = 3601.8): 0.0019542590473255483 / 0.0019542590473255483 = 1.0
# on time step 144685 (time=3617.12), 0.00315259 s/step
# field decay(t = 3651.8250000000003): 0.002254645396629932 / 0.002254645396629932 = 1.0
# on time step 146134 (time=3653.35), 0.00276098 s/step
# on time step 147521 (time=3688.03), 0.00288554 s/step
# field decay(t = 3701.8500000000004): 0.0025882260773714325 / 0.0025882260773714325 = 1.0
# on time step 148631 (time=3715.78), 0.00360863 s/step
# on time step 149824 (time=3745.6), 0.00335382 s/step
# field decay(t = 3751.875): 0.0029563375056198713 / 0.0029563375056198713 = 1.0
# on time step 150976 (time=3774.4), 0.00347437 s/step
# field decay(t = 3801.9): 0.003359956521139051 / 0.003359956521139051 = 1.0
# on time step 152265 (time=3806.62), 0.0031047 s/step
# on time step 153515 (time=3837.88), 0.00320138 s/step
# field decay(t = 3851.925): 0.003799628525838103 / 0.003799628525838103 = 1.0
# on time step 154721 (time=3868.03), 0.00331858 s/step
# on time step 155954 (time=3898.85), 0.00325359 s/step
# field decay(t = 3901.9500000000003): 0.004275397072129618 / 0.004275397072129618 = 1.0
# on time step 157261 (time=3931.53), 0.0030621 s/step
# field decay(t = 3951.9750000000004): 0.0047867374030281405 / 0.0047867374030281405 = 1.0
# on time step 158424 (time=3960.6), 0.00344148 s/step
# on time step 159685 (time=3992.12), 0.00317298 s/step
# field decay(t = 4002.0): 0.005332496498975829 / 0.005332496498975829 = 1.0
# on time step 160892 (time=4022.3), 0.00331507 s/step
# on time step 162069 (time=4051.73), 0.00339911 s/step
# field decay(t = 4052.025): 0.0059108424054718535 / 0.0059108424054718535 = 1.0
# on time step 163369 (time=4084.23), 0.00307855 s/step
# field decay(t = 4102.05): 0.006519225509663176 / 0.006519225509663176 = 1.0
# on time step 164596 (time=4114.9), 0.00326307 s/step
# on time step 165664 (time=4141.6), 0.00374599 s/step
# field decay(t = 4152.075): 0.007160827675109331 / 0.007160827675109331 = 1.0
# on time step 167072 (time=4176.8), 0.00284121 s/step
# field decay(t = 4202.1): 0.007818865824778304 / 0.007818865824778304 = 1.0
# on time step 168626 (time=4215.65), 0.00257407 s/step
# field decay(t = 4252.125): 0.008494779534809368 / 0.008494779534809368 = 1.0
# on time step 170125 (time=4253.12), 0.00267122 s/step
# on time step 171632 (time=4290.8), 0.00265611 s/step
# field decay(t = 4302.150000000001): 0.009183078021936358 / 0.009183078021936358 = 1.0
# on time step 173084 (time=4327.1), 0.00275519 s/step
# field decay(t = 4352.175): 0.009877618383011226 / 0.009877618383011226 = 1.0
# on time step 174483 (time=4362.07), 0.00285928 s/step
# on time step 175914 (time=4397.85), 0.00279544 s/step
# field decay(t = 4402.2): 0.010571680201041045 / 0.010571680201041045 = 1.0
# on time step 177415 (time=4435.38), 0.00267549 s/step
# field decay(t = 4452.225): 0.011258060859446944 / 0.011258060859446944 = 1.0
# on time step 178906 (time=4472.65), 0.00268321 s/step
# field decay(t = 4502.25): 0.011929190258307902 / 0.011929190258307902 = 1.0
# on time step 180154 (time=4503.85), 0.00320728 s/step
# on time step 181457 (time=4536.43), 0.00307175 s/step
# field decay(t = 4552.275000000001): 0.012577262734399124 / 0.012577262734399124 = 1.0
# on time step 182518 (time=4562.95), 0.00377417 s/step
# on time step 183619 (time=4590.48), 0.00363597 s/step
# field decay(t = 4602.3): 0.013194383216257554 / 0.013194383216257554 = 1.0
# on time step 184699 (time=4617.48), 0.00370711 s/step
# on time step 185809 (time=4645.23), 0.00360444 s/step
# field decay(t = 4652.325): 0.013772723939186046 / 0.013772723939186046 = 1.0
# on time step 186968 (time=4674.2), 0.00345214 s/step
# field decay(t = 4702.35): 0.014304687585842529 / 0.014304687585842529 = 1.0
# on time step 188174 (time=4704.35), 0.00331768 s/step
# on time step 189151 (time=4728.78), 0.00409462 s/step
# field decay(t = 4752.375): 0.014783072083868108 / 0.014783072083868108 = 1.0
# on time step 190230 (time=4755.75), 0.0037088 s/step
# on time step 191588 (time=4789.7), 0.0029557 s/step
# field decay(t = 4802.400000000001): 0.015201232142829217 / 0.015201232142829217 = 1.0
# on time step 193063 (time=4826.57), 0.0027128 s/step
# field decay(t = 4852.425): 0.01555323249790472 / 0.01555323249790472 = 1.0
# on time step 195848 (time=4896.2), 0.0014363 s/step
# field decay(t = 4902.45): 0.015833987943731184 / 0.015833987943731184 = 1.0
# field decay(t = 4952.475): 0.01603938549909027 / 0.01603938549909027 = 1.0
# on time step 198587 (time=4964.68), 0.00146045 s/step
# field decay(t = 5002.5): 0.016166384647089704 / 0.016166384647089704 = 1.0
# field decay(t = 5052.525000000001): 0.016213092229077186 / 0.016213092229077186 = 1.0
# on time step 202753 (time=5068.83), 0.000960245 s/step
# field decay(t = 5102.55): 0.016213330964580115 / 0.016213330964580115 = 1.0
# field decay(t = 5152.575000000001): 0.01617805829894825 / 0.016213330964580115 = 0.9978244652065068
# field decay(t = 5202.6): 0.016060942728163302 / 0.016213330964580115 = 0.9906010531241407
# on time step 208273 (time=5206.83), 0.000724707 s/step
# field decay(t = 5252.625): 0.015865866817259724 / 0.016213330964580115 = 0.978569231203664
# field decay(t = 5302.650000000001): 0.015594962161211659 / 0.016213330964580115 = 0.9618604711937754
# on time step 213387 (time=5334.68), 0.000782238 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 28
#      25 sim.load_minus_flux_data(refl, norm_refl_data)
#      27 # Run simulation with holes
# ---> 28 sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))
#      30 eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
#      31 ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:4530, in Simulation.run(self, *step_funcs, **kwargs)
#    4527     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4529 if until_after_sources is not None:
# -> 4530     self._run_sources_until(until_after_sources, step_funcs)
#    4531 elif until is not None:
#    4532     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2871, in Simulation._run_sources_until(self, cond, step_funcs)
#    2867             return cond[i](sim) and sim.round_time() >= ts
#    2869         new_conds.append(f)
# -> 2871 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2829, in Simulation._run_until(self, cond, step_funcs)
#    2827     for func in step_funcs:
#    2828         _eval_step_func(self, func, "step")
# -> 2829     self.fields.step()
#    2831 # Translating the recursive scheme version of run-until into an iterative version
#    2832 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2833 # be the same as scheme.
#    2834 for func in step_funcs:
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/__init__.py:3040, in fields.step(self)
#    3039 def step(self):
# -> 3040     return _meep.fields_step(self)
#
# KeyboardInterrupt:

# %%
# Source
sources = [mp.Source(mp.GaussianSource(wavelength=wl, fwidth=df),
                     component=mp.Ey,
                     center=mp.Vector3(-0.5 * sx + dpml),
                     size=mp.Vector3(0, w, 0))]

# Normalization run simulation
norm_sim = mp.Simulation(cell_size=cell,
                         boundary_layers=pml_layers,
                         geometry=[mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)],  # No holes for normalization
                         sources=sources,
                         resolution=resolution)



# Flux monitors
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5 * sx + dpml + 0.5), size=mp.Vector3(0, 2*w, 0))
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5 * sx - dpml - 0.5), size=mp.Vector3(0, 2*w, 0))


# Add flux monitors
norm_refl = norm_sim.add_flux(fcen, df, nfreq, refl_fr)
norm_tran = norm_sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
norm_sim.plot2D()
plt.show()

# Run normalization simulation
norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ey)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Save flux for normalization
norm_refl_data = norm_sim.get_flux_data(norm_refl)
norm_tran_data = norm_sim.get_flux_data(norm_tran)

# Calculate the incident power for normalization
norm_refl_flux = mp.get_fluxes(norm_refl)
norm_tran_flux = mp.get_fluxes(norm_tran)
norm_incident_flux = np.array(norm_refl_flux) + np.array(norm_tran_flux)

# Reset simulation for main run with holes
norm_sim.reset_meep()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000449181 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# time for set_epsilon = 0.5567 s
# -----------
# on time step 2175 (time=54.375), 0.00183932 s/step
# on time step 4420 (time=110.5), 0.00178232 s/step
# on time step 6708 (time=167.7), 0.00174827 s/step
# on time step 8997 (time=224.925), 0.00174759 s/step
# on time step 11212 (time=280.3), 0.00180608 s/step
# on time step 13447 (time=336.175), 0.00179021 s/step
# on time step 15344 (time=383.6), 0.00212212 s/step
# on time step 17229 (time=430.725), 0.00212213 s/step
# on time step 19041 (time=476.025), 0.00220826 s/step
# on time step 20913 (time=522.825), 0.0021372 s/step
# on time step 23007 (time=575.175), 0.00191079 s/step
# on time step 25177 (time=629.425), 0.00184366 s/step
# on time step 27250 (time=681.25), 0.00193 s/step
# on time step 29399 (time=734.975), 0.00186179 s/step
# on time step 31521 (time=788.025), 0.00188523 s/step
# on time step 33626 (time=840.65), 0.00190046 s/step
# on time step 35793 (time=894.825), 0.00184601 s/step
# on time step 38006 (time=950.15), 0.00180781 s/step
# on time step 40203 (time=1005.08), 0.00182122 s/step
# on time step 42329 (time=1058.23), 0.00188199 s/step
# on time step 43766 (time=1094.15), 0.00280327 s/step
# on time step 45540 (time=1138.5), 0.00225505 s/step
# on time step 47074 (time=1176.85), 0.00263413 s/step
# on time step 48761 (time=1219.03), 0.00237118 s/step
# on time step 50522 (time=1263.05), 0.00227238 s/step
# on time step 52433 (time=1310.83), 0.00209328 s/step
# on time step 54307 (time=1357.68), 0.00213536 s/step
# on time step 55923 (time=1398.08), 0.00247534 s/step
# on time step 57663 (time=1441.58), 0.00229934 s/step
# on time step 59446 (time=1486.15), 0.00224367 s/step
# on time step 61309 (time=1532.73), 0.00214723 s/step
# on time step 63195 (time=1579.88), 0.00212204 s/step
# on time step 65001 (time=1625.03), 0.00221743 s/step
# on time step 66764 (time=1669.1), 0.00226951 s/step
# on time step 68516 (time=1712.9), 0.00228406 s/step
# on time step 70389 (time=1759.73), 0.00213614 s/step
# on time step 72142 (time=1803.55), 0.00228225 s/step
# on time step 74159 (time=1853.98), 0.0019836 s/step
# on time step 76260 (time=1906.5), 0.00190392 s/step
# on time step 78373 (time=1959.33), 0.00189344 s/step
# on time step 80379 (time=2009.48), 0.00199406 s/step
# on time step 82422 (time=2060.55), 0.00195865 s/step
# on time step 84475 (time=2111.88), 0.00194897 s/step
# on time step 86562 (time=2164.05), 0.00191681 s/step
# on time step 88665 (time=2216.62), 0.00190222 s/step
# on time step 90840 (time=2271), 0.00183991 s/step
# on time step 93052 (time=2326.3), 0.00180845 s/step
# on time step 95271 (time=2381.78), 0.00180307 s/step
# on time step 97513 (time=2437.83), 0.00178461 s/step
# on time step 99738 (time=2493.45), 0.00179787 s/step
# on time step 101983 (time=2549.58), 0.00178181 s/step
# on time step 104065 (time=2601.62), 0.00192151 s/step
# on time step 106167 (time=2654.18), 0.00190305 s/step
# on time step 108340 (time=2708.5), 0.00184129 s/step
# on time step 110439 (time=2760.98), 0.0019065 s/step
# on time step 112646 (time=2816.15), 0.00181349 s/step
# on time step 114822 (time=2870.55), 0.0018388 s/step
# on time step 116936 (time=2923.4), 0.00189279 s/step
# on time step 119017 (time=2975.43), 0.00192256 s/step
# on time step 120974 (time=3024.35), 0.00204395 s/step
# on time step 122999 (time=3074.98), 0.00197615 s/step
# on time step 125112 (time=3127.8), 0.00189317 s/step
# on time step 127224 (time=3180.6), 0.00189448 s/step
# on time step 129308 (time=3232.7), 0.00191985 s/step
# on time step 131388 (time=3284.7), 0.00192384 s/step
# on time step 133407 (time=3335.18), 0.00198184 s/step
# on time step 135292 (time=3382.3), 0.00212282 s/step
# on time step 137189 (time=3429.73), 0.00210917 s/step
# on time step 139068 (time=3476.7), 0.0021288 s/step
# on time step 140996 (time=3524.9), 0.00207473 s/step
# on time step 142919 (time=3572.98), 0.00208115 s/step
# on time step 144938 (time=3623.45), 0.00198138 s/step
# on time step 146935 (time=3673.38), 0.0020036 s/step
# on time step 148923 (time=3723.08), 0.00201287 s/step
# on time step 150866 (time=3771.65), 0.00205906 s/step
# on time step 152838 (time=3820.95), 0.00202941 s/step
# on time step 154770 (time=3869.25), 0.00207145 s/step
# on time step 156780 (time=3919.5), 0.00199016 s/step
# on time step 158772 (time=3969.3), 0.00201522 s/step
# on time step 160774 (time=4019.35), 0.00199805 s/step
# on time step 162714 (time=4067.85), 0.00206268 s/step
# on time step 164685 (time=4117.12), 0.00203467 s/step
# on time step 166742 (time=4168.55), 0.00194677 s/step
# on time step 168726 (time=4218.15), 0.00201704 s/step
# on time step 170698 (time=4267.45), 0.00202878 s/step
# on time step 172723 (time=4318.07), 0.00197837 s/step
# on time step 174735 (time=4368.38), 0.00198832 s/step
# on time step 176772 (time=4419.3), 0.00196442 s/step
# on time step 178799 (time=4469.98), 0.00197388 s/step
# on time step 180666 (time=4516.65), 0.00214294 s/step
# on time step 182630 (time=4565.75), 0.00203922 s/step
# on time step 184646 (time=4616.15), 0.00198444 s/step
# on time step 186640 (time=4666), 0.00200663 s/step
# on time step 188635 (time=4715.88), 0.00200567 s/step
# on time step 190595 (time=4764.88), 0.00204346 s/step
# on time step 192586 (time=4814.65), 0.00200923 s/step
# on time step 194583 (time=4864.57), 0.00200349 s/step
# on time step 196476 (time=4911.9), 0.00211362 s/step
# on time step 198419 (time=4960.48), 0.00206018 s/step
# on time step 200387 (time=5009.68), 0.00203288 s/step
# on time step 202302 (time=5057.55), 0.00209239 s/step
# on time step 204222 (time=5105.55), 0.00209051 s/step
# on time step 206194 (time=5154.85), 0.00204297 s/step
# on time step 208228 (time=5205.7), 0.0019672 s/step
# on time step 210107 (time=5252.68), 0.00212935 s/step
# on time step 212145 (time=5303.62), 0.00196362 s/step
# on time step 214088 (time=5352.2), 0.00205907 s/step
# on time step 216000 (time=5400), 0.00209276 s/step
# on time step 217961 (time=5449.03), 0.00204007 s/step
# on time step 219857 (time=5496.43), 0.00210986 s/step
# on time step 221828 (time=5545.7), 0.00203064 s/step
# on time step 223671 (time=5591.78), 0.00217039 s/step
# on time step 225642 (time=5641.05), 0.00202993 s/step
# on time step 227595 (time=5689.88), 0.00204835 s/step
# on time step 229434 (time=5735.85), 0.00218584 s/step
# on time step 231046 (time=5776.15), 0.00248151 s/step
# on time step 232582 (time=5814.55), 0.00260506 s/step
# on time step 234242 (time=5856.05), 0.00241007 s/step
# on time step 235864 (time=5896.6), 0.0024681 s/step
# on time step 237415 (time=5935.38), 0.00258266 s/step
# on time step 239616 (time=5990.4), 0.00181761 s/step
# on time step 241425 (time=6035.62), 0.00221246 s/step
# on time step 243638 (time=6090.95), 0.00180808 s/step
# on time step 245703 (time=6142.58), 0.00194351 s/step
# on time step 247802 (time=6195.05), 0.00190586 s/step
# on time step 249937 (time=6248.43), 0.00187372 s/step
# on time step 251681 (time=6292.03), 0.00229423 s/step
# on time step 253440 (time=6336), 0.00227439 s/step
# on time step 254696 (time=6367.4), 0.00318561 s/step
# on time step 254831 (time=6370.78), 0.0907336 s/step
# on time step 256362 (time=6409.05), 0.00261941 s/step
# on time step 257873 (time=6446.83), 0.00264891 s/step
# on time step 259472 (time=6486.8), 0.00250187 s/step
# on time step 261259 (time=6531.48), 0.00223914 s/step
# on time step 263099 (time=6577.48), 0.0021741 s/step
# on time step 265169 (time=6629.23), 0.00193295 s/step
# on time step 266751 (time=6668.78), 0.00252975 s/step
# on time step 268537 (time=6713.43), 0.00224051 s/step
# on time step 270284 (time=6757.1), 0.00229038 s/step
# on time step 271940 (time=6798.5), 0.00241622 s/step
# on time step 273634 (time=6840.85), 0.00236228 s/step
# on time step 275291 (time=6882.28), 0.0024149 s/step
# on time step 276792 (time=6919.8), 0.00267234 s/step
# on time step 278256 (time=6956.4), 0.00273307 s/step
# on time step 279772 (time=6994.3), 0.00263949 s/step
# on time step 281418 (time=7035.45), 0.00243071 s/step
# on time step 283101 (time=7077.53), 0.00237745 s/step
# on time step 284708 (time=7117.7), 0.00248941 s/step
# on time step 286423 (time=7160.58), 0.00233364 s/step
# on time step 288064 (time=7201.6), 0.00243921 s/step
# on time step 289764 (time=7244.1), 0.00235416 s/step
# on time step 291420 (time=7285.5), 0.00242022 s/step
# on time step 293207 (time=7330.18), 0.00224029 s/step
# on time step 294887 (time=7372.18), 0.00238109 s/step
# on time step 296491 (time=7412.28), 0.00249434 s/step
# on time step 298163 (time=7454.08), 0.00239315 s/step
# on time step 299913 (time=7497.83), 0.00228581 s/step
# on time step 301582 (time=7539.55), 0.00239719 s/step
# on time step 303402 (time=7585.05), 0.0021985 s/step
# on time step 305190 (time=7629.75), 0.00223851 s/step
# on time step 306947 (time=7673.68), 0.0022988 s/step
# on time step 308640 (time=7716), 0.00236362 s/step
# on time step 310330 (time=7758.25), 0.0023677 s/step
# on time step 311968 (time=7799.2), 0.00244203 s/step
# on time step 313738 (time=7843.45), 0.0022606 s/step
# on time step 315584 (time=7889.6), 0.00216736 s/step
# on time step 317318 (time=7932.95), 0.00230696 s/step
# on time step 319100 (time=7977.5), 0.00224492 s/step
# on time step 320941 (time=8023.53), 0.00217356 s/step
# on time step 322666 (time=8066.65), 0.00231911 s/step
# on time step 324356 (time=8108.9), 0.00236797 s/step
# on time step 326166 (time=8154.15), 0.00221063 s/step
# on time step 327966 (time=8199.15), 0.0022225 s/step
# on time step 329751 (time=8243.77), 0.00224163 s/step
# on time step 331465 (time=8286.62), 0.00233477 s/step
# on time step 333208 (time=8330.2), 0.00229538 s/step
# on time step 334995 (time=8374.88), 0.00223858 s/step
# on time step 336747 (time=8418.68), 0.00228341 s/step
# on time step 338425 (time=8460.62), 0.0023853 s/step
# on time step 340144 (time=8503.6), 0.00232766 s/step
# on time step 341935 (time=8548.38), 0.00223359 s/step
# on time step 343540 (time=8588.5), 0.0024926 s/step
# on time step 345376 (time=8634.4), 0.00217993 s/step
# on time step 347147 (time=8678.68), 0.00225888 s/step
# on time step 348971 (time=8724.27), 0.00219315 s/step
# on time step 350858 (time=8771.45), 0.00212048 s/step
# on time step 352673 (time=8816.83), 0.00220489 s/step
# on time step 354520 (time=8863), 0.00216607 s/step
# on time step 356408 (time=8910.2), 0.00211883 s/step
# on time step 358300 (time=8957.5), 0.00211438 s/step
# on time step 360214 (time=9005.35), 0.00209061 s/step
# on time step 362117 (time=9052.93), 0.00210206 s/step
# on time step 363730 (time=9093.25), 0.00248192 s/step
# on time step 365670 (time=9141.75), 0.00206207 s/step
# on time step 367568 (time=9189.2), 0.0021087 s/step
# on time step 369473 (time=9236.83), 0.00209992 s/step
# on time step 371341 (time=9283.52), 0.00214221 s/step
# on time step 373024 (time=9325.6), 0.00237805 s/step
# on time step 374784 (time=9369.6), 0.00227375 s/step
# on time step 376487 (time=9412.18), 0.00234964 s/step
# on time step 378265 (time=9456.62), 0.00225059 s/step
# on time step 380042 (time=9501.05), 0.00225156 s/step
# on time step 381892 (time=9547.3), 0.00216297 s/step
# on time step 383747 (time=9593.68), 0.00215823 s/step
# on time step 385611 (time=9640.27), 0.00214662 s/step
# on time step 387455 (time=9686.38), 0.00216952 s/step
# on time step 389297 (time=9732.43), 0.00217201 s/step
# on time step 391089 (time=9777.23), 0.00223402 s/step
# on time step 392962 (time=9824.05), 0.00213607 s/step
# on time step 394815 (time=9870.38), 0.00215957 s/step
# on time step 396794 (time=9919.85), 0.0020231 s/step
# on time step 398661 (time=9966.53), 0.00214354 s/step
# run 0 finished at t = 10005.0 (400200 timesteps)

# %%
# Main simulation with holes
geometry_holes = [mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)]

hole_positions = generate_waveguide(N, t_1, t_2, r)
for x_position in hole_positions:
    geometry_holes.append(mp.Cylinder(r, height=mp.inf, center=mp.Vector3(x_position, 0, 0), material=mp.air))

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry_holes,  # Geometry with holes
                    sources=sources,
                    resolution=resolution)



# Add flux monitors
refl = sim.add_flux(fcen, df, nfreq, refl_fr)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()


# Load the saved flux data for normalization
sim.load_minus_flux_data(refl, norm_refl_data)

# Run simulation with holes
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ey)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Get the reflected and transmitted flux
reflected_flux = mp.get_fluxes(refl)
transmitted_flux = mp.get_fluxes(tran)

# Normalize the transmission and reflection
transmission = np.array(transmitted_flux) / norm_incident_flux
reflection = np.array(reflected_flux) / norm_incident_flux
freqs = np.linspace(fcen - df/2, fcen + df/2, nfreq)

# Plot the transmission and reflection
plt.figure(figsize=(10, 6))
plt.plot(freqs, transmission, label="Transmission")
plt.plot(freqs, reflection, label="Reflection")
plt.xlabel("Frequency (1/μm)")
plt.ylabel("Normalized Flux")
plt.legend()
plt.title("Transmission and Reflection Spectra")
plt.grid(True)
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-18.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-16.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-13.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-11.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-8.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-6.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-3.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder
# , center = (1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 7 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000885963 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-18.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-16.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-13.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-11.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-8.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-6.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-3.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (1.5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 7 objects not shown)...
# time for set_epsilon = 1.2416 s
# -----------
# on time step 1347 (time=33.675), 0.00297138 s/step
# on time step 2822 (time=70.55), 0.00271401 s/step
# on time step 4294 (time=107.35), 0.00271813 s/step
# on time step 5761 (time=144.025), 0.00272787 s/step
# on time step 7187 (time=179.675), 0.00280643 s/step
# on time step 8661 (time=216.525), 0.0027152 s/step
# on time step 10235 (time=255.875), 0.00254232 s/step
# on time step 11828 (time=295.7), 0.00251121 s/step
# on time step 13262 (time=331.55), 0.00279093 s/step
# on time step 14745 (time=368.625), 0.00269758 s/step
# on time step 16248 (time=406.2), 0.00266191 s/step
# on time step 17751 (time=443.775), 0.00266236 s/step
# on time step 19193 (time=479.825), 0.00277502 s/step
# on time step 20615 (time=515.375), 0.00281377 s/step
# on time step 22014 (time=550.35), 0.00286192 s/step
# on time step 23350 (time=583.75), 0.00299799 s/step
# on time step 24826 (time=620.65), 0.00271015 s/step
# on time step 26286 (time=657.15), 0.00274039 s/step
# on time step 27767 (time=694.175), 0.00270159 s/step
# on time step 29230 (time=730.75), 0.00273439 s/step
# on time step 30644 (time=766.1), 0.00282991 s/step
# on time step 32121 (time=803.025), 0.00270909 s/step
# on time step 33557 (time=838.925), 0.00278675 s/step
# on time step 35023 (time=875.575), 0.00272967 s/step
# on time step 36467 (time=911.675), 0.00277018 s/step
# on time step 37966 (time=949.15), 0.0026691 s/step
# on time step 39439 (time=985.975), 0.00271634 s/step
# on time step 40906 (time=1022.65), 0.00272772 s/step
# on time step 42367 (time=1059.17), 0.00273791 s/step
# on time step 43797 (time=1094.92), 0.00279836 s/step
# on time step 45221 (time=1130.53), 0.00281056 s/step
# on time step 46585 (time=1164.62), 0.00293399 s/step
# on time step 48091 (time=1202.28), 0.00265678 s/step
# on time step 49579 (time=1239.48), 0.00269059 s/step
# on time step 51079 (time=1276.98), 0.00266689 s/step
# on time step 52537 (time=1313.43), 0.00274367 s/step
# on time step 53972 (time=1349.3), 0.00278833 s/step
# on time step 55463 (time=1386.58), 0.00268311 s/step
# on time step 56948 (time=1423.7), 0.00270262 s/step
# on time step 58452 (time=1461.3), 0.0026611 s/step
# on time step 60018 (time=1500.45), 0.00255499 s/step
# on time step 61595 (time=1539.88), 0.0025365 s/step
# on time step 63197 (time=1579.93), 0.00249744 s/step
# on time step 64749 (time=1618.73), 0.00257774 s/step
# on time step 66317 (time=1657.93), 0.0025521 s/step
# on time step 67856 (time=1696.4), 0.00259998 s/step
# on time step 69380 (time=1734.5), 0.00262473 s/step
# on time step 70948 (time=1773.7), 0.00255161 s/step
# on time step 72507 (time=1812.68), 0.00256701 s/step
# on time step 74097 (time=1852.43), 0.00251647 s/step
# on time step 75682 (time=1892.05), 0.00252459 s/step
# on time step 77263 (time=1931.58), 0.00253056 s/step
# on time step 78873 (time=1971.83), 0.00248596 s/step
# on time step 80495 (time=2012.38), 0.00246611 s/step
# on time step 82074 (time=2051.85), 0.00253409 s/step
# on time step 83624 (time=2090.6), 0.00258107 s/step
# on time step 85219 (time=2130.47), 0.00250834 s/step
# on time step 86744 (time=2168.6), 0.0026237 s/step
# on time step 88242 (time=2206.05), 0.00267043 s/step
# on time step 89827 (time=2245.68), 0.00252395 s/step
# on time step 91318 (time=2282.95), 0.00268279 s/step
# on time step 92679 (time=2316.97), 0.00294213 s/step
# on time step 94122 (time=2353.05), 0.00277349 s/step
# on time step 95592 (time=2389.8), 0.00272344 s/step
# on time step 97124 (time=2428.1), 0.00261118 s/step
# on time step 98579 (time=2464.48), 0.00275034 s/step
# on time step 99965 (time=2499.12), 0.0028872 s/step
# on time step 101430 (time=2535.75), 0.00273064 s/step
# on time step 102860 (time=2571.5), 0.00279812 s/step
# on time step 104168 (time=2604.2), 0.00305837 s/step
# on time step 105618 (time=2640.45), 0.00275925 s/step
# on time step 106888 (time=2672.2), 0.00314966 s/step
# on time step 108204 (time=2705.1), 0.00304071 s/step
# on time step 109553 (time=2738.83), 0.00296669 s/step
# on time step 110962 (time=2774.05), 0.00283906 s/step
# on time step 112351 (time=2808.78), 0.00288172 s/step
# on time step 113743 (time=2843.58), 0.00287436 s/step
# on time step 115117 (time=2877.93), 0.00291321 s/step
# on time step 116488 (time=2912.2), 0.0029191 s/step
# on time step 117825 (time=2945.62), 0.00299179 s/step
# on time step 119108 (time=2977.7), 0.00311873 s/step
# on time step 120406 (time=3010.15), 0.00308168 s/step
# on time step 121823 (time=3045.58), 0.00282305 s/step
# on time step 123156 (time=3078.9), 0.00300148 s/step
# on time step 124568 (time=3114.2), 0.002834 s/step
# on time step 125973 (time=3149.33), 0.00284778 s/step
# on time step 127362 (time=3184.05), 0.00287985 s/step
# on time step 128732 (time=3218.3), 0.00292104 s/step
# on time step 130148 (time=3253.7), 0.00282678 s/step
# on time step 131595 (time=3289.88), 0.00276554 s/step
# on time step 132993 (time=3324.83), 0.00286351 s/step
# on time step 134410 (time=3360.25), 0.002824 s/step
# on time step 135837 (time=3395.93), 0.00280335 s/step
# on time step 137244 (time=3431.1), 0.00284352 s/step
# on time step 138735 (time=3468.38), 0.00268394 s/step
# on time step 140169 (time=3504.23), 0.00279046 s/step
# on time step 141589 (time=3539.73), 0.00281691 s/step
# on time step 143027 (time=3575.68), 0.00278242 s/step
# on time step 144459 (time=3611.48), 0.00279384 s/step
# on time step 145834 (time=3645.85), 0.00290999 s/step
# on time step 147289 (time=3682.23), 0.0027492 s/step
# on time step 148765 (time=3719.12), 0.00271081 s/step
# on time step 150256 (time=3756.4), 0.00268382 s/step
# on time step 151743 (time=3793.58), 0.00269043 s/step
# on time step 153200 (time=3830), 0.00274714 s/step
# on time step 154642 (time=3866.05), 0.00277633 s/step
# on time step 156055 (time=3901.38), 0.00283196 s/step
# on time step 157509 (time=3937.73), 0.00275135 s/step
# on time step 158995 (time=3974.88), 0.00269224 s/step
# on time step 160404 (time=4010.1), 0.00283942 s/step
# on time step 161843 (time=4046.08), 0.00278102 s/step
# on time step 163236 (time=4080.9), 0.00287212 s/step
# on time step 164615 (time=4115.38), 0.00290154 s/step
# on time step 166006 (time=4150.15), 0.00287569 s/step
# on time step 167406 (time=4185.15), 0.0028573 s/step
# on time step 168848 (time=4221.2), 0.00277397 s/step
# on time step 170279 (time=4256.98), 0.00279549 s/step
# on time step 171759 (time=4293.98), 0.00270293 s/step
# on time step 173169 (time=4329.23), 0.00283752 s/step
# on time step 174563 (time=4364.07), 0.00287106 s/step
# on time step 175940 (time=4398.5), 0.00290727 s/step
# on time step 177306 (time=4432.65), 0.00292888 s/step
# on time step 178735 (time=4468.38), 0.00280039 s/step
# on time step 180142 (time=4503.55), 0.00284331 s/step
# on time step 181515 (time=4537.88), 0.00291402 s/step
# on time step 182922 (time=4573.05), 0.00284311 s/step
# on time step 184355 (time=4608.88), 0.00279294 s/step
# on time step 185839 (time=4645.98), 0.0026955 s/step
# on time step 187241 (time=4681.03), 0.00285347 s/step
# on time step 188681 (time=4717.03), 0.0027782 s/step
# on time step 190153 (time=4753.82), 0.0027183 s/step
# on time step 191617 (time=4790.43), 0.00273287 s/step
# on time step 193083 (time=4827.07), 0.00272917 s/step
# on time step 194498 (time=4862.45), 0.0028277 s/step
# on time step 195918 (time=4897.95), 0.0028184 s/step
# on time step 197422 (time=4935.55), 0.00266016 s/step
# on time step 198843 (time=4971.08), 0.00281609 s/step
# on time step 200272 (time=5006.8), 0.0027998 s/step
# on time step 201710 (time=5042.75), 0.00278381 s/step
# on time step 203171 (time=5079.28), 0.00273915 s/step
# on time step 204642 (time=5116.05), 0.00271951 s/step
# on time step 206100 (time=5152.5), 0.00274535 s/step
# on time step 207536 (time=5188.4), 0.00278637 s/step
# on time step 208930 (time=5223.25), 0.00286949 s/step
# on time step 210369 (time=5259.23), 0.00277988 s/step
# on time step 211761 (time=5294.03), 0.0028736 s/step
# on time step 213163 (time=5329.08), 0.00285411 s/step
# on time step 214566 (time=5364.15), 0.00285202 s/step
# on time step 215997 (time=5399.93), 0.00279594 s/step
# on time step 217432 (time=5435.8), 0.00278832 s/step
# on time step 218853 (time=5471.33), 0.00281634 s/step
# on time step 220283 (time=5507.08), 0.00279812 s/step
# on time step 221831 (time=5545.78), 0.00258414 s/step
# on time step 223261 (time=5581.53), 0.00279774 s/step
# on time step 224611 (time=5615.28), 0.00296362 s/step
# on time step 225997 (time=5649.93), 0.00288718 s/step
# on time step 227407 (time=5685.18), 0.002838 s/step
# on time step 228792 (time=5719.8), 0.00288853 s/step
# on time step 230161 (time=5754.03), 0.00292268 s/step
# on time step 231508 (time=5787.7), 0.00297079 s/step
# on time step 232932 (time=5823.3), 0.00281022 s/step
# on time step 234306 (time=5857.65), 0.0029118 s/step
# on time step 235679 (time=5891.98), 0.00291438 s/step
# on time step 237067 (time=5926.68), 0.00288379 s/step
# on time step 238467 (time=5961.68), 0.00285795 s/step
# on time step 239859 (time=5996.48), 0.00287388 s/step
# on time step 241244 (time=6031.1), 0.00288859 s/step
# on time step 242639 (time=6065.98), 0.00286923 s/step
# on time step 244110 (time=6102.75), 0.0027199 s/step
# on time step 245479 (time=6136.98), 0.00292397 s/step
# on time step 246854 (time=6171.35), 0.00291002 s/step
# on time step 248245 (time=6206.12), 0.00287628 s/step
# on time step 249689 (time=6242.23), 0.00277037 s/step
# on time step 251032 (time=6275.8), 0.00297915 s/step
# on time step 252281 (time=6307.03), 0.00320325 s/step
# on time step 253676 (time=6341.9), 0.00286927 s/step
# on time step 255127 (time=6378.18), 0.00275709 s/step
# on time step 256551 (time=6413.78), 0.00280969 s/step
# on time step 258006 (time=6450.15), 0.00275061 s/step
# on time step 259427 (time=6485.68), 0.0028151 s/step
# on time step 260833 (time=6520.83), 0.00284524 s/step
# on time step 262229 (time=6555.73), 0.00286595 s/step
# on time step 263625 (time=6590.62), 0.00286689 s/step
# on time step 265077 (time=6626.93), 0.00275535 s/step
# on time step 266451 (time=6661.28), 0.00291233 s/step
# on time step 267853 (time=6696.33), 0.00285402 s/step
# on time step 269226 (time=6730.65), 0.0029144 s/step
# on time step 270614 (time=6765.35), 0.00288299 s/step
# on time step 272045 (time=6801.12), 0.00279687 s/step
# on time step 273467 (time=6836.68), 0.00281497 s/step
# on time step 274861 (time=6871.53), 0.00287019 s/step
# on time step 276265 (time=6906.62), 0.00284994 s/step
# on time step 277729 (time=6943.23), 0.00273266 s/step
# on time step 279201 (time=6980.03), 0.00271848 s/step
# on time step 280577 (time=7014.43), 0.00290871 s/step
# on time step 281898 (time=7047.45), 0.00303009 s/step
# on time step 283297 (time=7082.43), 0.00286091 s/step
# on time step 284650 (time=7116.25), 0.00295823 s/step
# on time step 285995 (time=7149.88), 0.00297409 s/step
# on time step 287421 (time=7185.53), 0.00280673 s/step
# on time step 288821 (time=7220.53), 0.00285813 s/step
# on time step 290302 (time=7257.55), 0.00270153 s/step
# on time step 291734 (time=7293.35), 0.0027948 s/step
# on time step 293109 (time=7327.73), 0.00290918 s/step
# on time step 294540 (time=7363.5), 0.00279559 s/step
# on time step 295930 (time=7398.25), 0.00287855 s/step
# on time step 297291 (time=7432.28), 0.00294007 s/step
# on time step 298761 (time=7469.03), 0.00272162 s/step
# on time step 300153 (time=7503.83), 0.00287553 s/step
# on time step 301495 (time=7537.38), 0.00298149 s/step
# on time step 302854 (time=7571.35), 0.00294485 s/step
# on time step 304310 (time=7607.75), 0.00274863 s/step
# on time step 305739 (time=7643.48), 0.00280025 s/step
# on time step 307137 (time=7678.43), 0.00286238 s/step
# on time step 308556 (time=7713.9), 0.00282034 s/step
# on time step 309928 (time=7748.2), 0.0029169 s/step
# on time step 311371 (time=7784.28), 0.0027727 s/step
# on time step 312787 (time=7819.68), 0.00282624 s/step
# on time step 314154 (time=7853.85), 0.00292712 s/step
# on time step 315556 (time=7888.9), 0.00285467 s/step
# on time step 316980 (time=7924.5), 0.00281113 s/step
# on time step 318400 (time=7960), 0.00281704 s/step
# on time step 319819 (time=7995.48), 0.00282025 s/step
# on time step 321287 (time=8032.18), 0.00272535 s/step
# on time step 322672 (time=8066.8), 0.00288812 s/step
# on time step 324034 (time=8100.85), 0.00293903 s/step
# on time step 325421 (time=8135.53), 0.00288412 s/step
# on time step 326869 (time=8171.73), 0.00276436 s/step
# on time step 328325 (time=8208.12), 0.00274884 s/step
# on time step 329745 (time=8243.62), 0.00281702 s/step
# on time step 331147 (time=8278.68), 0.00285543 s/step
# on time step 332576 (time=8314.4), 0.00279951 s/step
# on time step 333947 (time=8348.68), 0.00291828 s/step
# on time step 335315 (time=8382.88), 0.00292526 s/step
# on time step 336631 (time=8415.77), 0.00304162 s/step
# on time step 338079 (time=8451.98), 0.0027632 s/step
# on time step 339463 (time=8486.58), 0.00289072 s/step
# on time step 340877 (time=8521.93), 0.00282947 s/step
# on time step 342246 (time=8556.15), 0.00292273 s/step
# on time step 343641 (time=8591.02), 0.00286897 s/step
# on time step 344988 (time=8624.7), 0.00296964 s/step
# on time step 346389 (time=8659.73), 0.00285658 s/step
# on time step 347846 (time=8696.15), 0.00274642 s/step
# on time step 349240 (time=8731), 0.00287048 s/step
# on time step 350632 (time=8765.8), 0.00287388 s/step
# on time step 352041 (time=8801.02), 0.00284037 s/step
# on time step 353445 (time=8836.12), 0.00284918 s/step
# on time step 354865 (time=8871.62), 0.0028171 s/step
# on time step 356219 (time=8905.48), 0.00295481 s/step
# on time step 357618 (time=8940.45), 0.0028595 s/step
# on time step 359038 (time=8975.95), 0.00281768 s/step
# on time step 360430 (time=9010.75), 0.00287424 s/step
# on time step 361893 (time=9047.33), 0.00273475 s/step
# on time step 363267 (time=9081.68), 0.00291345 s/step
# on time step 364722 (time=9118.05), 0.00275093 s/step
# on time step 366120 (time=9153), 0.00286185 s/step
# on time step 367540 (time=9188.5), 0.00281827 s/step
# on time step 368918 (time=9222.95), 0.00290376 s/step
# on time step 370324 (time=9258.1), 0.00284582 s/step
# on time step 371752 (time=9293.8), 0.00280188 s/step
# on time step 373170 (time=9329.25), 0.00282191 s/step
# on time step 374567 (time=9364.18), 0.00286555 s/step
# on time step 375968 (time=9399.2), 0.00285568 s/step
# on time step 377362 (time=9434.05), 0.00287139 s/step
# on time step 378759 (time=9468.98), 0.00286391 s/step
# on time step 380162 (time=9504.05), 0.00285237 s/step
# on time step 381520 (time=9538), 0.00294655 s/step
# on time step 382925 (time=9573.12), 0.00284757 s/step
# on time step 384310 (time=9607.75), 0.00288896 s/step
# on time step 385749 (time=9643.73), 0.00278031 s/step
# on time step 387174 (time=9679.35), 0.00280717 s/step
# on time step 388596 (time=9714.9), 0.002814 s/step
# on time step 389994 (time=9749.85), 0.00286236 s/step
# on time step 391422 (time=9785.55), 0.00280133 s/step
# on time step 392850 (time=9821.25), 0.0028017 s/step
# on time step 394217 (time=9855.43), 0.00292792 s/step
# on time step 395567 (time=9889.18), 0.00296467 s/step
# on time step 397236 (time=9930.9), 0.00239703 s/step
# on time step 399073 (time=9976.83), 0.00217843 s/step
# run 0 finished at t = 10005.0 (400200 timesteps)
