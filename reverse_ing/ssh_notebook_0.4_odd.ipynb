# %%
#!/usr/bin/env python
# coding: utf-8
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_waveguide(N, intra_pair_spacing, inter_pair_spacing, radius):
        # Adjust spacings to include the diameters of the circles
        adjusted_intra_pair_spacing = intra_pair_spacing + 2 * radius
        adjusted_inter_pair_spacing = inter_pair_spacing + 2 * radius
        
        # Generate the list with adjusted spacings
        result = [0]
        for i in range(1, N):
            if i % 2 == 1:  # If it's an odd index, use adjusted intra-pair spacing
                next_value = result[-1] + adjusted_intra_pair_spacing
            else:  # For even indices, use adjusted inter-pair spacing
                next_value = result[-1] + adjusted_inter_pair_spacing
            result.append(next_value)
        
        # Find the center value
        if N % 2 == 1:
            center_value = result[len(result) // 2]
        else:
            center_value = (result[(len(result) // 2) - 1] + result[len(result) // 2]) / 2
        
        # Shift the list so the center value is at 0
        shifted_result = [x - center_value for x in result]
        
        return shifted_result

# %%
# Material definitions
n_SiO2 = 1.45  # Refractive index of SiO2
eps_SiO2 = n_SiO2**2  # Dielectric constant of SiO2

resolution = 20  # pixels/um
w = 2  # width of waveguide in um
r = 0.5  # radius of holes in um
t_1 = 1  # intra-pair spacing
t_2 = 2  # inter-pair spacing (defect spacing, ordinary spacing = 1)
sy = 10  # size of cell in y direction (perpendicular to waveguide), in um
pad = 7  # padding between last hole and PML edge, in um
dpml = 1  # PML thickness, in um
N = 15  # number of holes

# %%
wl = 0.4    # source wavelength (in μm)
fcen = 1/wl  # pulse center frequency (in 1/μm)
df = 0.001  # pulse width (in frequency, in 1/μm)
nfreq = 500  # number of frequency points to compute flux

# %%
# Calculate the size of the cell in the x direction
if N % 2 == 0:
    sx = 2 * (pad + dpml + N // 2 + 2 * N // 2) - 20
else:
    sx = 2 * (pad + dpml + (N + 1) // 2 + 2 * (N + 1) // 2) - 20


cell = mp.Vector3(sx, sy, 0)
pml_layers = [mp.PML(dpml)]

# Define the waveguide material
SiO2_material = mp.Medium(epsilon=eps_SiO2)


# Source
sources = [mp.Source(mp.GaussianSource(wavelength=wl, fwidth=df),
                     component=mp.Ez,
                     center=mp.Vector3(-0.5 * sx + dpml),
                     size=mp.Vector3(0, w, 0))]

# Normalization run simulation
norm_sim = mp.Simulation(cell_size=cell,
                         boundary_layers=pml_layers,
                         geometry=[mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)],  # No holes for normalization
                         sources=sources,
                         resolution=resolution)



# Flux monitors
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5 * sx + dpml + 0.5), size=mp.Vector3(0, 2*w, 0))
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5 * sx - dpml - 0.5), size=mp.Vector3(0, 2*w, 0))


# Add flux monitors
norm_refl = norm_sim.add_flux(fcen, df, nfreq, refl_fr)
norm_tran = norm_sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
norm_sim.plot2D()
plt.show()

# Run normalization simulation
norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Save flux for normalization
norm_refl_data = norm_sim.get_flux_data(norm_refl)
norm_tran_data = norm_sim.get_flux_data(norm_tran)

# Calculate the incident power for normalization
norm_refl_flux = mp.get_fluxes(norm_refl)
norm_tran_flux = mp.get_fluxes(norm_tran)
norm_incident_flux = np.array(norm_refl_flux) + np.array(norm_tran_flux)

# Reset simulation for main run with holes
norm_sim.reset_meep()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000401974 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# time for set_epsilon = 0.202123 s
# -----------
# field decay(t = 50.025000000000006): 1.0237198109292607e-18 / 1.0237198109292607e-18 = 1.0
# field decay(t = 100.05000000000001): 2.481165271373844e-12 / 2.481165271373844e-12 = 1.0
# field decay(t = 150.07500000000002): 2.442068720022027e-12 / 2.481165271373844e-12 = 0.9842426654109306
# on time step 7762 (time=194.05), 0.000515353 s/step
# field decay(t = 200.10000000000002): 4.004128383172241e-12 / 4.004128383172241e-12 = 1.0
# field decay(t = 250.125): 6.275568163921326e-12 / 6.275568163921326e-12 = 1.0
# field decay(t = 300.15000000000003): 1.0227721023303844e-11 / 1.0227721023303844e-11 = 1.0
# field decay(t = 350.175): 1.6560489166811268e-11 / 1.6560489166811268e-11 = 1.0
# on time step 15202 (time=380.05), 0.000537664 s/step
# field decay(t = 400.20000000000005): 2.611337120714155e-11 / 2.611337120714155e-11 = 1.0
# field decay(t = 450.225): 4.14728003149578e-11 / 4.14728003149578e-11 = 1.0
# field decay(t = 500.25): 6.567473028747302e-11 / 6.567473028747302e-11 = 1.0
# field decay(t = 550.275): 1.0335701958587635e-10 / 1.0335701958587635e-10 = 1.0
# on time step 22281 (time=557.025), 0.000565076 s/step
# field decay(t = 600.3000000000001): 1.62096264340786e-10 / 1.62096264340786e-10 = 1.0
# field decay(t = 650.325): 2.530000572548203e-10 / 2.530000572548203e-10 = 1.0
# field decay(t = 700.35): 3.9213107940407186e-10 / 3.9213107940407186e-10 = 1.0
# on time step 28614 (time=715.35), 0.00063165 s/step
# field decay(t = 750.375): 6.070240400275609e-10 / 6.070240400275609e-10 = 1.0
# field decay(t = 800.4000000000001): 9.329629953542207e-10 / 9.329629953542207e-10 = 1.0
# field decay(t = 850.4250000000001): 1.423888214040755e-09 / 1.423888214040755e-09 = 1.0
# on time step 35058 (time=876.45), 0.000620805 s/step
# field decay(t = 900.45): 2.1664439362503803e-09 / 2.1664439362503803e-09 = 1.0
# field decay(t = 950.475): 3.279943358318604e-09 / 3.279943358318604e-09 = 1.0
# field decay(t = 1000.5): 4.940877721417272e-09 / 4.940877721417272e-09 = 1.0
# field decay(t = 1050.525): 7.405136017900295e-09 / 7.405136017900295e-09 = 1.0
# on time step 42356 (time=1058.9), 0.000548128 s/step
# field decay(t = 1100.55): 1.1038385045752876e-08 / 1.1038385045752876e-08 = 1.0
# field decay(t = 1150.575): 1.639721559900358e-08 / 1.639721559900358e-08 = 1.0
# field decay(t = 1200.6000000000001): 2.420224466028447e-08 / 2.420224466028447e-08 = 1.0
# on time step 49498 (time=1237.45), 0.000560094 s/step
# field decay(t = 1250.625): 3.554778621557286e-08 / 3.554778621557286e-08 = 1.0
# field decay(t = 1300.65): 5.195144617418559e-08 / 5.195144617418559e-08 = 1.0
# field decay(t = 1350.6750000000002): 7.554046298441675e-08 / 7.554046298441675e-08 = 1.0
# on time step 55281 (time=1382.03), 0.000691749 s/step
# field decay(t = 1400.7): 1.0930542097334263e-07 / 1.0930542097334263e-07 = 1.0
# field decay(t = 1450.7250000000001): 1.573597792682073e-07 / 1.573597792682073e-07 = 1.0
# field decay(t = 1500.75): 2.2542439704997638e-07 / 2.2542439704997638e-07 = 1.0
# on time step 60407 (time=1510.18), 0.000780445 s/step
# field decay(t = 1550.775): 3.2174593787763456e-07 / 3.2174593787763456e-07 = 1.0
# field decay(t = 1600.8000000000002): 4.5629111661983287e-07 / 4.5629111661983287e-07 = 1.0
# on time step 65923 (time=1648.08), 0.000725209 s/step
# field decay(t = 1650.825): 6.438922546889332e-07 / 6.438922546889332e-07 = 1.0
# field decay(t = 1700.8500000000001): 9.040814576861094e-07 / 9.040814576861094e-07 = 1.0
# field decay(t = 1750.875): 1.263084016755131e-06 / 1.263084016755131e-06 = 1.0
# on time step 70877 (time=1771.93), 0.000807487 s/step
# field decay(t = 1800.9): 1.7558153984936922e-06 / 1.7558153984936922e-06 = 1.0
# field decay(t = 1850.9250000000002): 2.4285990901928294e-06 / 2.4285990901928294e-06 = 1.0
# field decay(t = 1900.95): 3.3423887354415615e-06 / 3.3423887354415615e-06 = 1.0
# on time step 76095 (time=1902.38), 0.000766686 s/step
# field decay(t = 1950.9750000000001): 4.582864398086575e-06 / 4.582864398086575e-06 = 1.0
# field decay(t = 2001.0): 6.244367828011642e-06 / 6.244367828011642e-06 = 1.0
# on time step 81497 (time=2037.43), 0.000740484 s/step
# field decay(t = 2051.025): 8.465868906245179e-06 / 8.465868906245179e-06 = 1.0
# field decay(t = 2101.05): 1.1420422446926242e-05 / 1.1420422446926242e-05 = 1.0
# field decay(t = 2151.0750000000003): 1.5329353645195856e-05 / 1.5329353645195856e-05 = 1.0
# on time step 87255 (time=2181.38), 0.000694711 s/step
# field decay(t = 2201.1): 2.047342287914102e-05 / 2.047342287914102e-05 = 1.0
# field decay(t = 2251.125): 2.7207413351268373e-05 / 2.7207413351268373e-05 = 1.0
# field decay(t = 2301.15): 3.5975822293337094e-05 / 3.5975822293337094e-05 = 1.0
# on time step 93104 (time=2327.6), 0.000683965 s/step
# field decay(t = 2351.175): 4.738465087621168e-05 / 4.738465087621168e-05 = 1.0
# field decay(t = 2401.2000000000003): 6.20312108699168e-05 / 6.20312108699168e-05 = 1.0
# field decay(t = 2451.225): 8.080026733707212e-05 / 8.080026733707212e-05 = 1.0
# on time step 98787 (time=2469.68), 0.000703964 s/step
# field decay(t = 2501.25): 0.00010472322078825761 / 0.00010472322078825761 = 1.0
# field decay(t = 2551.275): 0.0001350520691879694 / 0.0001350520691879694 = 1.0
# field decay(t = 2601.3): 0.0001732958587460939 / 0.0001732958587460939 = 1.0
# on time step 104435 (time=2610.88), 0.000708249 s/step
# field decay(t = 2651.3250000000003): 0.00022126065863475433 / 0.00022126065863475433 = 1.0
# field decay(t = 2701.3500000000004): 0.0002810920833378208 / 0.0002810920833378208 = 1.0
# on time step 109697 (time=2742.43), 0.000760209 s/step
# field decay(t = 2751.375): 0.00035565078410962207 / 0.00035565078410962207 = 1.0
# field decay(t = 2801.4): 0.0004473179771554641 / 0.0004473179771554641 = 1.0
# on time step 113741 (time=2843.53), 0.000989256 s/step
# field decay(t = 2851.425): 0.0005598057232860259 / 0.0005598057232860259 = 1.0
# field decay(t = 2901.4500000000003): 0.0006970864685135433 / 0.0006970864685135433 = 1.0
# on time step 116967 (time=2924.18), 0.00124001 s/step
# field decay(t = 2951.4750000000004): 0.0008637030938838205 / 0.0008637030938838205 = 1.0
# on time step 120033 (time=3000.83), 0.00130466 s/step
# field decay(t = 3001.5): 0.001064807051608677 / 0.001064807051608677 = 1.0
# field decay(t = 3051.525): 0.0013061887526397036 / 0.0013061887526397036 = 1.0
# on time step 123133 (time=3078.33), 0.00129052 s/step
# field decay(t = 3101.55): 0.0015942974722470897 / 0.0015942974722470897 = 1.0
# field decay(t = 3151.5750000000003): 0.0019377353663353075 / 0.0019377353663353075 = 1.0
# on time step 126302 (time=3157.55), 0.00126226 s/step
# field decay(t = 3201.6000000000004): 0.002341564662691111 / 0.002341564662691111 = 1.0
# on time step 129636 (time=3240.9), 0.00119991 s/step
# field decay(t = 3251.625): 0.002815440201081047 / 0.002815440201081047 = 1.0
# field decay(t = 3301.65): 0.003368332608525738 / 0.003368332608525738 = 1.0
# on time step 133284 (time=3332.1), 0.00109665 s/step
# field decay(t = 3351.675): 0.004009703147039761 / 0.004009703147039761 = 1.0
# field decay(t = 3401.7000000000003): 0.004749390644227844 / 0.004749390644227844 = 1.0
# on time step 136891 (time=3422.28), 0.00110918 s/step
# field decay(t = 3451.7250000000004): 0.005597472898630765 / 0.005597472898630765 = 1.0
# field decay(t = 3501.75): 0.0065640928145508405 / 0.0065640928145508405 = 1.0
# on time step 140499 (time=3512.48), 0.00110866 s/step
# field decay(t = 3551.775): 0.00766389534435581 / 0.00766389534435581 = 1.0
# on time step 144032 (time=3600.8), 0.00113237 s/step
# field decay(t = 3601.8): 0.008897756286458346 / 0.008897756286458346 = 1.0
# field decay(t = 3651.8250000000003): 0.010278741665901085 / 0.010278741665901085 = 1.0
# on time step 147422 (time=3685.55), 0.00118 s/step
# field decay(t = 3701.8500000000004): 0.011814840735522835 / 0.011814840735522835 = 1.0
# field decay(t = 3751.875): 0.01351276645509639 / 0.01351276645509639 = 1.0
# on time step 150844 (time=3771.1), 0.00116923 s/step
# field decay(t = 3801.9): 0.015377622180845532 / 0.015377622180845532 = 1.0
# on time step 154066 (time=3851.65), 0.00124175 s/step
# field decay(t = 3851.925): 0.01741255801476344 / 0.01741255801476344 = 1.0
# field decay(t = 3901.9500000000003): 0.01961843879230968 / 0.01961843879230968 = 1.0
# on time step 157184 (time=3929.6), 0.00128315 s/step
# field decay(t = 3951.9750000000004): 0.022003358549016225 / 0.022003358549016225 = 1.0
# field decay(t = 4002.0): 0.024543651303821284 / 0.024543651303821284 = 1.0
# on time step 160122 (time=4003.05), 0.00136178 s/step
# field decay(t = 4052.025): 0.02724067292867363 / 0.02724067292867363 = 1.0
# on time step 162779 (time=4069.48), 0.00150566 s/step
# field decay(t = 4102.05): 0.030083267592588833 / 0.030083267592588833 = 1.0
# on time step 165256 (time=4131.4), 0.00161502 s/step
# field decay(t = 4152.075): 0.03305679024056108 / 0.03305679024056108 = 1.0
# on time step 167621 (time=4190.53), 0.00169146 s/step
# field decay(t = 4202.1): 0.03614304999218188 / 0.03614304999218188 = 1.0
# on time step 169773 (time=4244.32), 0.00185895 s/step
# field decay(t = 4252.125): 0.03932035450753621 / 0.03932035450753621 = 1.0
# on time step 171699 (time=4292.48), 0.00207738 s/step
# field decay(t = 4302.150000000001): 0.04256361853772547 / 0.04256361853772547 = 1.0
# on time step 173493 (time=4337.32), 0.00223065 s/step
# field decay(t = 4352.175): 0.04585775456285776 / 0.04585775456285776 = 1.0
# on time step 175231 (time=4380.78), 0.00230218 s/step
# field decay(t = 4402.2): 0.04914532568887261 / 0.04914532568887261 = 1.0
# on time step 176680 (time=4417), 0.00276171 s/step
# on time step 177966 (time=4449.15), 0.00311169 s/step
# field decay(t = 4452.225): 0.052405894269437606 / 0.052405894269437606 = 1.0
# on time step 178859 (time=4471.48), 0.00449704 s/step
# on time step 179793 (time=4494.82), 0.00428489 s/step
# field decay(t = 4502.25): 0.055604062423658715 / 0.055604062423658715 = 1.0
# on time step 180840 (time=4521), 0.00382148 s/step
# on time step 181943 (time=4548.57), 0.00362701 s/step
# field decay(t = 4552.275000000001): 0.05870314839395102 / 0.05870314839395102 = 1.0
# on time step 182968 (time=4574.2), 0.00390307 s/step
# on time step 184034 (time=4600.85), 0.00375342 s/step
# field decay(t = 4602.3): 0.06166585582461204 / 0.06166585582461204 = 1.0
# on time step 184887 (time=4622.18), 0.00479045 s/step
# on time step 185709 (time=4642.73), 0.00496184 s/step
# field decay(t = 4652.325): 0.06445500303162292 / 0.06445500303162292 = 1.0
# on time step 186558 (time=4663.95), 0.00471171 s/step
# on time step 187416 (time=4685.4), 0.00466244 s/step
# on time step 188042 (time=4701.05), 0.00654867 s/step
# field decay(t = 4702.35): 0.0670342860805156 / 0.0670342860805156 = 1.0
# on time step 188665 (time=4716.62), 0.00642159 s/step
# on time step 189408 (time=4735.2), 0.00539081 s/step
# on time step 189944 (time=4748.6), 0.007521 s/step
# field decay(t = 4752.375): 0.06937786919477112 / 0.06937786919477112 = 1.0
# on time step 190675 (time=4766.88), 0.00549382 s/step
# on time step 191385 (time=4784.62), 0.00563555 s/step
# field decay(t = 4802.400000000001): 0.07143476263098912 / 0.07143476263098912 = 1.0
# on time step 192364 (time=4809.1), 0.00409077 s/step
# on time step 193481 (time=4837.03), 0.00358498 s/step
# field decay(t = 4852.425): 0.07318578495365817 / 0.07318578495365817 = 1.0
# on time step 194466 (time=4861.65), 0.0040633 s/step
# on time step 195605 (time=4890.12), 0.00351285 s/step
# field decay(t = 4902.45): 0.07460576383364508 / 0.07460576383364508 = 1.0
# on time step 196836 (time=4920.9), 0.00325158 s/step
# on time step 198008 (time=4950.2), 0.00341392 s/step
# field decay(t = 4952.475): 0.0756739676599312 / 0.0756739676599312 = 1.0
# on time step 199221 (time=4980.53), 0.00329915 s/step
# field decay(t = 5002.5): 0.07637463042713491 / 0.07637463042713491 = 1.0
# on time step 200473 (time=5011.83), 0.00319549 s/step
# on time step 201599 (time=5039.98), 0.0035524 s/step
# field decay(t = 5052.525000000001): 0.0766973241868189 / 0.0766973241868189 = 1.0
# on time step 202716 (time=5067.9), 0.00358961 s/step
# on time step 203924 (time=5098.1), 0.00331207 s/step
# field decay(t = 5102.55): 0.07671991758429039 / 0.07671991758429039 = 1.0
# on time step 204891 (time=5122.28), 0.00414005 s/step
# on time step 206031 (time=5150.78), 0.00351289 s/step
# field decay(t = 5152.575000000001): 0.07663621904427889 / 0.07671991758429039 = 0.9989090376704388
# on time step 207173 (time=5179.33), 0.00350327 s/step
# on time step 208011 (time=5200.28), 0.00477404 s/step
# field decay(t = 5202.6): 0.07619018339152929 / 0.07671991758429039 = 0.9930952194757106
# on time step 208616 (time=5215.4), 0.00666618 s/step
# on time step 209517 (time=5237.93), 0.00444209 s/step
# field decay(t = 5252.625): 0.07536994761664309 / 0.07671991758429039 = 0.9824039179113544
# on time step 210726 (time=5268.15), 0.00331059 s/step
# field decay(t = 5302.650000000001): 0.07418667281377572 / 0.07671991758429039 = 0.9669806114203465
# on time step 212388 (time=5309.7), 0.00244024 s/step
# on time step 213890 (time=5347.25), 0.00266422 s/step
# field decay(t = 5352.675): 0.07265777321990093 / 0.07671991758429039 = 0.9470522845657846
# on time step 215370 (time=5384.25), 0.00270378 s/step
# field decay(t = 5402.700000000001): 0.0708054610419065 / 0.07671991758429039 = 0.9229084606890275
# on time step 216870 (time=5421.75), 0.00266693 s/step
# field decay(t = 5452.725): 0.06865622346443344 / 0.07671991758429039 = 0.8948943850076799
# on time step 218372 (time=5459.3), 0.00266347 s/step
# on time step 219709 (time=5492.73), 0.00299262 s/step
# field decay(t = 5502.75): 0.06624018640479466 / 0.07671991758429039 = 0.863402731526896
# on time step 221218 (time=5530.45), 0.00265419 s/step
# on time step 221972 (time=5549.3), 0.00530519 s/step
# field decay(t = 5552.775000000001): 0.06359041805299988 / 0.07671991758429039 = 0.8288645250841746
# on time step 222683 (time=5567.08), 0.00563176 s/step
# on time step 223722 (time=5593.05), 0.00385086 s/step
# field decay(t = 5602.8): 0.06073042855298804 / 0.07671991758429039 = 0.7915862068838242
# on time step 224987 (time=5624.68), 0.00316222 s/step
# field decay(t = 5652.825000000001): 0.05771979306090586 / 0.07671991758429039 = 0.7523443048213714
# on time step 226244 (time=5656.1), 0.00318276 s/step
# on time step 227354 (time=5683.85), 0.00361103 s/step
# field decay(t = 5702.85): 0.054584793421130116 / 0.07671991758429039 = 0.7114813876221787
# on time step 228291 (time=5707.28), 0.00426962 s/step
# on time step 229473 (time=5736.83), 0.00338558 s/step
# field decay(t = 5752.875): 0.051362608775279546 / 0.07671991758429039 = 0.6694820640135417
# on time step 230697 (time=5767.43), 0.00326938 s/step
# on time step 232033 (time=5800.83), 0.00299652 s/step
# field decay(t = 5802.900000000001): 0.048089579993204866 / 0.07671991758429039 = 0.6268200163323945
# on time step 233223 (time=5830.58), 0.00336569 s/step
# field decay(t = 5852.925): 0.04480055228783869 / 0.07671991758429039 = 0.5839494318879757
# on time step 234199 (time=5854.98), 0.00415228 s/step
# on time step 235600 (time=5890), 0.00285572 s/step
# field decay(t = 5902.950000000001): 0.041528308091445566 / 0.07671991758429039 = 0.5412976108299306
# on time step 236943 (time=5923.58), 0.00300873 s/step
# field decay(t = 5952.975): 0.03830307159422308 / 0.07671991758429039 = 0.49925850809394295
# on time step 238418 (time=5960.45), 0.0027179 s/step
# on time step 239874 (time=5996.85), 0.00274732 s/step
# field decay(t = 6003.0): 0.03513969446491764 / 0.07671991758429039 = 0.4580257066401365
# on time step 241445 (time=6036.12), 0.00254663 s/step
# field decay(t = 6053.025000000001): 0.03208748177669802 / 0.07671991758429039 = 0.4182418697392922
# on time step 243010 (time=6075.25), 0.00256956 s/step
# field decay(t = 6103.05): 0.029154243189960603 / 0.07671991758429039 = 0.3800087918229254
# on time step 244466 (time=6111.65), 0.00274754 s/step
# on time step 246117 (time=6152.93), 0.00242482 s/step
# field decay(t = 6153.075000000001): 0.02635702573328835 / 0.07671991758429039 = 0.3435486711039607
# on time step 247737 (time=6193.43), 0.00247013 s/step
# field decay(t = 6203.1): 0.023709343954322587 / 0.07671991758429039 = 0.3090376619379665
# on time step 249568 (time=6239.2), 0.00218485 s/step
# field decay(t = 6253.125): 0.021221259841410125 / 0.07671991758429039 = 0.2766069165558581
# on time step 251443 (time=6286.08), 0.00213376 s/step
# field decay(t = 6303.150000000001): 0.01889954159441154 / 0.07671991758429039 = 0.24634465455006585
# on time step 253010 (time=6325.25), 0.00255286 s/step
# field decay(t = 6353.175): 0.016747879747315588 / 0.07671991758429039 = 0.21829897990851047
# on time step 254434 (time=6360.85), 0.00280908 s/step
# on time step 255806 (time=6395.15), 0.00291707 s/step
# field decay(t = 6403.200000000001): 0.014759576945573711 / 0.07671991758429039 = 0.19238259646665687
# on time step 256864 (time=6421.6), 0.00378074 s/step
# field decay(t = 6453.225): 0.01294883769178356 / 0.07671991758429039 = 0.16878065174609935
# on time step 258300 (time=6457.5), 0.00278714 s/step
# on time step 259148 (time=6478.7), 0.00475187 s/step
# field decay(t = 6503.25): 0.011303583534308779 / 0.07671991758429039 = 0.14733571007671892
# on time step 260540 (time=6513.5), 0.00287387 s/step
# field decay(t = 6553.275000000001): 0.009818157609156216 / 0.07671991758429039 = 0.12797403748992867
# on time step 262463 (time=6561.58), 0.0020821 s/step
# field decay(t = 6603.3): 0.00848540131836766 / 0.07671991758429039 = 0.1106023257786343
# on time step 264292 (time=6607.3), 0.00218986 s/step
# on time step 265867 (time=6646.68), 0.00254141 s/step
# field decay(t = 6653.325000000001): 0.00729698135432276 / 0.07671991758429039 = 0.09511195507093365
# on time step 267572 (time=6689.3), 0.00234645 s/step
# field decay(t = 6703.35): 0.006243708086789548 / 0.07671991758429039 = 0.08138314382219886
# on time step 269278 (time=6731.95), 0.00234524 s/step
# field decay(t = 6753.375): 0.005315821436429248 / 0.07671991758429039 = 0.0692886750117905
# on time step 270976 (time=6774.4), 0.00235652 s/step
# field decay(t = 6803.400000000001): 0.004500224142482296 / 0.07671991758429039 = 0.05865783337863996
# on time step 272621 (time=6815.53), 0.00243211 s/step
# field decay(t = 6853.425): 0.0037932392518245646 / 0.07671991758429039 = 0.04944269195358585
# on time step 274206 (time=6855.15), 0.00252538 s/step
# on time step 275928 (time=6898.2), 0.00232383 s/step
# field decay(t = 6903.450000000001): 0.0031813746868780313 / 0.07671991758429039 = 0.041467389265411145
# on time step 277658 (time=6941.45), 0.00231247 s/step
# field decay(t = 6953.475): 0.0026548985175407964 / 0.07671991758429039 = 0.034605075202588965
# on time step 279331 (time=6983.28), 0.00239121 s/step
# field decay(t = 7003.5): 0.0022044973308934226 / 0.07671991758429039 = 0.028734354784354304
# on time step 280720 (time=7018), 0.00287979 s/step
# field decay(t = 7053.525000000001): 0.0018213760441822859 / 0.07671991758429039 = 0.02374058916553426
# on time step 282339 (time=7058.48), 0.00247254 s/step
# field decay(t = 7103.55): 0.0014973321811476347 / 0.07671991758429039 = 0.019516863785763984
# on time step 284270 (time=7106.75), 0.00207194 s/step
# field decay(t = 7153.575000000001): 0.0012247999655995794 / 0.07671991758429039 = 0.01596456310388916
# on time step 286168 (time=7154.2), 0.00210787 s/step
# on time step 288125 (time=7203.12), 0.00204453 s/step
# field decay(t = 7203.6): 0.000996044230666502 / 0.07671991758429039 = 0.012982863668644732
# on time step 289791 (time=7244.78), 0.00240144 s/step
# field decay(t = 7253.625): 0.0008066292011482014 / 0.07671991758429039 = 0.01051394770154669
# on time step 291486 (time=7287.15), 0.00238411 s/step
# field decay(t = 7303.650000000001): 0.0006499768075217468 / 0.07671991758429039 = 0.008472073849761796
# on time step 293219 (time=7330.48), 0.00230868 s/step
# field decay(t = 7353.675): 0.0005211349051098927 / 0.07671991758429039 = 0.006792693755664347
# on time step 295006 (time=7375.15), 0.00223946 s/step
# field decay(t = 7403.700000000001): 0.0004157488126133819 / 0.07671991758429039 = 0.005419046653127701
# on time step 296796 (time=7419.9), 0.00223499 s/step
# field decay(t = 7453.725): 0.00033001991782806336 / 0.07671991758429039 = 0.004301619816854966
# on time step 298604 (time=7465.1), 0.00221241 s/step
# field decay(t = 7503.75): 0.0002606621173084496 / 0.07671991758429039 = 0.0033975807784473464
# on time step 300453 (time=7511.33), 0.00216453 s/step
# field decay(t = 7553.775000000001): 0.0002048538438130824 / 0.07671991758429039 = 0.002670152031746049
# on time step 302472 (time=7561.8), 0.00198162 s/step
# field decay(t = 7603.8): 0.00016003223768256157 / 0.07671991758429039 = 0.0020859281751278978
# on time step 304375 (time=7609.38), 0.00210256 s/step
# field decay(t = 7653.825000000001): 0.00012451509660106315 / 0.07671991758429039 = 0.0016229826689302853
# on time step 306315 (time=7657.88), 0.00206246 s/step
# field decay(t = 7703.85): 9.639736863502689e-05 / 0.07671991758429039 = 0.0012564842568960966
# on time step 308279 (time=7706.98), 0.00203683 s/step
# field decay(t = 7753.875): 7.425684431906887e-05 / 0.07671991758429039 = 0.0009678952566324723
# on time step 310313 (time=7757.83), 0.00196703 s/step
# field decay(t = 7803.900000000001): 5.691624688102229e-05 / 0.07671991758429039 = 0.0007418705425287994
# on time step 312380 (time=7809.5), 0.00193571 s/step
# field decay(t = 7853.925): 4.340749455633456e-05 / 0.07671991758429039 = 0.0005657917255795244
# on time step 314356 (time=7858.9), 0.00202513 s/step
# on time step 316106 (time=7902.65), 0.00228601 s/step
# field decay(t = 7903.950000000001): 3.293990626058047e-05 / 0.07671991758429039 = 0.00042935273261197345
# on time step 317839 (time=7945.98), 0.00230997 s/step
# field decay(t = 7953.975): 2.487184595390923e-05 / 0.07671991758429039 = 0.00032419020688575573
# on time step 319390 (time=7984.75), 0.00258089 s/step
# field decay(t = 8004.0): 1.8664668257595134e-05 / 0.07671991758429039 = 0.00024328321569283095
# on time step 321020 (time=8025.5), 0.00245447 s/step
# field decay(t = 8054.025000000001): 1.3952573728265791e-05 / 0.07671991758429039 = 0.00018186377367958485
# on time step 322742 (time=8068.55), 0.00232434 s/step
# field decay(t = 8104.05): 1.0378068900887696e-05 / 0.07671991758429039 = 0.00013527215914283997
# on time step 324563 (time=8114.08), 0.0021969 s/step
# field decay(t = 8154.075000000001): 7.680815685498176e-06 / 0.07671991758429039 = 0.00010011501481423572
# on time step 326370 (time=8159.25), 0.00221478 s/step
# on time step 328133 (time=8203.33), 0.00226909 s/step
# field decay(t = 8204.1): 5.656227863525642e-06 / 0.07671991758429039 = 7.372567700312342e-05
# on time step 329962 (time=8249.05), 0.00218719 s/step
# field decay(t = 8254.125): 4.144530116001287e-06 / 0.07671991758429039 = 5.4021566322041315e-05
# on time step 331860 (time=8296.5), 0.00210764 s/step
# field decay(t = 8304.15): 3.0216905999504287e-06 / 0.07671991758429039 = 3.9385999035134096e-05
# on time step 333401 (time=8335.02), 0.0025965 s/step
# field decay(t = 8354.175000000001): 2.192071830756392e-06 / 0.07671991758429039 = 2.857239553663511e-05
# on time step 335230 (time=8380.75), 0.00218835 s/step
# field decay(t = 8404.2): 1.5802254290345273e-06 / 0.07671991758429039 = 2.0597329595647314e-05
# on time step 337038 (time=8425.95), 0.00221246 s/step
# field decay(t = 8454.225): 1.134931664645568e-06 / 0.07671991758429039 = 1.4793181489000493e-05
# on time step 338771 (time=8469.27), 0.00230913 s/step
# field decay(t = 8504.25): 8.110565712994122e-07 / 0.07671991758429039 = 1.0571655925051317e-05
# on time step 340776 (time=8519.4), 0.00199596 s/step
# field decay(t = 8554.275): 5.767137872885713e-07 / 0.07671991758429039 = 7.517132518487773e-06
# on time step 342736 (time=8568.4), 0.00204118 s/step
# field decay(t = 8604.300000000001): 4.0803778409274005e-07 / 0.07671991758429039 = 5.318537831384378e-06
# on time step 344730 (time=8618.25), 0.0020061 s/step
# field decay(t = 8654.325): 2.8725335752212046e-07 / 0.07671991758429039 = 3.7441823005938694e-06
# on time step 346699 (time=8667.48), 0.00203184 s/step
# field decay(t = 8704.35): 2.012156909705168e-07 / 0.07671991758429039 = 2.6227308019386986e-06
# on time step 348673 (time=8716.83), 0.0020266 s/step
# field decay(t = 8754.375): 1.4024511793552592e-07 / 0.07671991758429039 = 1.8280144498518506e-06
# on time step 350480 (time=8762), 0.002214 s/step
# on time step 351887 (time=8797.18), 0.00285395 s/step
# field decay(t = 8804.4): 9.711740191793479e-08 / 0.07671991758429039 = 1.2658694766093062e-06
# on time step 353280 (time=8832), 0.00287244 s/step
# field decay(t = 8854.425000000001): 6.701576177868233e-08 / 0.07671991758429039 = 8.735119104508118e-07
# on time step 354559 (time=8863.98), 0.00312895 s/step
# on time step 355942 (time=8898.55), 0.00289316 s/step
# field decay(t = 8904.45): 4.601273037469885e-08 / 0.07671991758429039 = 5.997494760620113e-07
# on time step 357444 (time=8936.1), 0.00266398 s/step
# field decay(t = 8954.475): 3.1434374419543706e-08 / 0.07671991758429039 = 4.097289909756158e-07
# on time step 358872 (time=8971.8), 0.00280134 s/step
# field decay(t = 9004.5): 2.1367123907423228e-08 / 0.07671991758429039 = 2.7850817076214484e-07
# on time step 360416 (time=9010.4), 0.00259219 s/step
# on time step 361732 (time=9043.3), 0.0030419 s/step
# field decay(t = 9054.525): 1.445256036193993e-08 / 0.07671991758429039 = 1.8838081188058157e-07
# on time step 363245 (time=9081.12), 0.00264484 s/step
# field decay(t = 9104.550000000001): 9.726649953453362e-09 / 0.07671991758429039 = 1.2678128782876907e-07
# on time step 364741 (time=9118.52), 0.00267588 s/step
# field decay(t = 9154.575): 6.513269990768032e-09 / 0.07671991758429039 = 8.489672820114871e-08
# on time step 366221 (time=9155.52), 0.00270659 s/step
# on time step 367771 (time=9194.27), 0.00258143 s/step
# field decay(t = 9204.6): 4.332915931317556e-09 / 0.07671991758429039 = 5.647706707397179e-08
# on time step 369332 (time=9233.3), 0.00256328 s/step
# field decay(t = 9254.625): 2.8726210376685737e-09 / 0.07671991758429039 = 3.744296302863584e-08
# on time step 370893 (time=9272.33), 0.00256288 s/step
# field decay(t = 9304.65): 1.8949563327379085e-09 / 0.07671991758429039 = 2.4699665906913467e-08
# on time step 372340 (time=9308.5), 0.00276469 s/step
# on time step 373783 (time=9344.58), 0.00277559 s/step
# field decay(t = 9354.675000000001): 1.2438831070566815e-09 / 0.07671991758429039 = 1.6213300877051336e-08
# on time step 375374 (time=9384.35), 0.0025222 s/step
# field decay(t = 9404.7): 8.123486077217308e-10 / 0.07671991758429039 = 1.058849687669727e-08
# on time step 376820 (time=9420.5), 0.00276716 s/step
# field decay(t = 9454.725): 5.278251331574183e-10 / 0.07671991758429039 = 6.879897030357327e-09
# on time step 378206 (time=9455.15), 0.00288618 s/step
# on time step 379620 (time=9490.5), 0.00282896 s/step
# field decay(t = 9504.75): 3.4122724582465544e-10 / 0.07671991758429039 = 4.447700891359235e-09
# on time step 380912 (time=9522.8), 0.00310204 s/step
# on time step 382184 (time=9554.6), 0.00316573 s/step
# field decay(t = 9554.775): 2.1956830736800698e-10 / 0.07671991758429039 = 2.8619466011127082e-09
# on time step 383591 (time=9589.77), 0.00285095 s/step
# field decay(t = 9604.800000000001): 1.4032473181947975e-10 / 0.07671991758429039 = 1.8290521710390033e-09
# on time step 385267 (time=9631.68), 0.00238827 s/step
# field decay(t = 9654.825): 8.937840119558227e-11 / 0.07671991758429039 = 1.1649960533049881e-09
# on time step 386715 (time=9667.88), 0.00276541 s/step
# on time step 388099 (time=9702.48), 0.00289168 s/step
# field decay(t = 9704.85): 5.666976634863605e-11 / 0.07671991758429039 = 7.386578105532282e-10
# on time step 389378 (time=9734.45), 0.00312936 s/step
# field decay(t = 9754.875): 3.574201860640162e-11 / 0.07671991758429039 = 4.658766553956825e-10
# on time step 390572 (time=9764.3), 0.00335036 s/step
# on time step 391819 (time=9795.48), 0.00321289 s/step
# field decay(t = 9804.9): 2.2419617967502954e-11 / 0.07671991758429039 = 2.922268254898872e-10
# on time step 393036 (time=9825.9), 0.00328704 s/step
# field decay(t = 9854.925000000001): 1.3981721246063875e-11 / 0.07671991758429039 = 1.8224369480979282e-10
# on time step 394274 (time=9856.85), 0.00323463 s/step
# on time step 395643 (time=9891.08), 0.00292276 s/step
# field decay(t = 9904.95): 8.687582372714677e-12 / 0.07671991758429039 = 1.1323763953695378e-10
# on time step 397004 (time=9925.1), 0.00294034 s/step
# field decay(t = 9954.975): 5.371527302737435e-12 / 0.07671991758429039 = 7.001476893970673e-11
# on time step 398299 (time=9957.48), 0.00308884 s/step
# on time step 399499 (time=9987.48), 0.00333473 s/step
# field decay(t = 10005.0): 3.3003962649350487e-12 / 0.07671991758429039 = 4.3018767079734934e-11
# run 0 finished at t = 10005.0 (400200 timesteps)

# %%
# Main simulation with holes
geometry_holes = [mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)]

hole_positions = generate_waveguide(N, t_1, t_2, r)
for x_position in hole_positions:
    geometry_holes.append(mp.Cylinder(r, height=mp.inf, center=mp.Vector3(x_position, 0, 0), material=mp.air))

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry_holes,  # Geometry with holes
                    sources=sources,
                    resolution=resolution)



# Add flux monitors
refl = sim.add_flux(fcen, df, nfreq, refl_fr)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()

# Load the saved flux data for normalization
sim.load_minus_flux_data(refl, norm_refl_data)

# Run simulation with holes
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Get the reflected and transmitted flux
reflected_flux = mp.get_fluxes(refl)
transmitted_flux = mp.get_fluxes(tran)

# Normalize the transmission and reflection
transmission = np.array(transmitted_flux) / norm_incident_flux
reflection = np.array(reflected_flux) / norm_incident_flux
freqs = np.linspace(fcen - df/2, fcen + df/2, nfreq)

# Plot the transmission and reflection
plt.figure(figsize=(10, 6))
plt.plot(freqs, transmission, label="Transmission")
plt.plot(freqs, reflection, label="Reflection")
plt.xlabel("Frequency (1/μm)")
plt.ylabel("Normalized Flux")
plt.legend()
plt.title("Transmission and Reflection Spectra")
plt.grid(True)
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00160503 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# time for set_epsilon = 2.26759 s
# -----------
# on time step 986 (time=24.65), 0.00408485 s/step
# on time step 1977 (time=49.425), 0.00403658 s/step
# field decay(t = 50.025000000000006): 5.7578974319550705e-18 / 5.7578974319550705e-18 = 1.0
# on time step 3242 (time=81.05), 0.00316355 s/step
# field decay(t = 100.05000000000001): 5.427099593496103e-12 / 5.427099593496103e-12 = 1.0
# on time step 4479 (time=111.975), 0.00323405 s/step
# on time step 5751 (time=143.775), 0.00314724 s/step
# field decay(t = 150.07500000000002): 8.269399685454242e-12 / 8.269399685454242e-12 = 1.0
# on time step 7158 (time=178.95), 0.00284312 s/step
# field decay(t = 200.10000000000002): 1.3430221142465694e-11 / 1.3430221142465694e-11 = 1.0
# on time step 8563 (time=214.075), 0.00284787 s/step
# field decay(t = 250.125): 2.1800897469372855e-11 / 2.1800897469372855e-11 = 1.0
# on time step 10034 (time=250.85), 0.00271975 s/step
# on time step 11083 (time=277.075), 0.00381529 s/step
# field decay(t = 300.15000000000003): 3.517282093590383e-11 / 3.517282093590383e-11 = 1.0
# on time step 12431 (time=310.775), 0.0029682 s/step
# on time step 13678 (time=341.95), 0.00320837 s/step
# field decay(t = 350.175): 5.656618102307704e-11 / 5.656618102307704e-11 = 1.0
# on time step 14889 (time=372.225), 0.0033034 s/step
# field decay(t = 400.20000000000005): 9.04033500426157e-11 / 9.04033500426157e-11 = 1.0
# on time step 16107 (time=402.675), 0.00329278 s/step
# on time step 17619 (time=440.475), 0.00264653 s/step
# field decay(t = 450.225): 1.438489841232242e-10 / 1.438489841232242e-10 = 1.0
# on time step 19138 (time=478.45), 0.00263368 s/step
# field decay(t = 500.25): 2.2772784045620876e-10 / 2.2772784045620876e-10 = 1.0
# on time step 20582 (time=514.55), 0.00277884 s/step
# field decay(t = 550.275): 3.593906790579571e-10 / 3.593906790579571e-10 = 1.0
# on time step 22070 (time=551.75), 0.00268832 s/step
# on time step 23639 (time=590.975), 0.00255062 s/step
# field decay(t = 600.3000000000001): 5.632410203266747e-10 / 5.632410203266747e-10 = 1.0
# on time step 25105 (time=627.625), 0.00273244 s/step
# field decay(t = 650.325): 8.783688528750041e-10 / 8.783688528750041e-10 = 1.0
# on time step 26725 (time=668.125), 0.00246959 s/step
# field decay(t = 700.35): 1.3630313097930153e-09 / 1.3630313097930153e-09 = 1.0
# on time step 28234 (time=705.85), 0.00265187 s/step
# on time step 29738 (time=743.45), 0.0026648 s/step
# field decay(t = 750.375): 2.104446196926826e-09 / 2.104446196926826e-09 = 1.0
# on time step 31116 (time=777.9), 0.00290917 s/step
# field decay(t = 800.4000000000001): 3.233011863451401e-09 / 3.233011863451401e-09 = 1.0
# on time step 32654 (time=816.35), 0.00260091 s/step
# field decay(t = 850.4250000000001): 4.94199924318438e-09 / 4.94199924318438e-09 = 1.0
# on time step 34057 (time=851.425), 0.00285188 s/step
# on time step 35490 (time=887.25), 0.00279141 s/step
# field decay(t = 900.45): 7.516827430005348e-09 / 7.516827430005348e-09 = 1.0
# on time step 36994 (time=924.85), 0.00266014 s/step
# field decay(t = 950.475): 1.1394671483848443e-08 / 1.1394671483848443e-08 = 1.0
# on time step 38476 (time=961.9), 0.00270082 s/step
# on time step 39997 (time=999.925), 0.00263006 s/step
# field decay(t = 1000.5): 1.7158498805520432e-08 / 1.7158498805520432e-08 = 1.0
# on time step 41557 (time=1038.92), 0.00258455 s/step
# field decay(t = 1050.525): 2.57089079684087e-08 / 2.57089079684087e-08 = 1.0
# on time step 43336 (time=1083.4), 0.00224916 s/step
# field decay(t = 1100.55): 3.8328089366713395e-08 / 3.8328089366713395e-08 = 1.0
# on time step 44793 (time=1119.83), 0.00274603 s/step
# field decay(t = 1150.575): 5.685608087960583e-08 / 5.685608087960583e-08 = 1.0
# on time step 46044 (time=1151.1), 0.00319915 s/step
# on time step 47481 (time=1187.03), 0.00279309 s/step
# field decay(t = 1200.6000000000001): 8.391999479670522e-08 / 8.391999479670522e-08 = 1.0
# on time step 49014 (time=1225.35), 0.00261091 s/step
# field decay(t = 1250.625): 1.232488488182272e-07 / 1.232488488182272e-07 = 1.0
# on time step 50593 (time=1264.83), 0.00253471 s/step
# field decay(t = 1300.65): 1.8010611976491246e-07 / 1.8010611976491246e-07 = 1.0
# on time step 52134 (time=1303.35), 0.0025965 s/step
# on time step 53545 (time=1338.62), 0.00283814 s/step
# field decay(t = 1350.6750000000002): 2.622696825914828e-07 / 2.622696825914828e-07 = 1.0
# on time step 54878 (time=1371.95), 0.00300253 s/step
# field decay(t = 1400.7): 3.794390406838426e-07 / 3.794390406838426e-07 = 1.0
# on time step 56182 (time=1404.55), 0.00306751 s/step
# on time step 57588 (time=1439.7), 0.00286052 s/step
# field decay(t = 1450.7250000000001): 5.462157517200228e-07 / 5.462157517200228e-07 = 1.0
# on time step 59033 (time=1475.83), 0.00276818 s/step
# field decay(t = 1500.75): 7.82374798200015e-07 / 7.82374798200015e-07 = 1.0
# on time step 60363 (time=1509.08), 0.00300816 s/step
# on time step 61649 (time=1541.23), 0.00311054 s/step
# field decay(t = 1550.775): 1.115048773651999e-06 / 1.115048773651999e-06 = 1.0
# on time step 62934 (time=1573.35), 0.00311457 s/step
# field decay(t = 1600.8000000000002): 1.581252715453202e-06 / 1.581252715453202e-06 = 1.0
# on time step 64239 (time=1605.98), 0.00306648 s/step
# on time step 65571 (time=1639.28), 0.00300444 s/step
# field decay(t = 1650.825): 2.231192794290742e-06 / 2.231192794290742e-06 = 1.0
# on time step 67098 (time=1677.45), 0.00262021 s/step
# field decay(t = 1700.8500000000001): 3.132574199666469e-06 / 3.132574199666469e-06 = 1.0
# on time step 68644 (time=1716.1), 0.00258757 s/step
# field decay(t = 1750.875): 4.381980521545057e-06 / 4.381980521545057e-06 = 1.0
# on time step 70229 (time=1755.73), 0.00252408 s/step
# on time step 71648 (time=1791.2), 0.0028204 s/step
# field decay(t = 1800.9): 6.090919138134819e-06 / 6.090919138134819e-06 = 1.0
# on time step 72880 (time=1822), 0.00324785 s/step
# field decay(t = 1850.9250000000002): 8.424102863895352e-06 / 8.424102863895352e-06 = 1.0
# on time step 74521 (time=1863.03), 0.00243854 s/step
# on time step 75906 (time=1897.65), 0.00289057 s/step
# field decay(t = 1900.95): 1.1592921267845585e-05 / 1.1592921267845585e-05 = 1.0
# on time step 77223 (time=1930.58), 0.00303922 s/step
# field decay(t = 1950.9750000000001): 1.587415181555539e-05 / 1.587415181555539e-05 = 1.0
# on time step 78635 (time=1965.88), 0.00283379 s/step
# field decay(t = 2001.0): 2.162801090550577e-05 / 2.162801090550577e-05 = 1.0
# on time step 80040 (time=2001), 0.00284946 s/step
# on time step 81342 (time=2033.55), 0.0030734 s/step
# field decay(t = 2051.025): 2.9320477519207594e-05 / 2.9320477519207594e-05 = 1.0
# on time step 82665 (time=2066.62), 0.00302428 s/step
# on time step 83942 (time=2098.55), 0.00313266 s/step
# field decay(t = 2101.05): 3.955067665110994e-05 / 3.955067665110994e-05 = 1.0
# on time step 85322 (time=2133.05), 0.00289917 s/step
# field decay(t = 2151.0750000000003): 5.314618457286458e-05 / 5.314618457286458e-05 = 1.0
# on time step 86533 (time=2163.33), 0.00330557 s/step
# on time step 87718 (time=2192.95), 0.00337567 s/step
# field decay(t = 2201.1): 7.097462496462889e-05 / 7.097462496462889e-05 = 1.0
# on time step 88952 (time=2223.8), 0.00324919 s/step
# field decay(t = 2251.125): 9.431103887439449e-05 / 9.431103887439449e-05 = 1.0
# on time step 90206 (time=2255.15), 0.00319024 s/step
# on time step 91390 (time=2284.75), 0.00337888 s/step
# field decay(t = 2301.15): 0.0001246953786747634 / 0.0001246953786747634 = 1.0
# on time step 92566 (time=2314.15), 0.00340274 s/step
# on time step 93830 (time=2345.75), 0.00317045 s/step
# field decay(t = 2351.175): 0.00016404635822583072 / 0.00016404635822583072 = 1.0
# on time step 94994 (time=2374.85), 0.00343801 s/step
# field decay(t = 2401.2000000000003): 0.00021473915495687614 / 0.00021473915495687614 = 1.0
# on time step 96278 (time=2406.95), 0.00311559 s/step
# on time step 97572 (time=2439.3), 0.00309244 s/step
# field decay(t = 2451.225): 0.0002796947367924844 / 0.0002796947367924844 = 1.0
# on time step 98962 (time=2474.05), 0.00287879 s/step
# field decay(t = 2501.25): 0.00036248142413496 / 0.00036248142413496 = 1.0
# on time step 100287 (time=2507.18), 0.00303092 s/step
# on time step 101683 (time=2542.08), 0.00286628 s/step
# field decay(t = 2551.275): 0.00046789992998965866 / 0.00046789992998965866 = 1.0
# on time step 103038 (time=2575.95), 0.00295296 s/step
# field decay(t = 2601.3): 0.0006003473072018199 / 0.0006003473072018199 = 1.0
# on time step 104426 (time=2610.65), 0.00288276 s/step
# on time step 105696 (time=2642.4), 0.00315243 s/step
# field decay(t = 2651.3250000000003): 0.000766444228105824 / 0.000766444228105824 = 1.0
# on time step 107081 (time=2677.03), 0.00288968 s/step
# field decay(t = 2701.3500000000004): 0.0009736143221029339 / 0.0009736143221029339 = 1.0
# on time step 108518 (time=2712.95), 0.00278529 s/step
# on time step 109870 (time=2746.75), 0.0029593 s/step
# field decay(t = 2751.375): 0.0012306137225776867 / 0.0012306137225776867 = 1.0
# on time step 111236 (time=2780.9), 0.00292892 s/step
# field decay(t = 2801.4): 0.0015476934950234837 / 0.0015476934950234837 = 1.0
# on time step 112502 (time=2812.55), 0.00316036 s/step
# on time step 113953 (time=2848.83), 0.00276618 s/step
# field decay(t = 2851.425): 0.0019367633731736545 / 0.0019367633731736545 = 1.0
# on time step 115329 (time=2883.23), 0.00290749 s/step
# field decay(t = 2901.4500000000003): 0.0024115516700869495 / 0.0024115516700869495 = 1.0
# on time step 116564 (time=2914.1), 0.00324758 s/step
# on time step 118005 (time=2950.12), 0.0027767 s/step
# field decay(t = 2951.4750000000004): 0.00299028660027151 / 0.00299028660027151 = 1.0
# on time step 119372 (time=2984.3), 0.00292781 s/step
# field decay(t = 3001.5): 0.0036862173539855556 / 0.0036862173539855556 = 1.0
# on time step 120622 (time=3015.55), 0.00320299 s/step
# on time step 121921 (time=3048.03), 0.00311029 s/step
# field decay(t = 3051.525): 0.00452144721122818 / 0.00452144721122818 = 1.0
# on time step 123184 (time=3079.6), 0.00316758 s/step
# field decay(t = 3101.55): 0.005518262933760928 / 0.005518262933760928 = 1.0
# on time step 124488 (time=3112.2), 0.00307482 s/step
# on time step 125881 (time=3147.03), 0.00287326 s/step
# field decay(t = 3151.5750000000003): 0.006701248369180772 / 0.006701248369180772 = 1.0
# on time step 127394 (time=3184.85), 0.00264477 s/step
# field decay(t = 3201.6000000000004): 0.008097247940235744 / 0.008097247940235744 = 1.0
# on time step 128773 (time=3219.33), 0.00290258 s/step
# field decay(t = 3251.625): 0.009735260098414232 / 0.009735260098414232 = 1.0
# on time step 130156 (time=3253.9), 0.00289425 s/step
# on time step 131452 (time=3286.3), 0.00311669 s/step
# field decay(t = 3301.65): 0.011646249179753676 / 0.011646249179753676 = 1.0
# on time step 132779 (time=3319.48), 0.00301447 s/step
# field decay(t = 3351.675): 0.013872390344128679 / 0.013872390344128679 = 1.0
# on time step 134361 (time=3359.03), 0.00252888 s/step
# on time step 136028 (time=3400.7), 0.00240285 s/step
# field decay(t = 3401.7000000000003): 0.016430013719536347 / 0.016430013719536347 = 1.0
# on time step 137638 (time=3440.95), 0.00248559 s/step
# field decay(t = 3451.7250000000004): 0.019362121771173666 / 0.019362121771173666 = 1.0
# on time step 139175 (time=3479.38), 0.0026036 s/step
# field decay(t = 3501.75): 0.0227036855524346 / 0.0227036855524346 = 1.0
# on time step 140759 (time=3518.98), 0.00252599 s/step
# field decay(t = 3551.775): 0.026489159194434612 / 0.026489159194434612 = 1.0
# on time step 142338 (time=3558.45), 0.00253444 s/step
# on time step 144036 (time=3600.9), 0.00235584 s/step
# field decay(t = 3601.8): 0.03075164676695589 / 0.03075164676695589 = 1.0
# on time step 145725 (time=3643.12), 0.00236829 s/step
# field decay(t = 3651.8250000000003): 0.03552196438964146 / 0.03552196438964146 = 1.0
# on time step 147440 (time=3686), 0.00233358 s/step
# field decay(t = 3701.8500000000004): 0.04082761061011386 / 0.04082761061011386 = 1.0
# on time step 149022 (time=3725.55), 0.00254417 s/step
# field decay(t = 3751.875): 0.04671626639349003 / 0.04671626639349003 = 1.0
# on time step 150758 (time=3768.95), 0.00230512 s/step
# field decay(t = 3801.9): 0.053158560519939786 / 0.053158560519939786 = 1.0
# on time step 152572 (time=3814.3), 0.00220593 s/step
# field decay(t = 3851.925): 0.060187553226687215 / 0.060187553226687215 = 1.0
# on time step 154342 (time=3858.55), 0.00226064 s/step
# on time step 155986 (time=3899.65), 0.00243331 s/step
# field decay(t = 3901.9500000000003): 0.06780606704325753 / 0.06780606704325753 = 1.0
# on time step 157694 (time=3942.35), 0.00234923 s/step
# field decay(t = 3951.9750000000004): 0.07600791334963718 / 0.07600791334963718 = 1.0
# on time step 159398 (time=3984.95), 0.00234769 s/step
# field decay(t = 4002.0): 0.08477688474256896 / 0.08477688474256896 = 1.0
# on time step 160993 (time=4024.83), 0.00250919 s/step
# field decay(t = 4052.025): 0.094085887331582 / 0.094085887331582 = 1.0
# on time step 162463 (time=4061.58), 0.00272294 s/step
# on time step 163013 (time=4075.33), 0.00730058 s/step
# on time step 163608 (time=4090.2), 0.00679654 s/step
# field decay(t = 4102.05): 0.10389625744844085 / 0.10389625744844085 = 1.0
# on time step 164439 (time=4110.98), 0.00484271 s/step
# on time step 165075 (time=4126.88), 0.00647177 s/step
# on time step 165724 (time=4143.1), 0.00624869 s/step
# field decay(t = 4152.075): 0.11419917413085542 / 0.11419917413085542 = 1.0
# on time step 166352 (time=4158.8), 0.00637045 s/step
# on time step 167550 (time=4188.75), 0.00333945 s/step
# field decay(t = 4202.1): 0.1248494022246086 / 0.1248494022246086 = 1.0
# on time step 168744 (time=4218.6), 0.00335016 s/step
# on time step 169903 (time=4247.57), 0.00345372 s/step
# field decay(t = 4252.125): 0.13581206618571617 / 0.13581206618571617 = 1.0
# on time step 171278 (time=4281.95), 0.00293329 s/step
# field decay(t = 4302.150000000001): 0.14700043837196936 / 0.14700043837196936 = 1.0
# on time step 172550 (time=4313.75), 0.00314496 s/step
# on time step 173925 (time=4348.12), 0.00290964 s/step
# field decay(t = 4352.175): 0.15831690345899813 / 0.15831690345899813 = 1.0
# on time step 175104 (time=4377.6), 0.00339322 s/step
# field decay(t = 4402.2): 0.16965408714946664 / 0.16965408714946664 = 1.0
# on time step 176202 (time=4405.05), 0.00364436 s/step
# on time step 177397 (time=4434.93), 0.00334815 s/step
# field decay(t = 4452.225): 0.18089632695465518 / 0.18089632695465518 = 1.0
# on time step 178569 (time=4464.23), 0.00341371 s/step
# on time step 179652 (time=4491.3), 0.00369596 s/step
# field decay(t = 4502.25): 0.1919214659400415 / 0.1919214659400415 = 1.0
# on time step 180710 (time=4517.75), 0.00378146 s/step
# on time step 181871 (time=4546.78), 0.00344544 s/step
# field decay(t = 4552.275000000001): 0.20264480026434756 / 0.20264480026434756 = 1.0
# on time step 183104 (time=4577.6), 0.00324579 s/step
# field decay(t = 4602.3): 0.21285180735883136 / 0.21285180735883136 = 1.0
# on time step 184454 (time=4611.35), 0.0029648 s/step
# on time step 185745 (time=4643.62), 0.00310802 s/step
# field decay(t = 4652.325): 0.2224577801164067 / 0.2224577801164067 = 1.0
# on time step 187003 (time=4675.07), 0.00318259 s/step
# field decay(t = 4702.35): 0.23133760470526787 / 0.23133760470526787 = 1.0
# on time step 188175 (time=4704.38), 0.00341476 s/step
# on time step 189490 (time=4737.25), 0.0030441 s/step
# field decay(t = 4752.375): 0.23937194448503593 / 0.23937194448503593 = 1.0
# on time step 190601 (time=4765.03), 0.00360428 s/step
# on time step 191944 (time=4798.6), 0.00300233 s/step
# field decay(t = 4802.400000000001): 0.24644989524275798 / 0.24644989524275798 = 1.0
# on time step 193159 (time=4828.98), 0.00329221 s/step
# field decay(t = 4852.425): 0.25247152558963926 / 0.25247152558963926 = 1.0
# on time step 194365 (time=4859.12), 0.00332066 s/step
# on time step 195569 (time=4889.23), 0.00332937 s/step
# field decay(t = 4902.45): 0.25735022141683433 / 0.25735022141683433 = 1.0
# on time step 196838 (time=4920.95), 0.0031527 s/step
# on time step 198080 (time=4952), 0.00322225 s/step
# field decay(t = 4952.475): 0.2610268991988997 / 0.2610268991988997 = 1.0
# on time step 199172 (time=4979.3), 0.00366302 s/step
# field decay(t = 5002.5): 0.2634180123351917 / 0.2634180123351917 = 1.0
# on time step 200334 (time=5008.35), 0.00345684 s/step
# on time step 201487 (time=5037.18), 0.00347187 s/step
# field decay(t = 5052.525000000001): 0.2645050971999281 / 0.2645050971999281 = 1.0
# on time step 202686 (time=5067.15), 0.00333778 s/step
# on time step 203794 (time=5094.85), 0.00361279 s/step
# field decay(t = 5102.55): 0.2645743614512667 / 0.2645743614512667 = 1.0
# on time step 204945 (time=5123.62), 0.00347596 s/step
# field decay(t = 5152.575000000001): 0.2642683191435125 / 0.2645743614512667 = 0.9988432654393439
# on time step 206366 (time=5159.15), 0.00281569 s/step
# on time step 207810 (time=5195.25), 0.00277177 s/step
# field decay(t = 5202.6): 0.2627131048521509 / 0.2645743614512667 = 0.9929650908390885
# on time step 209331 (time=5233.28), 0.00263044 s/step
# field decay(t = 5252.625): 0.2598643730876377 / 0.2645743614512667 = 0.9821978655157916
# on time step 210784 (time=5269.6), 0.00275511 s/step
# field decay(t = 5302.650000000001): 0.25576441384186616 / 0.2645743614512667 = 0.9667014310794309
# on time step 212268 (time=5306.7), 0.0026961 s/step
# on time step 213652 (time=5341.3), 0.00289051 s/step
# field decay(t = 5352.675): 0.2504735452182744 / 0.2645743614512667 = 0.9467037691949997
# on time step 215146 (time=5378.65), 0.00267766 s/step
# field decay(t = 5402.700000000001): 0.24404089875745077 / 0.2645743614512667 = 0.92239058017117
# on time step 216598 (time=5414.95), 0.00275604 s/step
# on time step 217981 (time=5449.53), 0.00289274 s/step
# field decay(t = 5452.725): 0.23660962644642797 / 0.2645743614512667 = 0.8943029292353042
# on time step 219245 (time=5481.12), 0.00316576 s/step
# field decay(t = 5502.75): 0.22826039830814254 / 0.2645743614512667 = 0.8627457213014458
# on time step 220432 (time=5510.8), 0.0033758 s/step
# on time step 221483 (time=5537.08), 0.00380676 s/step
# field decay(t = 5552.775000000001): 0.21910742629898036 / 0.2645743614512667 = 0.8281506382444349
# on time step 222581 (time=5564.53), 0.00364404 s/step
# on time step 223659 (time=5591.48), 0.00371148 s/step
# field decay(t = 5602.8): 0.20927241659800352 / 0.2645743614512667 = 0.7909776875207557
# on time step 224792 (time=5619.8), 0.00353256 s/step
# on time step 226046 (time=5651.15), 0.00319063 s/step
# field decay(t = 5652.825000000001): 0.19888189322619088 / 0.2645743614512667 = 0.7517050863706759
# on time step 227121 (time=5678.03), 0.00372175 s/step
# field decay(t = 5702.85): 0.18806451791098128 / 0.2645743614512667 = 0.7108191318289238
# on time step 228174 (time=5704.35), 0.00379915 s/step
# on time step 229352 (time=5733.8), 0.00339643 s/step
# field decay(t = 5752.875): 0.17694848436846192 / 0.2645743614512667 = 0.6688043520084426
# on time step 230667 (time=5766.68), 0.00304332 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 28
#      25 sim.load_minus_flux_data(refl, norm_refl_data)
#      27 # Run simulation with holes
# ---> 28 sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))
#      30 eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
#      31 ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:4530, in Simulation.run(self, *step_funcs, **kwargs)
#    4527     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4529 if until_after_sources is not None:
# -> 4530     self._run_sources_until(until_after_sources, step_funcs)
#    4531 elif until is not None:
#    4532     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2871, in Simulation._run_sources_until(self, cond, step_funcs)
#    2867             return cond[i](sim) and sim.round_time() >= ts
#    2869         new_conds.append(f)
# -> 2871 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2829, in Simulation._run_until(self, cond, step_funcs)
#    2827     for func in step_funcs:
#    2828         _eval_step_func(self, func, "step")
# -> 2829     self.fields.step()
#    2831 # Translating the recursive scheme version of run-until into an iterative version
#    2832 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2833 # be the same as scheme.
#    2834 for func in step_funcs:
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/__init__.py:3040, in fields.step(self)
#    3039 def step(self):
# -> 3040     return _meep.fields_step(self)
#
# KeyboardInterrupt:

# %%
# Source
sources = [mp.Source(mp.GaussianSource(wavelength=wl, fwidth=df),
                     component=mp.Ey,
                     center=mp.Vector3(-0.5 * sx + dpml),
                     size=mp.Vector3(0, w, 0))]

# Normalization run simulation
norm_sim = mp.Simulation(cell_size=cell,
                         boundary_layers=pml_layers,
                         geometry=[mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)],  # No holes for normalization
                         sources=sources,
                         resolution=resolution)



# Flux monitors
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5 * sx + dpml + 0.5), size=mp.Vector3(0, 2*w, 0))
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5 * sx - dpml - 0.5), size=mp.Vector3(0, 2*w, 0))


# Add flux monitors
norm_refl = norm_sim.add_flux(fcen, df, nfreq, refl_fr)
norm_tran = norm_sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
norm_sim.plot2D()
plt.show()

# Run normalization simulation
norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ey)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Save flux for normalization
norm_refl_data = norm_sim.get_flux_data(norm_refl)
norm_tran_data = norm_sim.get_flux_data(norm_tran)

# Calculate the incident power for normalization
norm_refl_flux = mp.get_fluxes(norm_refl)
norm_tran_flux = mp.get_fluxes(norm_tran)
norm_incident_flux = np.array(norm_refl_flux) + np.array(norm_tran_flux)

# Reset simulation for main run with holes
norm_sim.reset_meep()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000266075 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# time for set_epsilon = 0.259158 s
# -----------
# on time step 5447 (time=136.175), 0.000734411 s/step
# on time step 11038 (time=275.95), 0.000715525 s/step
# on time step 16425 (time=410.625), 0.000742649 s/step
# on time step 21263 (time=531.575), 0.000826909 s/step
# on time step 26453 (time=661.325), 0.000770717 s/step
# on time step 31652 (time=791.3), 0.000769477 s/step
# on time step 36921 (time=923.025), 0.000759229 s/step
# on time step 41537 (time=1038.42), 0.000866689 s/step
# on time step 46343 (time=1158.58), 0.00083234 s/step
# on time step 51192 (time=1279.8), 0.000825027 s/step
# on time step 56217 (time=1405.43), 0.000796033 s/step
# on time step 61517 (time=1537.93), 0.000754792 s/step
# on time step 66505 (time=1662.62), 0.000802042 s/step
# on time step 71588 (time=1789.7), 0.000787008 s/step
# on time step 76460 (time=1911.5), 0.000821048 s/step
# on time step 81340 (time=2033.5), 0.000819758 s/step
# on time step 86274 (time=2156.85), 0.000810814 s/step
# on time step 91141 (time=2278.53), 0.000821944 s/step
# on time step 95903 (time=2397.58), 0.000840139 s/step
# on time step 100658 (time=2516.45), 0.000841274 s/step
# on time step 105669 (time=2641.73), 0.000798255 s/step
# on time step 110724 (time=2768.1), 0.000791435 s/step
# on time step 115659 (time=2891.48), 0.000810578 s/step
# on time step 120678 (time=3016.95), 0.000797065 s/step
# on time step 125597 (time=3139.93), 0.000813312 s/step
# on time step 130526 (time=3263.15), 0.000811591 s/step
# on time step 135644 (time=3391.1), 0.000781689 s/step
# on time step 140840 (time=3521), 0.000769885 s/step
# on time step 145410 (time=3635.25), 0.000875391 s/step
# on time step 149886 (time=3747.15), 0.000893727 s/step
# on time step 154555 (time=3863.88), 0.000856751 s/step
# on time step 159639 (time=3990.98), 0.000786802 s/step
# on time step 164877 (time=4121.93), 0.00076376 s/step
# on time step 170187 (time=4254.68), 0.000753306 s/step
# on time step 175557 (time=4388.93), 0.000744964 s/step
# on time step 180703 (time=4517.57), 0.000777356 s/step
# on time step 185952 (time=4648.8), 0.000762093 s/step
# on time step 190930 (time=4773.25), 0.000803561 s/step
# on time step 196140 (time=4903.5), 0.000767948 s/step
# on time step 201293 (time=5032.33), 0.000776345 s/step
# on time step 206679 (time=5166.98), 0.000742698 s/step
# on time step 212104 (time=5302.6), 0.000737414 s/step
# on time step 217443 (time=5436.08), 0.000749297 s/step
# on time step 222386 (time=5559.65), 0.000809316 s/step
# on time step 227193 (time=5679.83), 0.00083213 s/step
# on time step 230596 (time=5764.9), 0.00117558 s/step
# on time step 234369 (time=5859.23), 0.00106033 s/step
# on time step 238674 (time=5966.85), 0.00092919 s/step
# on time step 243464 (time=6086.6), 0.000835156 s/step
# on time step 248323 (time=6208.08), 0.000823251 s/step
# on time step 253078 (time=6326.95), 0.000841236 s/step
# on time step 258179 (time=6454.48), 0.000784243 s/step
# on time step 262176 (time=6554.4), 0.00100088 s/step
# on time step 266780 (time=6669.5), 0.000868964 s/step
# on time step 271517 (time=6787.93), 0.000844432 s/step
# on time step 276120 (time=6903), 0.00086906 s/step
# on time step 281218 (time=7030.45), 0.000784738 s/step
# on time step 286258 (time=7156.45), 0.000793745 s/step
# on time step 290939 (time=7273.48), 0.000854525 s/step
# on time step 294860 (time=7371.5), 0.00102021 s/step
# on time step 299450 (time=7486.25), 0.0008716 s/step
# on time step 303719 (time=7592.98), 0.000937138 s/step
# on time step 307921 (time=7698.03), 0.000952106 s/step
# on time step 312286 (time=7807.15), 0.000916426 s/step
# on time step 316367 (time=7909.18), 0.000980174 s/step
# on time step 321043 (time=8026.08), 0.000855499 s/step
# on time step 325495 (time=8137.38), 0.000898642 s/step
# on time step 329818 (time=8245.45), 0.000925388 s/step
# on time step 334337 (time=8358.43), 0.000885296 s/step
# on time step 338058 (time=8451.45), 0.00107524 s/step
# on time step 341712 (time=8542.8), 0.00109479 s/step
# on time step 345590 (time=8639.75), 0.00103167 s/step
# on time step 349605 (time=8740.12), 0.000996433 s/step
# on time step 354141 (time=8853.52), 0.00088192 s/step
# on time step 358757 (time=8968.93), 0.000866617 s/step
# on time step 363562 (time=9089.05), 0.000832582 s/step
# on time step 368439 (time=9210.98), 0.000820245 s/step
# on time step 373273 (time=9331.83), 0.000827628 s/step
# on time step 377695 (time=9442.38), 0.000904677 s/step
# on time step 382221 (time=9555.52), 0.000883851 s/step
# on time step 386688 (time=9667.2), 0.000895462 s/step
# on time step 390319 (time=9757.98), 0.00110176 s/step
# on time step 394924 (time=9873.1), 0.000868624 s/step
# on time step 399520 (time=9988), 0.000870394 s/step
# run 0 finished at t = 10005.0 (400200 timesteps)

# %%
# Main simulation with holes
geometry_holes = [mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)]

hole_positions = generate_waveguide(N, t_1, t_2, r)
for x_position in hole_positions:
    geometry_holes.append(mp.Cylinder(r, height=mp.inf, center=mp.Vector3(x_position, 0, 0), material=mp.air))

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry_holes,  # Geometry with holes
                    sources=sources,
                    resolution=resolution)



# Add flux monitors
refl = sim.add_flux(fcen, df, nfreq, refl_fr)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()

# Load the saved flux data for normalization
sim.load_minus_flux_data(refl, norm_refl_data)

# Run simulation with holes
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ey)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Get the reflected and transmitted flux
reflected_flux = mp.get_fluxes(refl)
transmitted_flux = mp.get_fluxes(tran)

# Normalize the transmission and reflection
transmission = np.array(transmitted_flux) / norm_incident_flux
reflection = np.array(reflected_flux) / norm_incident_flux
freqs = np.linspace(fcen - df/2, fcen + df/2, nfreq)

# Plot the transmission and reflection
plt.figure(figsize=(10, 6))
plt.plot(freqs, transmission, label="Transmission")
plt.plot(freqs, reflection, label="Reflection")
plt.xlabel("Frequency (1/μm)")
plt.ylabel("Normalized Flux")
plt.legend()
plt.title("Transmission and Reflection Spectra")
plt.grid(True)
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00166583 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# time for set_epsilon = 0.735281 s
# -----------
# on time step 3163 (time=79.075), 0.00126493 s/step
# on time step 6486 (time=162.15), 0.00120376 s/step
# on time step 9421 (time=235.525), 0.0013631 s/step
# on time step 12336 (time=308.4), 0.00137234 s/step
# on time step 15629 (time=390.725), 0.00121487 s/step
# on time step 18917 (time=472.925), 0.00121661 s/step
# on time step 22287 (time=557.175), 0.00118713 s/step
# on time step 25570 (time=639.25), 0.00121846 s/step
# on time step 28734 (time=718.35), 0.00126453 s/step
# on time step 31883 (time=797.075), 0.00127029 s/step
# on time step 34998 (time=874.95), 0.00128419 s/step
# on time step 38012 (time=950.3), 0.00132735 s/step
# on time step 41009 (time=1025.23), 0.00133475 s/step
# on time step 44320 (time=1108), 0.00120816 s/step
# on time step 47178 (time=1179.45), 0.00139965 s/step
# on time step 50118 (time=1252.95), 0.00136094 s/step
# on time step 53178 (time=1329.45), 0.00130725 s/step
# on time step 56517 (time=1412.93), 0.00119807 s/step
# on time step 59843 (time=1496.08), 0.00120292 s/step
# on time step 63137 (time=1578.43), 0.00121446 s/step
# on time step 66447 (time=1661.18), 0.00120877 s/step
# on time step 69453 (time=1736.33), 0.00133076 s/step
# on time step 72292 (time=1807.3), 0.00140911 s/step
# on time step 75137 (time=1878.43), 0.00140624 s/step
# on time step 78197 (time=1954.93), 0.00130721 s/step
# on time step 81270 (time=2031.75), 0.00130223 s/step
# on time step 84273 (time=2106.83), 0.00133227 s/step
# on time step 87044 (time=2176.1), 0.00144361 s/step
# on time step 89970 (time=2249.25), 0.0013674 s/step
# on time step 93177 (time=2329.43), 0.00124756 s/step
# on time step 96037 (time=2400.93), 0.00139893 s/step
# on time step 98930 (time=2473.25), 0.00138282 s/step
# on time step 102278 (time=2556.95), 0.00119506 s/step
# on time step 105391 (time=2634.78), 0.00128512 s/step
# on time step 108549 (time=2713.73), 0.00126665 s/step
# on time step 111487 (time=2787.18), 0.00136179 s/step
# on time step 114672 (time=2866.8), 0.0012561 s/step
# on time step 117645 (time=2941.12), 0.00134585 s/step
# on time step 120854 (time=3021.35), 0.00124665 s/step
# on time step 124100 (time=3102.5), 0.00123251 s/step
# on time step 127446 (time=3186.15), 0.00119552 s/step
# on time step 130790 (time=3269.75), 0.00119626 s/step
# on time step 134061 (time=3351.53), 0.00122295 s/step
# on time step 136765 (time=3419.12), 0.00147954 s/step
# on time step 139828 (time=3495.7), 0.00130628 s/step
# on time step 142831 (time=3570.78), 0.00133204 s/step
# on time step 145883 (time=3647.08), 0.00131081 s/step
# on time step 149028 (time=3725.7), 0.00127196 s/step
# on time step 152235 (time=3805.88), 0.00124742 s/step
# on time step 155569 (time=3889.23), 0.00120005 s/step
# on time step 158470 (time=3961.75), 0.00137884 s/step
# on time step 161661 (time=4041.53), 0.00125366 s/step
# on time step 164970 (time=4124.25), 0.001209 s/step
# on time step 168170 (time=4204.25), 0.00125017 s/step
# on time step 171063 (time=4276.57), 0.00138307 s/step
# on time step 174206 (time=4355.15), 0.00127297 s/step
# on time step 177228 (time=4430.7), 0.00132363 s/step
# on time step 180438 (time=4510.95), 0.00124637 s/step
# on time step 183628 (time=4590.7), 0.00125428 s/step
# on time step 186692 (time=4667.3), 0.00130568 s/step
# on time step 189626 (time=4740.65), 0.00136364 s/step
# on time step 192611 (time=4815.28), 0.0013402 s/step
# on time step 195755 (time=4893.88), 0.0012726 s/step
# on time step 198982 (time=4974.55), 0.00123965 s/step
# on time step 202130 (time=5053.25), 0.00127083 s/step
# on time step 205354 (time=5133.85), 0.00124085 s/step
# on time step 208230 (time=5205.75), 0.00139086 s/step
# on time step 211380 (time=5284.5), 0.00127022 s/step
# on time step 214324 (time=5358.1), 0.0013587 s/step
# on time step 217244 (time=5431.1), 0.00137004 s/step
# on time step 220254 (time=5506.35), 0.00132906 s/step
# on time step 223241 (time=5581.03), 0.00133927 s/step
# on time step 226369 (time=5659.23), 0.00127889 s/step
# on time step 229545 (time=5738.62), 0.00125951 s/step
# on time step 232382 (time=5809.55), 0.00141016 s/step
# on time step 235473 (time=5886.83), 0.00129409 s/step
# on time step 238635 (time=5965.88), 0.00126549 s/step
# on time step 242525 (time=6063.12), 0.00102829 s/step
# on time step 247041 (time=6176.03), 0.000885775 s/step
# on time step 251636 (time=6290.9), 0.000870534 s/step
# on time step 256152 (time=6403.8), 0.000885815 s/step
# on time step 260555 (time=6513.88), 0.000908657 s/step
# on time step 265237 (time=6630.93), 0.000854389 s/step
# on time step 269671 (time=6741.78), 0.000902278 s/step
# on time step 274295 (time=6857.38), 0.000865195 s/step
# on time step 278835 (time=6970.88), 0.000881124 s/step
# on time step 283431 (time=7085.78), 0.000870374 s/step
# on time step 288232 (time=7205.8), 0.000833291 s/step
# on time step 293105 (time=7327.62), 0.000820899 s/step
# on time step 297933 (time=7448.33), 0.00082859 s/step
# on time step 302659 (time=7566.48), 0.00084649 s/step
# on time step 306901 (time=7672.53), 0.000943124 s/step
# on time step 311701 (time=7792.53), 0.000833476 s/step
# on time step 316720 (time=7918), 0.000797119 s/step
# on time step 321621 (time=8040.53), 0.000816287 s/step
# on time step 326591 (time=8164.78), 0.00080498 s/step
# on time step 330860 (time=8271.5), 0.000937029 s/step
# on time step 335646 (time=8391.15), 0.000835914 s/step
# on time step 340523 (time=8513.08), 0.000820192 s/step
# on time step 345520 (time=8638), 0.000800566 s/step
# on time step 350410 (time=8760.25), 0.000818064 s/step
# on time step 355353 (time=8883.83), 0.00080925 s/step
# on time step 360281 (time=9007.02), 0.000811797 s/step
# on time step 365232 (time=9130.8), 0.000808053 s/step
# on time step 370146 (time=9253.65), 0.000814055 s/step
# on time step 375184 (time=9379.6), 0.000793973 s/step
# on time step 380287 (time=9507.18), 0.000783868 s/step
# on time step 385481 (time=9637.02), 0.000770143 s/step
# on time step 390673 (time=9766.83), 0.000770489 s/step
# on time step 395919 (time=9897.98), 0.00076257 s/step
# run 0 finished at t = 10005.0 (400200 timesteps)
