# %%
#!/usr/bin/env python
# coding: utf-8
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_waveguide(N, intra_pair_spacing, inter_pair_spacing, radius):
        # Adjust spacings to include the diameters of the circles
        adjusted_intra_pair_spacing = intra_pair_spacing + 2 * radius
        adjusted_inter_pair_spacing = inter_pair_spacing + 2 * radius
        
        # Generate the list with adjusted spacings
        result = [0]
        for i in range(1, N):
            if i % 2 == 1:  # If it's an odd index, use adjusted intra-pair spacing
                next_value = result[-1] + adjusted_intra_pair_spacing
            else:  # For even indices, use adjusted inter-pair spacing
                next_value = result[-1] + adjusted_inter_pair_spacing
            result.append(next_value)
        
        # Find the center value
        if N % 2 == 1:
            center_value = result[len(result) // 2]
        else:
            center_value = (result[(len(result) // 2) - 1] + result[len(result) // 2]) / 2
        
        # Shift the list so the center value is at 0
        shifted_result = [x - center_value for x in result]
        
        return shifted_result

# %%
# Material definitions
n_SiO2 = 1.45  # Refractive index of SiO2
eps_SiO2 = n_SiO2**2  # Dielectric constant of SiO2

resolution = 20  # pixels/um
w = 2  # width of waveguide in um
r = 0.5  # radius of holes in um
t_1 = 1  # intra-pair spacing
t_2 = 2  # inter-pair spacing (defect spacing, ordinary spacing = 1)
sy = 10  # size of cell in y direction (perpendicular to waveguide), in um
pad = 7  # padding between last hole and PML edge, in um
dpml = 1  # PML thickness, in um
N = 15  # number of holes

# %%
wl = 1    # source wavelength (in μm)
fcen = 1/wl  # pulse center frequency (in 1/μm)
df = 0.001  # pulse width (in frequency, in 1/μm)
nfreq = 500  # number of frequency points to compute flux

# %%
# Calculate the size of the cell in the x direction
if N % 2 == 0:
    sx = 2 * (pad + dpml + N // 2 + 2 * N // 2) - 20
else:
    sx = 2 * (pad + dpml + (N + 1) // 2 + 2 * (N + 1) // 2) - 20


cell = mp.Vector3(sx, sy, 0)
pml_layers = [mp.PML(dpml)]

# Define the waveguide material
SiO2_material = mp.Medium(epsilon=eps_SiO2)


# Source
sources = [mp.Source(mp.GaussianSource(wavelength=wl, fwidth=df),
                     component=mp.Ez,
                     center=mp.Vector3(-0.5 * sx + dpml),
                     size=mp.Vector3(0, w, 0))]

# Normalization run simulation
norm_sim = mp.Simulation(cell_size=cell,
                         boundary_layers=pml_layers,
                         geometry=[mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)],  # No holes for normalization
                         sources=sources,
                         resolution=resolution)

# Flux monitors
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5 * sx + dpml + 0.5), size=mp.Vector3(0, 2*w, 0))
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5 * sx - dpml - 0.5), size=mp.Vector3(0, 2*w, 0))


# Add flux monitors
norm_refl = norm_sim.add_flux(fcen, df, nfreq, refl_fr)
norm_tran = norm_sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
norm_sim.plot2D()
plt.show()

# Run normalization simulation
norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Save flux for normalization
norm_refl_data = norm_sim.get_flux_data(norm_refl)
norm_tran_data = norm_sim.get_flux_data(norm_tran)

# Calculate the incident power for normalization
norm_refl_flux = mp.get_fluxes(norm_refl)
norm_tran_flux = mp.get_fluxes(norm_tran)
norm_incident_flux = np.array(norm_refl_flux) + np.array(norm_tran_flux)

# Reset simulation for main run with holes
norm_sim.reset_meep()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0762551 s
# Working in 2D dimensions.
# Computational cell is 44 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# time for set_epsilon = 0.892455 s
# -----------
# on time step 1196 (time=29.9), 0.00334489 s/step
# field decay(t = 50.025000000000006): 1.2904399841634256e-17 / 1.2904399841634256e-17 = 1.0
# on time step 2563 (time=64.075), 0.00297038 s/step
# on time step 3690 (time=92.25), 0.00354937 s/step
# field decay(t = 100.05000000000001): 4.40050923509865e-12 / 4.40050923509865e-12 = 1.0
# on time step 4791 (time=119.775), 0.0036338 s/step
# field decay(t = 150.07500000000002): 7.217280328538401e-12 / 7.217280328538401e-12 = 1.0
# on time step 6067 (time=151.675), 0.00314557 s/step
# on time step 7415 (time=185.375), 0.00296869 s/step
# field decay(t = 200.10000000000002): 1.1710712829685955e-11 / 1.1710712829685955e-11 = 1.0
# on time step 8835 (time=220.875), 0.00281777 s/step
# field decay(t = 250.125): 1.8696349286156955e-11 / 1.8696349286156955e-11 = 1.0
# on time step 10242 (time=256.05), 0.00284402 s/step
# on time step 11588 (time=289.7), 0.00297231 s/step
# field decay(t = 300.15000000000003): 3.034176194759502e-11 / 3.034176194759502e-11 = 1.0
# on time step 12968 (time=324.2), 0.00289997 s/step
# field decay(t = 350.175): 4.8584561846709556e-11 / 4.8584561846709556e-11 = 1.0
# on time step 14078 (time=351.95), 0.0036041 s/step
# on time step 15256 (time=381.4), 0.00339572 s/step
# field decay(t = 400.20000000000005): 7.751364463352526e-11 / 7.751364463352526e-11 = 1.0
# on time step 16527 (time=413.175), 0.00314785 s/step
# on time step 17576 (time=439.4), 0.00381771 s/step
# field decay(t = 450.225): 1.2316055639675848e-10 / 1.2316055639675848e-10 = 1.0
# on time step 18887 (time=472.175), 0.00305273 s/step
# field decay(t = 500.25): 1.950165494060855e-10 / 1.950165494060855e-10 = 1.0
# on time step 20195 (time=504.875), 0.00305823 s/step
# on time step 21489 (time=537.225), 0.00309273 s/step
# field decay(t = 550.275): 3.067283830236344e-10 / 3.067283830236344e-10 = 1.0
# on time step 22951 (time=573.775), 0.00273621 s/step
# field decay(t = 600.3000000000001): 4.806779224712259e-10 / 4.806779224712259e-10 = 1.0
# on time step 24450 (time=611.25), 0.00266881 s/step
# on time step 25910 (time=647.75), 0.00273984 s/step
# field decay(t = 650.325): 7.478717673164084e-10 / 7.478717673164084e-10 = 1.0
# on time step 27076 (time=676.9), 0.00343114 s/step
# field decay(t = 700.35): 1.16125923658437e-09 / 1.16125923658437e-09 = 1.0
# on time step 28436 (time=710.9), 0.00294505 s/step
# on time step 29652 (time=741.3), 0.00329049 s/step
# field decay(t = 750.375): 1.799414139974168e-09 / 1.799414139974168e-09 = 1.0
# on time step 30976 (time=774.4), 0.00302401 s/step
# field decay(t = 800.4000000000001): 2.7627573686878063e-09 / 2.7627573686878063e-09 = 1.0
# on time step 32219 (time=805.475), 0.00321905 s/step
# on time step 33690 (time=842.25), 0.00271958 s/step
# field decay(t = 850.4250000000001): 4.2175595777923234e-09 / 4.2175595777923234e-09 = 1.0
# on time step 35302 (time=882.55), 0.0024823 s/step
# field decay(t = 900.45): 6.411612325833523e-09 / 6.411612325833523e-09 = 1.0
# on time step 36798 (time=919.95), 0.00267421 s/step
# field decay(t = 950.475): 9.698114919796252e-09 / 9.698114919796252e-09 = 1.0
# on time step 38267 (time=956.675), 0.00272371 s/step
# on time step 39835 (time=995.875), 0.00255168 s/step
# field decay(t = 1000.5): 1.4595918722036617e-08 / 1.4595918722036617e-08 = 1.0
# on time step 41339 (time=1033.48), 0.00265995 s/step
# field decay(t = 1050.525): 2.1857350744330028e-08 / 2.1857350744330028e-08 = 1.0
# on time step 42890 (time=1072.25), 0.00258167 s/step
# field decay(t = 1100.55): 3.2561953509731304e-08 / 3.2561953509731304e-08 = 1.0
# on time step 44395 (time=1109.88), 0.00265824 s/step
# field decay(t = 1150.575): 4.8269373467319734e-08 / 4.8269373467319734e-08 = 1.0
# on time step 46030 (time=1150.75), 0.00244665 s/step
# on time step 47448 (time=1186.2), 0.00282154 s/step
# field decay(t = 1200.6000000000001): 7.12010933012926e-08 / 7.12010933012926e-08 = 1.0
# on time step 48902 (time=1222.55), 0.00275147 s/step
# field decay(t = 1250.625): 1.0449956250865245e-07 / 1.0449956250865245e-07 = 1.0
# on time step 50274 (time=1256.85), 0.00291641 s/step
# on time step 51722 (time=1293.05), 0.00276285 s/step
# field decay(t = 1300.65): 1.5260920070676402e-07 / 1.5260920070676402e-07 = 1.0
# on time step 53307 (time=1332.68), 0.00252466 s/step
# field decay(t = 1350.6750000000002): 2.2175631889274055e-07 / 2.2175631889274055e-07 = 1.0
# on time step 54900 (time=1372.5), 0.0025111 s/step
# field decay(t = 1400.7): 3.206180612901781e-07 / 3.206180612901781e-07 = 1.0
# on time step 56437 (time=1410.93), 0.00260346 s/step
# field decay(t = 1450.7250000000001): 4.61257515622699e-07 / 4.61257515622699e-07 = 1.0
# on time step 58132 (time=1453.3), 0.0023609 s/step
# on time step 59891 (time=1497.28), 0.00227454 s/step
# field decay(t = 1500.75): 6.6026733698549e-07 / 6.6026733698549e-07 = 1.0
# on time step 61488 (time=1537.2), 0.00250684 s/step
# field decay(t = 1550.775): 9.404409189894241e-07 / 9.404409189894241e-07 = 1.0
# on time step 62517 (time=1562.93), 0.003888 s/step
# on time step 64020 (time=1600.5), 0.00266158 s/step
# field decay(t = 1600.8000000000002): 1.3328177429376354e-06 / 1.3328177429376354e-06 = 1.0
# on time step 65507 (time=1637.68), 0.00269055 s/step
# field decay(t = 1650.825): 1.879502158180331e-06 / 1.879502158180331e-06 = 1.0
# on time step 67069 (time=1676.73), 0.00256142 s/step
# field decay(t = 1700.8500000000001): 2.6371694504216283e-06 / 2.6371694504216283e-06 = 1.0
# on time step 68666 (time=1716.65), 0.00250572 s/step
# field decay(t = 1750.875): 3.6940366461093302e-06 / 3.6940366461093302e-06 = 1.0
# on time step 70359 (time=1758.98), 0.00236296 s/step
# on time step 71570 (time=1789.25), 0.00330385 s/step
# field decay(t = 1800.9): 5.131359040342493e-06 / 5.131359040342493e-06 = 1.0
# on time step 72826 (time=1820.65), 0.0031848 s/step
# field decay(t = 1850.9250000000002): 7.092385576382565e-06 / 7.092385576382565e-06 = 1.0
# on time step 74210 (time=1855.25), 0.00290132 s/step
# on time step 75578 (time=1889.45), 0.00292504 s/step
# field decay(t = 1900.95): 9.753913815859354e-06 / 9.753913815859354e-06 = 1.0
# on time step 77114 (time=1927.85), 0.00260456 s/step
# field decay(t = 1950.9750000000001): 1.3347388764578041e-05 / 1.3347388764578041e-05 = 1.0
# on time step 78406 (time=1960.15), 0.00309694 s/step
# on time step 79694 (time=1992.35), 0.0031059 s/step
# field decay(t = 2001.0): 1.8173684932732703e-05 / 1.8173684932732703e-05 = 1.0
# on time step 81030 (time=2025.75), 0.0029946 s/step
# field decay(t = 2051.025): 2.462160857325152e-05 / 2.462160857325152e-05 = 1.0
# on time step 82296 (time=2057.4), 0.0031599 s/step
# on time step 83860 (time=2096.5), 0.0025581 s/step
# field decay(t = 2101.05): 3.319091543682239e-05 / 3.319091543682239e-05 = 1.0
# on time step 85454 (time=2136.35), 0.00251014 s/step
# field decay(t = 2151.0750000000003): 4.451939381961609e-05 / 4.451939381961609e-05 = 1.0
# on time step 87075 (time=2176.88), 0.00246851 s/step
# field decay(t = 2201.1): 5.9416856668033727e-05 / 5.9416856668033727e-05 = 1.0
# on time step 88605 (time=2215.12), 0.00261494 s/step
# on time step 89875 (time=2246.88), 0.0031497 s/step
# field decay(t = 2251.125): 7.890374727311387e-05 / 7.890374727311387e-05 = 1.0
# on time step 91405 (time=2285.12), 0.00261514 s/step
# field decay(t = 2301.15): 0.00010425930326425912 / 0.00010425930326425912 = 1.0
# on time step 92902 (time=2322.55), 0.00267234 s/step
# field decay(t = 2351.175): 0.0001370754598746503 / 0.0001370754598746503 = 1.0
# on time step 94198 (time=2354.95), 0.00308824 s/step
# on time step 95616 (time=2390.4), 0.00282167 s/step
# field decay(t = 2401.2000000000003): 0.00017932176434145325 / 0.00017932176434145325 = 1.0
# on time step 96870 (time=2421.75), 0.0031898 s/step
# field decay(t = 2451.225): 0.00023341875139219528 / 0.00023341875139219528 = 1.0
# on time step 98270 (time=2456.75), 0.00285997 s/step
# on time step 99619 (time=2490.48), 0.00296577 s/step
# field decay(t = 2501.25): 0.0003023198019911032 / 0.0003023198019911032 = 1.0
# on time step 100986 (time=2524.65), 0.00292812 s/step
# field decay(t = 2551.275): 0.0003896059910711984 / 0.0003896059910711984 = 1.0
# on time step 102359 (time=2558.98), 0.00291452 s/step
# on time step 103746 (time=2593.65), 0.00288482 s/step
# field decay(t = 2601.3): 0.0004995894496556733 / 0.0004995894496556733 = 1.0
# on time step 105023 (time=2625.58), 0.0031328 s/step
# field decay(t = 2651.3250000000003): 0.0006374261645741691 / 0.0006374261645741691 = 1.0
# on time step 106207 (time=2655.18), 0.00337959 s/step
# on time step 107428 (time=2685.7), 0.00327804 s/step
# field decay(t = 2701.3500000000004): 0.000809235559590783 / 0.000809235559590783 = 1.0
# on time step 108648 (time=2716.2), 0.00328105 s/step
# on time step 109799 (time=2744.98), 0.00347852 s/step
# field decay(t = 2751.375): 0.001024594378314124 / 0.001024594378314124 = 1.0
# on time step 111066 (time=2776.65), 0.00315769 s/step
# field decay(t = 2801.4): 0.0012877517752461285 / 0.0012877517752461285 = 1.0
# on time step 112233 (time=2805.83), 0.00342931 s/step
# on time step 113507 (time=2837.68), 0.00313981 s/step
# field decay(t = 2851.425): 0.0016104264768748826 / 0.0016104264768748826 = 1.0
# on time step 114786 (time=2869.65), 0.00312882 s/step
# field decay(t = 2901.4500000000003): 0.0020039100899058543 / 0.0020039100899058543 = 1.0
# on time step 116181 (time=2904.53), 0.0028754 s/step
# on time step 117587 (time=2939.68), 0.00284583 s/step
# field decay(t = 2951.4750000000004): 0.0024810989408117 / 0.0024810989408117 = 1.0
# on time step 119020 (time=2975.5), 0.00279226 s/step
# field decay(t = 3001.5): 0.003056598582164844 / 0.003056598582164844 = 1.0
# on time step 120366 (time=3009.15), 0.00297266 s/step
# on time step 121841 (time=3046.03), 0.00271283 s/step
# field decay(t = 3051.525): 0.0037468060815431274 / 0.0037468060815431274 = 1.0
# on time step 123174 (time=3079.35), 0.00300149 s/step
# field decay(t = 3101.55): 0.0045699620404574615 / 0.0045699620404574615 = 1.0
# on time step 124731 (time=3118.28), 0.00256909 s/step
# field decay(t = 3151.5750000000003): 0.005546161610203413 / 0.005546161610203413 = 1.0
# on time step 126325 (time=3158.12), 0.00251313 s/step
# on time step 127694 (time=3192.35), 0.00292254 s/step
# field decay(t = 3201.6000000000004): 0.006697318207702428 / 0.006697318207702428 = 1.0
# on time step 129131 (time=3228.28), 0.00278499 s/step
# field decay(t = 3251.625): 0.008047071749205303 / 0.008047071749205303 = 1.0
# on time step 130481 (time=3262.03), 0.00296439 s/step
# on time step 131876 (time=3296.9), 0.00286935 s/step
# field decay(t = 3301.65): 0.009620626485133994 / 0.009620626485133994 = 1.0
# on time step 133273 (time=3331.83), 0.00286592 s/step
# field decay(t = 3351.675): 0.011444515003712831 / 0.011444515003712831 = 1.0
# on time step 134593 (time=3364.83), 0.00303271 s/step
# on time step 136019 (time=3400.48), 0.00280545 s/step
# field decay(t = 3401.7000000000003): 0.013546275983318113 / 0.013546275983318113 = 1.0
# on time step 137465 (time=3436.62), 0.00277033 s/step
# field decay(t = 3451.7250000000004): 0.015954051073005467 / 0.015954051073005467 = 1.0
# on time step 138856 (time=3471.4), 0.00287654 s/step
# field decay(t = 3501.75): 0.01869608162876517 / 0.01869608162876517 = 1.0
# on time step 140163 (time=3504.08), 0.00306084 s/step
# on time step 141533 (time=3538.33), 0.00292831 s/step
# field decay(t = 3551.775): 0.021800110636420112 / 0.021800110636420112 = 1.0
# on time step 142974 (time=3574.35), 0.00277594 s/step
# field decay(t = 3601.8): 0.025292708583248908 / 0.025292708583248908 = 1.0
# on time step 144345 (time=3608.62), 0.00291778 s/step
# on time step 145866 (time=3646.65), 0.00263001 s/step
# field decay(t = 3651.8250000000003): 0.02919849828313861 / 0.02919849828313861 = 1.0
# on time step 147382 (time=3684.55), 0.00264079 s/step
# field decay(t = 3701.8500000000004): 0.033539316750882384 / 0.033539316750882384 = 1.0
# on time step 148758 (time=3718.95), 0.00290909 s/step
# on time step 149946 (time=3748.65), 0.00336873 s/step
# field decay(t = 3751.875): 0.03838359876024204 / 0.03838359876024204 = 1.0
# on time step 151268 (time=3781.7), 0.00302735 s/step
# field decay(t = 3801.9): 0.043649042977055116 / 0.043649042977055116 = 1.0
# on time step 152775 (time=3819.38), 0.00265528 s/step
# field decay(t = 3851.925): 0.04938923323697931 / 0.04938923323697931 = 1.0
# on time step 154403 (time=3860.08), 0.00245711 s/step
# on time step 156037 (time=3900.93), 0.00244903 s/step
# field decay(t = 3901.9500000000003): 0.055605580118983124 / 0.055605580118983124 = 1.0
# on time step 157548 (time=3938.7), 0.00264825 s/step
# field decay(t = 3951.9750000000004): 0.06229210226709229 / 0.06229210226709229 = 1.0
# on time step 159187 (time=3979.68), 0.00244164 s/step
# field decay(t = 4002.0): 0.06943463155497846 / 0.06943463155497846 = 1.0
# on time step 160805 (time=4020.12), 0.00247288 s/step
# field decay(t = 4052.025): 0.07701011900715293 / 0.07701011900715293 = 1.0
# on time step 162609 (time=4065.23), 0.00221735 s/step
# field decay(t = 4102.05): 0.08498611770557302 / 0.08498611770557302 = 1.0
# on time step 164395 (time=4109.88), 0.00224047 s/step
# on time step 166022 (time=4150.55), 0.00246046 s/step
# field decay(t = 4152.075): 0.09332042685564261 / 0.09332042685564261 = 1.0
# on time step 167772 (time=4194.3), 0.00228652 s/step
# field decay(t = 4202.1): 0.1019609676576616 / 0.1019609676576616 = 1.0
# on time step 169585 (time=4239.62), 0.00220679 s/step
# field decay(t = 4252.125): 0.1108459206905703 / 0.1108459206905703 = 1.0
# on time step 171294 (time=4282.35), 0.00234082 s/step
# field decay(t = 4302.150000000001): 0.11990409295275045 / 0.11990409295275045 = 1.0
# on time step 172956 (time=4323.9), 0.00240751 s/step
# field decay(t = 4352.175): 0.12905559415599208 / 0.12905559415599208 = 1.0
# on time step 174659 (time=4366.48), 0.00234985 s/step
# field decay(t = 4402.2): 0.1382127719787578 / 0.1382127719787578 = 1.0
# on time step 176335 (time=4408.38), 0.00238693 s/step
# on time step 178066 (time=4451.65), 0.00231134 s/step
# field decay(t = 4452.225): 0.14728145029795117 / 0.14728145029795117 = 1.0
# on time step 179654 (time=4491.35), 0.00252763 s/step
# field decay(t = 4502.25): 0.15616239188499476 / 0.15616239188499476 = 1.0
# on time step 181225 (time=4530.62), 0.00254774 s/step
# on time step 181907 (time=4547.68), 0.00586678 s/step
# field decay(t = 4552.275000000001): 0.16475302001014988 / 0.16475302001014988 = 1.0
# on time step 182504 (time=4562.6), 0.00671329 s/step
# on time step 183288 (time=4582.2), 0.00510717 s/step
# on time step 183993 (time=4599.82), 0.00584138 s/step
# field decay(t = 4602.3): 0.172949311595677 / 0.172949311595677 = 1.0
# on time step 184656 (time=4616.4), 0.00605696 s/step
# on time step 185161 (time=4629.03), 0.00792118 s/step
# field decay(t = 4652.325): 0.18064785818961854 / 0.18064785818961854 = 1.0
# on time step 186253 (time=4656.32), 0.00366391 s/step
# on time step 187587 (time=4689.68), 0.00299927 s/step
# field decay(t = 4702.35): 0.187747999759456 / 0.187747999759456 = 1.0
# on time step 188805 (time=4720.12), 0.00328435 s/step
# field decay(t = 4752.375): 0.19421424949288577 / 0.19421424949288577 = 1.0
# on time step 190126 (time=4753.15), 0.00302876 s/step
# on time step 191423 (time=4785.57), 0.00308494 s/step
# field decay(t = 4802.400000000001): 0.1998291923521496 / 0.1998291923521496 = 1.0
# on time step 192775 (time=4819.38), 0.00295944 s/step
# on time step 194017 (time=4850.43), 0.0032229 s/step
# field decay(t = 4852.425): 0.2045809996249147 / 0.2045809996249147 = 1.0
# on time step 195088 (time=4877.2), 0.00375799 s/step
# field decay(t = 4902.45): 0.20840119158769246 / 0.20840119158769246 = 1.0
# on time step 196336 (time=4908.4), 0.00320664 s/step
# on time step 197532 (time=4938.3), 0.00334653 s/step
# field decay(t = 4952.475): 0.2112339013565795 / 0.2112339013565795 = 1.0
# on time step 198741 (time=4968.53), 0.00330871 s/step
# on time step 199749 (time=4993.73), 0.00397071 s/step
# field decay(t = 5002.5): 0.21303726148554916 / 0.21303726148554916 = 1.0
# on time step 201027 (time=5025.68), 0.00313098 s/step
# field decay(t = 5052.525000000001): 0.21378441430840836 / 0.21378441430840836 = 1.0
# on time step 202311 (time=5057.78), 0.00311588 s/step
# on time step 203597 (time=5089.93), 0.0031116 s/step
# field decay(t = 5102.55): 0.21380583498515351 / 0.21380583498515351 = 1.0
# on time step 204925 (time=5123.12), 0.00301207 s/step
# field decay(t = 5152.575000000001): 0.21345560509960215 / 0.21380583498515351 = 0.9983619255032227
# on time step 206276 (time=5156.9), 0.00296135 s/step
# on time step 207448 (time=5186.2), 0.00341407 s/step
# field decay(t = 5202.6): 0.2120622532899472 / 0.21380583498515351 = 0.9918450228669982
# on time step 208665 (time=5216.62), 0.00328828 s/step
# on time step 209818 (time=5245.45), 0.00347578 s/step
# field decay(t = 5252.625): 0.20962723573821734 / 0.21380583498515351 = 0.980456102859745
# on time step 211162 (time=5279.05), 0.00298166 s/step
# field decay(t = 5302.650000000001): 0.2061866614549741 / 0.21380583498515351 = 0.9643640524090071
# on time step 212403 (time=5310.08), 0.00323125 s/step
# on time step 213568 (time=5339.2), 0.00343408 s/step
# field decay(t = 5352.675): 0.20179107816199304 / 0.21380583498515351 = 0.9438052903280457
# on time step 214800 (time=5370), 0.00324685 s/step
# on time step 216088 (time=5402.2), 0.00311188 s/step
# field decay(t = 5402.700000000001): 0.1965042189651015 / 0.21380583498515351 = 0.9190779053281992
# on time step 217327 (time=5433.18), 0.00322909 s/step
# field decay(t = 5452.725): 0.19040148096501658 / 0.21380583498515351 = 0.8905345402675183
# on time step 218475 (time=5461.88), 0.00348949 s/step
# on time step 219679 (time=5491.98), 0.0033233 s/step
# field decay(t = 5502.75): 0.18356813090331459 / 0.21380583498515351 = 0.858573999704271
# on time step 220791 (time=5519.78), 0.00360493 s/step
# on time step 221993 (time=5549.83), 0.00332879 s/step
# field decay(t = 5552.775000000001): 0.17609733290751917 / 0.21380583498515351 = 0.8236320253829705
# on time step 223174 (time=5579.35), 0.00338972 s/step
# field decay(t = 5602.8): 0.16808803253846985 / 0.21380583498515351 = 0.7861713996259351
# on time step 224333 (time=5608.33), 0.00345357 s/step
# on time step 225832 (time=5645.8), 0.00267625 s/step
# field decay(t = 5652.825000000001): 0.1596428025646696 / 0.21380583498515351 = 0.7466718697165353
# on time step 227403 (time=5685.08), 0.00254662 s/step
# field decay(t = 5702.85): 0.1508656682544237 / 0.21380583498515351 = 0.7056199764842699
# on time step 228901 (time=5722.53), 0.00267089 s/step
# field decay(t = 5752.875): 0.14186002050594365 / 0.21380583498515351 = 0.6634992937203715
# on time step 230452 (time=5761.3), 0.00258069 s/step
# on time step 232016 (time=5800.4), 0.00255818 s/step
# field decay(t = 5802.900000000001): 0.13263500401523678 / 0.21380583498515351 = 0.6203525924558927
# on time step 233499 (time=5837.48), 0.00269885 s/step
# field decay(t = 5852.925): 0.12347046594155733 / 0.21380583498515351 = 0.5774887572648848
# on time step 235032 (time=5875.8), 0.00261253 s/step
# field decay(t = 5902.950000000001): 0.11436589786595462 / 0.21380583498515351 = 0.534905410200316
# on time step 236516 (time=5912.9), 0.0026959 s/step
# on time step 237925 (time=5948.12), 0.00284139 s/step
# field decay(t = 5952.975): 0.10540434997105058 / 0.21380583498515351 = 0.49299098866207164
# on time step 239243 (time=5981.08), 0.00303508 s/step
# field decay(t = 6003.0): 0.09666050341553269 / 0.21380583498515351 = 0.45209478694650546
# on time step 240487 (time=6012.18), 0.003243 s/step
# on time step 241571 (time=6039.28), 0.00369087 s/step
# field decay(t = 6053.025000000001): 0.08819990054015796 / 0.21380583498515351 = 0.4125233558115122
# on time step 242674 (time=6066.85), 0.00362796 s/step
# on time step 243914 (time=6097.85), 0.00322699 s/step
# field decay(t = 6103.05): 0.08007844967898003 / 0.21380583498515351 = 0.37453818640890046
# on time step 245014 (time=6125.35), 0.00363637 s/step
# field decay(t = 6153.075000000001): 0.07234220575731401 / 0.21380583498515351 = 0.3383546841101759
# on time step 246300 (time=6157.5), 0.00311193 s/step
# on time step 247440 (time=6186), 0.00350958 s/step
# field decay(t = 6203.1): 0.0650273966462447 / 0.21380583498515351 = 0.3041422917702884
# on time step 248376 (time=6209.4), 0.00427512 s/step
# on time step 249487 (time=6237.18), 0.00360324 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 44
#      41 plt.show()
#      43 # Run normalization simulation
# ---> 44 norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))
#      46 eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
#      47 ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:4530, in Simulation.run(self, *step_funcs, **kwargs)
#    4527     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4529 if until_after_sources is not None:
# -> 4530     self._run_sources_until(until_after_sources, step_funcs)
#    4531 elif until is not None:
#    4532     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2871, in Simulation._run_sources_until(self, cond, step_funcs)
#    2867             return cond[i](sim) and sim.round_time() >= ts
#    2869         new_conds.append(f)
# -> 2871 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2829, in Simulation._run_until(self, cond, step_funcs)
#    2827     for func in step_funcs:
#    2828         _eval_step_func(self, func, "step")
# -> 2829     self.fields.step()
#    2831 # Translating the recursive scheme version of run-until into an iterative version
#    2832 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2833 # be the same as scheme.
#    2834 for func in step_funcs:
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/__init__.py:3040, in fields.step(self)
#    3039 def step(self):
# -> 3040     return _meep.fields_step(self)
#
# KeyboardInterrupt:

# %%
# Main simulation with holes
geometry_holes = [mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)]

hole_positions = generate_waveguide(N, t_1, t_2, r)
for x_position in hole_positions:
    geometry_holes.append(mp.Cylinder(r, height=mp.inf, center=mp.Vector3(x_position, 0, 0), material=mp.air))

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry_holes,  # Geometry with holes
                    sources=sources,
                    resolution=resolution)



# Add flux monitors
refl = sim.add_flux(fcen, df, nfreq, refl_fr)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()

# Load the saved flux data for normalization
sim.load_minus_flux_data(refl, norm_refl_data)

# Run simulation with holes
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Get the reflected and transmitted flux
reflected_flux = mp.get_fluxes(refl)
transmitted_flux = mp.get_fluxes(tran)

# Normalize the transmission and reflection
transmission = np.array(transmitted_flux) / norm_incident_flux
reflection = np.array(reflected_flux) / norm_incident_flux
freqs = np.linspace(fcen - df/2, fcen + df/2, nfreq)

# Plot the transmission and reflection
plt.figure(figsize=(10, 6))
plt.plot(freqs, transmission, label="Transmission")
plt.plot(freqs, reflection, label="Reflection")
plt.xlabel("Frequency (1/μm)")
plt.ylabel("Normalized Flux")
plt.legend()
plt.title("Transmission and Reflection Spectra")
plt.grid(True)
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00342917 s
# Working in 2D dimensions.
# Computational cell is 38 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# time for set_epsilon = 1.28502 s
# -----------
# on time step 1651 (time=41.275), 0.00242291 s/step
# field decay(t = 50.025000000000006): 8.843647792517987e-15 / 8.843647792517987e-15 = 1.0
# on time step 3116 (time=77.9), 0.00273172 s/step
# field decay(t = 100.05000000000001): 1.2569756415976664e-12 / 1.2569756415976664e-12 = 1.0
# on time step 4585 (time=114.625), 0.00272373 s/step
# field decay(t = 150.07500000000002): 1.3590169852886214e-12 / 1.3590169852886214e-12 = 1.0
# on time step 6286 (time=157.15), 0.00235209 s/step
# on time step 7984 (time=199.6), 0.00235573 s/step
# field decay(t = 200.10000000000002): 2.179841337277421e-12 / 2.179841337277421e-12 = 1.0
# on time step 9813 (time=245.325), 0.00218705 s/step
# field decay(t = 250.125): 3.5395692797776636e-12 / 3.5395692797776636e-12 = 1.0
# on time step 11577 (time=289.425), 0.00226834 s/step
# field decay(t = 300.15000000000003): 5.7048611065486865e-12 / 5.7048611065486865e-12 = 1.0
# on time step 13112 (time=327.8), 0.00260643 s/step
# field decay(t = 350.175): 9.158529780929858e-12 / 9.158529780929858e-12 = 1.0
# on time step 14825 (time=370.625), 0.00233555 s/step
# field decay(t = 400.20000000000005): 1.4618785740284763e-11 / 1.4618785740284763e-11 = 1.0
# on time step 16479 (time=411.975), 0.00241937 s/step
# field decay(t = 450.225): 2.3327716239170106e-11 / 2.3327716239170106e-11 = 1.0
# on time step 18220 (time=455.5), 0.00229836 s/step
# on time step 19990 (time=499.75), 0.00226016 s/step
# field decay(t = 500.25): 3.686805076058844e-11 / 3.686805076058844e-11 = 1.0
# on time step 21793 (time=544.825), 0.00222039 s/step
# field decay(t = 550.275): 5.7979507317910954e-11 / 5.7979507317910954e-11 = 1.0
# on time step 23543 (time=588.575), 0.00228599 s/step
# field decay(t = 600.3000000000001): 9.072732884893226e-11 / 9.072732884893226e-11 = 1.0
# on time step 25278 (time=631.95), 0.00231192 s/step
# field decay(t = 650.325): 1.4125090630101162e-10 / 1.4125090630101162e-10 = 1.0
# on time step 27104 (time=677.6), 0.00219237 s/step
# field decay(t = 700.35): 2.188226277441399e-10 / 2.188226277441399e-10 = 1.0
# on time step 28766 (time=719.15), 0.00240959 s/step
# field decay(t = 750.375): 3.373086342238134e-10 / 3.373086342238134e-10 = 1.0
# on time step 30356 (time=758.9), 0.002527 s/step
# on time step 31899 (time=797.475), 0.00259327 s/step
# field decay(t = 800.4000000000001): 5.1735035592506e-10 / 5.1735035592506e-10 = 1.0
# on time step 33497 (time=837.425), 0.0025033 s/step
# field decay(t = 850.4250000000001): 7.895347713303726e-10 / 7.895347713303726e-10 = 1.0
# on time step 35097 (time=877.425), 0.00250638 s/step
# field decay(t = 900.45): 1.198898576427025e-09 / 1.198898576427025e-09 = 1.0
# on time step 36539 (time=913.475), 0.00278099 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 28
#      25 sim.load_minus_flux_data(refl, norm_refl_data)
#      27 # Run simulation with holes
# ---> 28 sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))
#      30 eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
#      31 ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:4530, in Simulation.run(self, *step_funcs, **kwargs)
#    4527     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4529 if until_after_sources is not None:
# -> 4530     self._run_sources_until(until_after_sources, step_funcs)
#    4531 elif until is not None:
#    4532     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2871, in Simulation._run_sources_until(self, cond, step_funcs)
#    2867             return cond[i](sim) and sim.round_time() >= ts
#    2869         new_conds.append(f)
# -> 2871 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/simulation.py:2829, in Simulation._run_until(self, cond, step_funcs)
#    2827     for func in step_funcs:
#    2828         _eval_step_func(self, func, "step")
# -> 2829     self.fields.step()
#    2831 # Translating the recursive scheme version of run-until into an iterative version
#    2832 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2833 # be the same as scheme.
#    2834 for func in step_funcs:
#
# File ~/miniconda3/envs/sshenv/lib/python3.11/site-packages/meep/__init__.py:3040, in fields.step(self)
#    3039 def step(self):
# -> 3040     return _meep.fields_step(self)
#
# KeyboardInterrupt:

# %%
# Source
sources = [mp.Source(mp.GaussianSource(wavelength=wl, fwidth=df),
                     component=mp.Ey,
                     center=mp.Vector3(-0.5 * sx + dpml),
                     size=mp.Vector3(0, w, 0))]

# Normalization run simulation
norm_sim = mp.Simulation(cell_size=cell,
                         boundary_layers=pml_layers,
                         geometry=[mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)],  # No holes for normalization
                         sources=sources,
                         resolution=resolution)



# Flux monitors
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5 * sx + dpml + 0.5), size=mp.Vector3(0, 2*w, 0))
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5 * sx - dpml - 0.5), size=mp.Vector3(0, 2*w, 0))


# Add flux monitors
norm_refl = norm_sim.add_flux(fcen, df, nfreq, refl_fr)
norm_tran = norm_sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
norm_sim.plot2D()
plt.show()

# Run normalization simulation
norm_sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = norm_sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ey)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Save flux for normalization
norm_refl_data = norm_sim.get_flux_data(norm_refl)
norm_tran_data = norm_sim.get_flux_data(norm_tran)

# Calculate the incident power for normalization
norm_refl_flux = mp.get_fluxes(norm_refl)
norm_tran_flux = mp.get_fluxes(norm_tran)
norm_incident_flux = np.array(norm_refl_flux) + np.array(norm_tran_flux)

# Reset simulation for main run with holes
norm_sim.reset_meep()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00681901 s
# Working in 2D dimensions.
# Computational cell is 38 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
# time for set_epsilon = 0.233639 s
# -----------
# on time step 5941 (time=148.525), 0.000673388 s/step
# on time step 11912 (time=297.8), 0.000669912 s/step
# on time step 17979 (time=449.475), 0.000659337 s/step
# on time step 23950 (time=598.75), 0.000669988 s/step
# on time step 29782 (time=744.55), 0.000685948 s/step
# on time step 35967 (time=899.175), 0.000646747 s/step
# on time step 42025 (time=1050.62), 0.000660332 s/step
# on time step 48311 (time=1207.78), 0.000636436 s/step
# on time step 54652 (time=1366.3), 0.000630866 s/step
# on time step 61008 (time=1525.2), 0.000629345 s/step
# on time step 67169 (time=1679.23), 0.000649275 s/step
# on time step 73503 (time=1837.58), 0.000631591 s/step
# on time step 79738 (time=1993.45), 0.000641598 s/step
# on time step 86077 (time=2151.93), 0.000631102 s/step
# on time step 92491 (time=2312.28), 0.00062371 s/step
# on time step 98548 (time=2463.7), 0.000660465 s/step
# on time step 104194 (time=2604.85), 0.000708518 s/step
# on time step 110061 (time=2751.53), 0.000681803 s/step
# on time step 116165 (time=2904.12), 0.00065532 s/step
# on time step 122115 (time=3052.88), 0.000672395 s/step
# on time step 127445 (time=3186.12), 0.000750473 s/step
# on time step 133009 (time=3325.23), 0.000718932 s/step
# on time step 138524 (time=3463.1), 0.000725312 s/step
# on time step 144393 (time=3609.83), 0.000681637 s/step
# on time step 150455 (time=3761.38), 0.000659925 s/step
# on time step 156191 (time=3904.78), 0.000697434 s/step
# on time step 162015 (time=4050.38), 0.000686907 s/step
# on time step 167569 (time=4189.23), 0.000720312 s/step
# on time step 173150 (time=4328.75), 0.000716757 s/step
# on time step 178920 (time=4473), 0.000693341 s/step
# on time step 184399 (time=4609.98), 0.000730197 s/step
# on time step 189855 (time=4746.38), 0.000733177 s/step
# on time step 195408 (time=4885.2), 0.000720334 s/step
# on time step 201167 (time=5029.18), 0.000694636 s/step
# on time step 206960 (time=5174), 0.000690503 s/step
# on time step 212625 (time=5315.62), 0.000706211 s/step
# on time step 218383 (time=5459.58), 0.000694743 s/step
# on time step 223983 (time=5599.58), 0.000714328 s/step
# on time step 229677 (time=5741.93), 0.000702565 s/step
# on time step 235565 (time=5889.12), 0.000679359 s/step
# on time step 241515 (time=6037.88), 0.000672292 s/step
# on time step 246629 (time=6165.73), 0.000782192 s/step
# on time step 251768 (time=6294.2), 0.000778482 s/step
# on time step 257219 (time=6430.48), 0.000733831 s/step
# on time step 263105 (time=6577.62), 0.000679635 s/step
# on time step 269128 (time=6728.2), 0.000664228 s/step
# on time step 275248 (time=6881.2), 0.000653632 s/step
# on time step 281412 (time=7035.3), 0.000648977 s/step
# on time step 287307 (time=7182.68), 0.000678634 s/step
# on time step 293356 (time=7333.9), 0.000661348 s/step
# on time step 299043 (time=7476.08), 0.000703366 s/step
# on time step 305043 (time=7626.08), 0.000666742 s/step
# on time step 310992 (time=7774.8), 0.000672384 s/step
# on time step 317183 (time=7929.58), 0.000646198 s/step
# on time step 323432 (time=8085.8), 0.00064014 s/step
# on time step 329527 (time=8238.18), 0.000656312 s/step
# on time step 335140 (time=8378.5), 0.000712682 s/step
# on time step 340420 (time=8510.5), 0.000757633 s/step
# on time step 344438 (time=8610.95), 0.000995527 s/step
# on time step 348713 (time=8717.83), 0.000935736 s/step
# on time step 353823 (time=8845.58), 0.000782795 s/step
# on time step 359395 (time=8984.88), 0.000717922 s/step
# on time step 364981 (time=9124.52), 0.000716187 s/step
# on time step 370450 (time=9261.25), 0.000731423 s/step
# on time step 376170 (time=9404.25), 0.000699316 s/step
# on time step 380861 (time=9521.52), 0.000852778 s/step
# on time step 386112 (time=9652.8), 0.000761839 s/step
# on time step 391487 (time=9787.18), 0.000744261 s/step
# on time step 396895 (time=9922.38), 0.000739656 s/step
# run 0 finished at t = 10005.0 (400200 timesteps)

# %%
# Main simulation with holes
geometry_holes = [mp.Block(size=mp.Vector3(mp.inf, w, mp.inf), material=SiO2_material)]

hole_positions = generate_waveguide(N, t_1, t_2, r)
for x_position in hole_positions:
    geometry_holes.append(mp.Cylinder(r, height=mp.inf, center=mp.Vector3(x_position, 0, 0), material=mp.air))

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry_holes,  # Geometry with holes
                    sources=sources,
                    resolution=resolution)



# Add flux monitors
refl = sim.add_flux(fcen, df, nfreq, refl_fr)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()


# Load the saved flux data for normalization
sim.load_minus_flux_data(refl, norm_refl_data)

# Run simulation with holes
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5 * sx - dpml - 0.5), 1e-3))

eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ey)
plt.figure(figsize=(16,9) )
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# Get the reflected and transmitted flux
reflected_flux = mp.get_fluxes(refl)
transmitted_flux = mp.get_fluxes(tran)

# Normalize the transmission and reflection
transmission = np.array(transmitted_flux) / norm_incident_flux
reflection = np.array(reflected_flux) / norm_incident_flux
freqs = np.linspace(fcen - df/2, fcen + df/2, nfreq)

# Plot the transmission and reflection
plt.figure(figsize=(10, 6))
plt.plot(freqs, transmission, label="Transmission")
plt.plot(freqs, reflection, label="Reflection")
plt.xlabel("Frequency (1/μm)")
plt.ylabel("Normalized Flux")
plt.legend()
plt.title("Transmission and Reflection Spectra")
plt.grid(True)
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000643015 s
# Working in 2D dimensions.
# Computational cell is 38 x 10 x 0 with resolution 20
#      block, center = (0,0,0)
#           size (1e+20,2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      cylinder, center = (-17,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-15,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-12,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-10,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-7,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-5,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-2,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (3,0,0)
#           radius 0.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 6 objects not shown)...
# time for set_epsilon = 0.60415 s
# -----------
# on time step 4244 (time=106.1), 0.000942527 s/step
# on time step 8271 (time=206.775), 0.000993331 s/step
# on time step 11646 (time=291.15), 0.00118556 s/step
# on time step 15667 (time=391.675), 0.000994989 s/step
# on time step 19362 (time=484.05), 0.00108285 s/step
# on time step 23004 (time=575.1), 0.00109833 s/step
# on time step 26767 (time=669.175), 0.00106324 s/step
# on time step 30305 (time=757.625), 0.00113086 s/step
# on time step 34334 (time=858.35), 0.000993048 s/step
# on time step 38161 (time=954.025), 0.00104548 s/step
# on time step 41892 (time=1047.3), 0.00107235 s/step
# on time step 45789 (time=1144.73), 0.00102644 s/step
# on time step 49006 (time=1225.15), 0.00124363 s/step
# on time step 52159 (time=1303.98), 0.00126864 s/step
# on time step 55510 (time=1387.75), 0.00119383 s/step
# on time step 58979 (time=1474.48), 0.00115318 s/step
# on time step 62895 (time=1572.38), 0.00102157 s/step
# on time step 66872 (time=1671.8), 0.00100588 s/step
# on time step 71017 (time=1775.43), 0.000965204 s/step
# on time step 75230 (time=1880.75), 0.00094965 s/step
# on time step 79392 (time=1984.8), 0.000961165 s/step
# on time step 83154 (time=2078.85), 0.00106331 s/step
# on time step 87059 (time=2176.47), 0.00102441 s/step
# on time step 90894 (time=2272.35), 0.00104318 s/step
# on time step 94055 (time=2351.38), 0.00126567 s/step
# on time step 98019 (time=2450.47), 0.00100922 s/step
# on time step 101998 (time=2549.95), 0.0010055 s/step
# on time step 106091 (time=2652.28), 0.000977517 s/step
# on time step 110163 (time=2754.08), 0.000982356 s/step
# on time step 114110 (time=2852.75), 0.00101345 s/step
# on time step 117552 (time=2938.8), 0.00116236 s/step
# on time step 121542 (time=3038.55), 0.00100262 s/step
# on time step 125662 (time=3141.55), 0.000971036 s/step
# on time step 129713 (time=3242.83), 0.000987487 s/step
# on time step 133938 (time=3348.45), 0.000946956 s/step
# on time step 137912 (time=3447.8), 0.0010067 s/step
# on time step 141763 (time=3544.08), 0.00103894 s/step
# on time step 145691 (time=3642.28), 0.00101834 s/step
# on time step 149401 (time=3735.03), 0.00107828 s/step
# on time step 153193 (time=3829.83), 0.00105502 s/step
# on time step 157205 (time=3930.12), 0.00099711 s/step
# on time step 160904 (time=4022.6), 0.00108154 s/step
# on time step 164496 (time=4112.4), 0.00111361 s/step
# on time step 168147 (time=4203.68), 0.00109567 s/step
# on time step 172244 (time=4306.1), 0.000976475 s/step
# on time step 176334 (time=4408.35), 0.000977997 s/step
# on time step 180433 (time=4510.82), 0.000975849 s/step
# on time step 184542 (time=4613.55), 0.000973665 s/step
# on time step 188554 (time=4713.85), 0.000997115 s/step
# on time step 192054 (time=4801.35), 0.00114298 s/step
# on time step 195581 (time=4889.53), 0.0011343 s/step
# on time step 199135 (time=4978.38), 0.00112568 s/step
# on time step 203112 (time=5077.8), 0.00100596 s/step
# on time step 206793 (time=5169.83), 0.0010869 s/step
# on time step 210444 (time=5261.1), 0.0010956 s/step
# on time step 214012 (time=5350.3), 0.00112114 s/step
# on time step 217827 (time=5445.68), 0.00104865 s/step
# on time step 221545 (time=5538.62), 0.00107587 s/step
# on time step 225019 (time=5625.48), 0.00115169 s/step
# on time step 228981 (time=5724.53), 0.0010098 s/step
# on time step 233140 (time=5828.5), 0.000961812 s/step
# on time step 236869 (time=5921.73), 0.00107283 s/step
# on time step 240740 (time=6018.5), 0.00103342 s/step
# on time step 244433 (time=6110.83), 0.00108336 s/step
# on time step 248335 (time=6208.38), 0.00102534 s/step
# on time step 252148 (time=6303.7), 0.00104919 s/step
# on time step 256166 (time=6404.15), 0.000995569 s/step
# on time step 260260 (time=6506.5), 0.000977083 s/step
# on time step 264396 (time=6609.9), 0.000967188 s/step
# on time step 268487 (time=6712.18), 0.000977979 s/step
# on time step 272194 (time=6804.85), 0.00107922 s/step
# on time step 275733 (time=6893.33), 0.0011305 s/step
# on time step 279436 (time=6985.9), 0.00108046 s/step
# on time step 283329 (time=7083.23), 0.00102772 s/step
# on time step 287111 (time=7177.78), 0.00105772 s/step
# on time step 290999 (time=7274.98), 0.00102888 s/step
# on time step 295095 (time=7377.38), 0.000976781 s/step
# on time step 298861 (time=7471.53), 0.0010623 s/step
# on time step 302713 (time=7567.83), 0.00103849 s/step
# on time step 306770 (time=7669.25), 0.000986187 s/step
# on time step 310901 (time=7772.53), 0.000968461 s/step
# on time step 314713 (time=7867.83), 0.00104953 s/step
# on time step 318412 (time=7960.3), 0.00108152 s/step
# on time step 322281 (time=8057.03), 0.00103398 s/step
# on time step 325978 (time=8149.45), 0.00108198 s/step
# on time step 330027 (time=8250.68), 0.000988134 s/step
# on time step 333982 (time=8349.55), 0.00101143 s/step
# on time step 337520 (time=8438), 0.00113081 s/step
# on time step 341290 (time=8532.25), 0.00106126 s/step
# on time step 345066 (time=8626.65), 0.00105951 s/step
# on time step 348990 (time=8724.75), 0.00101951 s/step
# on time step 353092 (time=8827.3), 0.000975173 s/step
# on time step 356931 (time=8923.27), 0.00104195 s/step
# on time step 360647 (time=9016.18), 0.0010767 s/step
# on time step 364429 (time=9110.73), 0.00105789 s/step
# on time step 368211 (time=9205.27), 0.00105783 s/step
# on time step 371823 (time=9295.58), 0.00110747 s/step
# on time step 375487 (time=9387.18), 0.00109177 s/step
# on time step 379223 (time=9480.58), 0.0010708 s/step
# on time step 382974 (time=9574.35), 0.00106647 s/step
# on time step 386937 (time=9673.43), 0.00100939 s/step
# on time step 390548 (time=9763.7), 0.001108 s/step
# on time step 394268 (time=9856.7), 0.00107536 s/step
# on time step 398158 (time=9953.95), 0.0010285 s/step
# run 0 finished at t = 10005.0 (400200 timesteps)
